# %%
from data import generate_batches
from data import prepare_data

from model.encoder import Encoder
from model.decoder import Decoder_luong

from BLEU import BLEU

from utils import time_since


from evaluator_dis import Evaluator

import torch
import torch.nn as nn
from torch.nn import functional
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

import numpy as np
import time
import random
import os
#from validation import Evaluator

# %load_ext autoreload
# %autoreload 2

# %%
USE_CUDA = True
MAX_LENGTH = 100
DIR_FILES = 'data/disambiguation/sense-eval2/'
DIR_TRAIN = os.path.join(DIR_FILES, 'train')
DIR_TEST = os.path.join(DIR_FILES, 'test')
DIR_RESULTS = 'results/step_1'
SPLIT_TRAIN = 0.7
SPLIT_VALID = 0.15
# The rest is for test

# %% [markdown]
# # Reading the data

# %%
input_lang, output_lang, pairs = prepare_data('en', 'spa', max_length=MAX_LENGTH, dir=DIR_TRAIN)
# Out:
# Reading lines...
# Read 9080 sentence pairs
# Filtered to 9057 pairs
# Creating vocab...
# Indexed 23102 words in input language, 23688 words in output

# %%
def read_test(dir):
    pairs = []
    with open(os.path.join(dir, 'test.raw'), 'r') as file:
        for line in file.readlines():
            pairs.append(line.replace('\n', ''))
    
    return pairs

# %%
pairs_train = np.array(pairs)
pairs_test = read_test(DIR_TEST)

# %% [markdown]
# # Train

# %%
def train(input_batches, target_batches, \
          encoder, decoder, encoder_optimizer, decoder_optimzier, \
          criterion, max_length=MAX_LENGTH, train=True):
    
    if train:
        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()
        
    loss = 0
    
    batch_size = input_batches.size()[1]
    
    encoder_hidden = encoder.init_hidden(batch_size)
    encoder_outputs, encoder_hidden = encoder(input_batches, encoder_hidden)
    
    decoder_context = Variable(torch.zeros(batch_size, decoder.hidden_size))   
    decoder_hidden = encoder_hidden
    
    # set the start of the sentences of the batch
    decoder_input = Variable(torch.LongTensor([input_lang.vocab.stoi['<sos>']] * batch_size))

    # store the decoder outputs to estimate the loss
    all_decoder_outputs = Variable(torch.zeros(target_batches.size()[0], batch_size, len(output_lang.vocab.stoi)))
    
    if USE_CUDA:
        decoder_input = decoder_input.cuda()
        all_decoder_outputs = all_decoder_outputs.cuda()
        decoder_context = decoder_context.cuda()  
    
    if train:
        use_teacher_forcing = random.random() < teacher_forcing_ratio
    else:
        use_teacher_forcing = False

    if use_teacher_forcing:        
        # Use targets as inputs
        for di in range(target_batches.shape[0]):
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
                decoder_input.unsqueeze(0), decoder_context, decoder_hidden, encoder_outputs)
            
            all_decoder_outputs[di] = decoder_output
            decoder_input = target_batches[di]
    else:        
        # Use decoder output as inputs
        for di in range(target_batches.shape[0]):            
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
                decoder_input.unsqueeze(0), decoder_context, decoder_hidden, encoder_outputs) 
            
            all_decoder_outputs[di] = decoder_output
            
            # Greedy approach, take the word with highest probability
            topv, topi = decoder_output.data.topk(1)            
            decoder_input = Variable(torch.LongTensor(topi.cpu()).squeeze())
            if USE_CUDA: decoder_input = decoder_input.cuda()
    
    loss = nn.NLLLoss()(all_decoder_outputs.view(-1, decoder.output_size), target_batches.contiguous().view(-1))          
    
    if train:
        loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
        torch.nn.utils.clip_grad_norm_(decoder.parameters(), clip)
        encoder_optimizer.step()
        decoder_optimizer.step()
    
    return loss.item()

# %% [markdown]
# # Model

# %%
attn_model = 'general'
hidden_size = 512
emb_size = 300
n_layers = 2
seed = 12
dropout_p = 0.1
teacher_forcing_ratio = 0.5
clip = 5.0

n_epochs = 30
batch_size = 64

# %%
torch.manual_seed(seed)
np.random.seed(seed)

# %%
encoder = Encoder(len(input_lang.vocab.stoi), hidden_size, emb_size, n_layers, dropout_p, input_lang, USE_CUDA)
decoder = Decoder_luong(attn_model, hidden_size, len(output_lang.vocab.stoi), emb_size, 2 * n_layers, dropout_p, output_lang, USE_CUDA)

if USE_CUDA:
    encoder = encoder.cuda()
    decoder = decoder.cuda()
    
learning_rate = 0.001
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()

# %%
# Keep track of time elapsed and running averages
start = time.time()
train_losses = []
validation_losses = []
validation_acc = []

plot_every = 5
print_every = 5
validate_loss_every = 25
best_acc = 0
print_loss_total = 0 # Reset every print_every
plot_loss_total = 0 # Reset every plot_every

# %%
for epoch in range(1, n_epochs): 
    # Shuffle data
    id_aux = np.random.permutation(np.arange(len(pairs_train)))
    pairs_train = pairs_train[id_aux]
    
    # Get the batches for this epoch
    input_batches, target_batches = generate_batches(input_lang, output_lang, batch_size, pairs_train, USE_CUDA=USE_CUDA)
    print_loss_total = 0
    
    for batch_ix, (input_var, target_var) in enumerate(zip(input_batches, target_batches)):
        encoder.train()
        decoder.train()
        
        #[input_var, _, _, _, _, _, _, _] = input_batch

        # Run the train function
        loss = train(input_var, target_var,\
                 encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, 
                 max_length=MAX_LENGTH, train=True)
        #loss = train_luong(input_var, target_var, input_var.size(1), True)
            
        torch.cuda.empty_cache()

        # Keep track of loss
        print_loss_total += loss
        plot_loss_total += loss

        if batch_ix == 0: continue

        if batch_ix % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print_summary = '%s (%d %d%%) %.4f' % (time_since(start, epoch / n_epochs), epoch, batch_ix / len(input_batches) * 100, print_loss_avg)
            train_losses.append(loss)
            print(print_summary)
    
    #input_batches, target_batches = generate_batches(input_lang, output_lang, batch_size, pairs_test, USE_CUDA=USE_CUDA)
    #print_loss_total = 0
    encoder.eval()
    decoder.eval()
    #for input_batch, target_var in zip(input_batches, target_batches):
    
    #    encoder.eval()
    #    decoder.eval()
    
    #    #[input_var, _, _, _, _, _, _, _] = input_batch
    #    input_var = input_batch
    #    # Run the train function
    #    loss = train(input_var, target_var,\
    #             encoder, decoder, encoder_optimizer, decoder_optimizer, criterion,\
    #             max_length=MAX_LENGTH, train=False)
        
    #    print_loss_total += loss
    #val_loss = print_loss_total / len(input_batches)
    #validation_losses.append(val_loss)
    # Evaluating acc
    evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
    acc = evaluator.evaluate_acc(pairs_test, k_beams=1)
    if acc > best_acc:
        best_bleu = acc
        torch.save(encoder.state_dict(), f'{DIR_RESULTS}/encoder.pkl')
        torch.save(decoder.state_dict(), f'{DIR_RESULTS}/decoder.pkl')
    validation_acc.append(acc)
    print(f'------------- acc: {acc}')

    # Prevent overflow gpu memory
    del evaluator
# Out:
# 0m 12s (- 6m 11s) (1 3%) 8.6818
# 0m 25s (- 12m 14s) (1 7%) 4.1682
# 0m 36s (- 17m 49s) (1 10%) 3.4351
# 0m 47s (- 22m 50s) (1 14%) 3.5046
# 0m 59s (- 28m 33s) (1 17%) 3.3789
# 1m 9s (- 33m 34s) (1 21%) 3.4257
# 1m 19s (- 38m 34s) (1 24%) 3.1339
# 1m 30s (- 43m 46s) (1 28%) 3.3261
# 1m 44s (- 50m 28s) (1 31%) 2.9057
# 1m 55s (- 55m 56s) (1 35%) 3.0947
# 2m 8s (- 61m 59s) (1 38%) 3.0848
# 2m 18s (- 66m 55s) (1 42%) 3.2857
# 2m 30s (- 72m 50s) (1 45%) 2.8325
# 2m 40s (- 77m 38s) (1 49%) 3.0030
# 2m 49s (- 81m 52s) (1 52%) 3.4222
# 2m 57s (- 86m 1s) (1 56%) 3.6910
# 3m 9s (- 91m 24s) (1 59%) 3.2429
# 3m 23s (- 98m 27s) (1 63%) 2.9688
# 3m 36s (- 104m 37s) (1 66%) 2.9571
# 3m 46s (- 109m 33s) (1 70%) 3.1424
# 4m 0s (- 116m 11s) (1 73%) 2.7055
# 4m 10s (- 121m 11s) (1 77%) 3.1694
# 4m 20s (- 125m 47s) (1 80%) 3.1557
# 4m 33s (- 132m 21s) (1 84%) 2.6898
# 4m 42s (- 136m 39s) (1 88%) 2.9978
# 4m 54s (- 142m 22s) (1 91%) 2.9846
# 5m 9s (- 149m 31s) (1 95%) 2.4678
# 5m 19s (- 154m 33s) (1 98%) 2.9141
# ------------- acc: 0.0
# 13m 30s (- 189m 5s) (2 3%) 3.6670
# 13m 44s (- 192m 21s) (2 7%) 2.4525
# 13m 56s (- 195m 7s) (2 10%) 2.5548
# 14m 8s (- 198m 4s) (2 14%) 2.6615
# 14m 22s (- 201m 20s) (2 17%) 2.3406
# 14m 36s (- 204m 28s) (2 21%) 2.3725
# 14m 48s (- 207m 20s) (2 24%) 2.5938
# 15m 1s (- 210m 14s) (2 28%) 2.5301
# 15m 14s (- 213m 17s) (2 31%) 2.6052
# 15m 28s (- 216m 41s) (2 35%) 2.2992
# 15m 41s (- 219m 45s) (2 38%) 2.4131
# 15m 51s (- 221m 59s) (2 42%) 2.7696
# 16m 5s (- 225m 18s) (2 45%) 2.4591
# 16m 17s (- 228m 2s) (2 49%) 2.6088
# 16m 29s (- 230m 48s) (2 52%) 2.6231
# 16m 40s (- 233m 20s) (2 56%) 2.6426
# 16m 47s (- 235m 11s) (2 59%) 2.9014
# 16m 55s (- 237m 1s) (2 63%) 3.0166
# 17m 6s (- 239m 37s) (2 66%) 2.5148
# 17m 17s (- 242m 11s) (2 70%) 2.4852
# 17m 28s (- 244m 32s) (2 73%) 2.6586
# 17m 38s (- 246m 52s) (2 77%) 2.6790
# 17m 49s (- 249m 36s) (2 80%) 2.3629
# 17m 59s (- 251m 56s) (2 84%) 2.5138
# 18m 9s (- 254m 16s) (2 88%) 2.5027
# 18m 19s (- 256m 30s) (2 91%) 2.5030
# 18m 30s (- 259m 13s) (2 95%) 2.4588
# 18m 41s (- 261m 46s) (2 98%) 2.2594
# ------------- acc: 0.0
# 30m 36s (- 275m 28s) (3 3%) 2.3436
# 30m 47s (- 277m 11s) (3 7%) 2.3333
# 30m 57s (- 278m 40s) (3 10%) 2.2144
# 31m 8s (- 280m 14s) (3 14%) 2.3309
# 31m 16s (- 281m 32s) (3 17%) 2.5370
# 31m 26s (- 282m 54s) (3 21%) 2.1586
# 31m 36s (- 284m 32s) (3 24%) 1.9718
# 31m 47s (- 286m 8s) (3 28%) 2.0840
# 31m 56s (- 287m 32s) (3 31%) 2.2224
# 32m 8s (- 289m 12s) (3 35%) 2.0150
# 32m 20s (- 291m 8s) (3 38%) 1.9320
# 32m 31s (- 292m 40s) (3 42%) 1.9158
# 32m 41s (- 294m 15s) (3 45%) 1.8316
# 32m 52s (- 295m 53s) (3 49%) 1.9927
# 33m 7s (- 298m 8s) (3 52%) 1.7936
# 33m 19s (- 299m 52s) (3 56%) 1.9236
# 33m 29s (- 301m 26s) (3 59%) 1.6888
# 33m 44s (- 303m 38s) (3 63%) 1.7401
# 33m 59s (- 305m 54s) (3 66%) 1.7266
# 34m 8s (- 307m 17s) (3 70%) 1.9985
# 34m 19s (- 308m 54s) (3 73%) 2.0770
# 34m 31s (- 310m 41s) (3 77%) 1.8163
# 34m 43s (- 312m 28s) (3 80%) 1.8123
# 34m 52s (- 313m 51s) (3 84%) 2.0629
# 35m 5s (- 315m 51s) (3 88%) 1.6078
# 35m 17s (- 317m 34s) (3 91%) 2.0718
# 35m 26s (- 318m 55s) (3 95%) 1.8986
# 35m 42s (- 321m 23s) (3 98%) 1.5089
# ------------- acc: 0.0
# 46m 45s (- 303m 58s) (4 3%) 1.7302
# 46m 57s (- 305m 15s) (4 7%) 1.3819
# 47m 7s (- 306m 19s) (4 10%) 1.7213
# 47m 15s (- 307m 13s) (4 14%) 1.8483
# 47m 28s (- 308m 34s) (4 17%) 1.5558
# 47m 39s (- 309m 47s) (4 21%) 1.6962
# 47m 49s (- 310m 52s) (4 24%) 1.5302
# 48m 2s (- 312m 15s) (4 28%) 1.6069
# 48m 10s (- 313m 10s) (4 31%) 1.5447
# 48m 19s (- 314m 6s) (4 35%) 1.6075
# 48m 33s (- 315m 35s) (4 38%) 1.3575
# 48m 43s (- 316m 39s) (4 42%) 1.4220
# 48m 56s (- 318m 10s) (4 45%) 1.1091
# 49m 10s (- 319m 39s) (4 49%) 1.1998
# 49m 20s (- 320m 40s) (4 52%) 1.2987
# 49m 32s (- 321m 59s) (4 56%) 1.3742
# 49m 45s (- 323m 22s) (4 59%) 1.6576
# 49m 56s (- 324m 35s) (4 63%) 1.4426
# 50m 7s (- 325m 47s) (4 66%) 1.5025
# 50m 21s (- 327m 18s) (4 70%) 1.1143
# 50m 29s (- 328m 12s) (4 73%) 1.6071
# 50m 42s (- 329m 36s) (4 77%) 1.4313
# 50m 53s (- 330m 45s) (4 80%) 1.3329
# 51m 3s (- 331m 49s) (4 84%) 1.4176
# 51m 16s (- 333m 15s) (4 88%) 1.3091
# 51m 27s (- 334m 25s) (4 91%) 1.5594
# 51m 38s (- 335m 37s) (4 95%) 1.5736
# 51m 48s (- 336m 43s) (4 98%) 1.3272
# ------------- acc: 0.0
# 60m 40s (- 303m 20s) (5 3%) 1.9261
# 60m 51s (- 304m 17s) (5 7%) 1.3036
# 61m 3s (- 305m 17s) (5 10%) 1.2656
# 61m 13s (- 306m 7s) (5 14%) 1.2014
# 61m 26s (- 307m 10s) (5 17%) 0.9692
# 61m 38s (- 308m 12s) (5 21%) 1.0256
# 61m 51s (- 309m 16s) (5 24%) 1.0069
# 62m 1s (- 310m 6s) (5 28%) 1.0991
# 62m 13s (- 311m 7s) (5 31%) 0.9970
# 62m 24s (- 312m 4s) (5 35%) 1.1996
# 62m 36s (- 313m 0s) (5 38%) 1.1415
# 62m 45s (- 313m 48s) (5 42%) 1.2078
# 62m 55s (- 314m 38s) (5 45%) 1.2594
# 63m 7s (- 315m 37s) (5 49%) 0.9464
# 63m 20s (- 316m 43s) (5 52%) 1.1171
# 63m 31s (- 317m 37s) (5 56%) 1.3435
# 63m 43s (- 318m 37s) (5 59%) 1.6314
# 63m 54s (- 319m 32s) (5 63%) 1.3206
# 64m 6s (- 320m 31s) (5 66%) 1.4974
# 64m 18s (- 321m 32s) (5 70%) 1.6107
# 64m 27s (- 322m 16s) (5 73%) 1.4347
# 64m 42s (- 323m 30s) (5 77%) 1.1108
# 64m 53s (- 324m 25s) (5 80%) 1.2308
# 65m 4s (- 325m 24s) (5 84%) 1.5344
# 65m 14s (- 326m 12s) (5 88%) 1.4332
# 65m 27s (- 327m 17s) (5 91%) 1.3304
# 65m 38s (- 328m 14s) (5 95%) 1.4038
# 65m 49s (- 329m 7s) (5 98%) 1.3711
# ------------- acc: 0.0
# 73m 26s (- 293m 47s) (6 3%) 1.7088
# 73m 36s (- 294m 27s) (6 7%) 1.3428
# 73m 46s (- 295m 5s) (6 10%) 1.5297
# 73m 58s (- 295m 53s) (6 14%) 1.1249
# 74m 9s (- 296m 36s) (6 17%) 1.0979
# 74m 21s (- 297m 26s) (6 21%) 0.8931
# 74m 32s (- 298m 11s) (6 24%) 1.1620
# 74m 42s (- 298m 50s) (6 28%) 1.1210
# 74m 54s (- 299m 38s) (6 31%) 1.2206
# 75m 6s (- 300m 25s) (6 35%) 1.0167
# 75m 19s (- 301m 16s) (6 38%) 1.1144
# 75m 27s (- 301m 50s) (6 42%) 1.1174
# 75m 38s (- 302m 34s) (6 45%) 0.8437
# 75m 48s (- 303m 14s) (6 49%) 1.3020
# 76m 0s (- 304m 0s) (6 52%) 0.9900
# 76m 11s (- 304m 47s) (6 56%) 0.7904
# 76m 23s (- 305m 32s) (6 59%) 1.4519
# 76m 34s (- 306m 19s) (6 63%) 0.9520

# %%
evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
acc = evaluator.evaluate_acc(pairs_test, k_beams=1, verbose=True)

# %%
acc
# Out:
# 0.0

# %%
p = ['Pop Art is an example .', '1', 'art_pop_art10600']
int(p[1])
# Out:
# 1

# %%
train_losses
# Out:
# [tensor(4.2680, device='cuda:0'),
#  tensor(4.3280, device='cuda:0'),
#  tensor(3.2405, device='cuda:0'),
#  tensor(3.0685, device='cuda:0'),
#  tensor(3.4384, device='cuda:0'),
#  tensor(3.1535, device='cuda:0'),
#  tensor(3.4878, device='cuda:0'),
#  tensor(3.2988, device='cuda:0'),
#  tensor(3.5391, device='cuda:0'),
#  tensor(3.2383, device='cuda:0'),
#  tensor(3.5126, device='cuda:0'),
#  tensor(3.6423, device='cuda:0'),
#  tensor(3.3424, device='cuda:0'),
#  tensor(2.8781, device='cuda:0'),
#  tensor(3.3466, device='cuda:0'),
#  tensor(3.3214, device='cuda:0'),
#  tensor(2.6270, device='cuda:0'),
#  tensor(3.1198, device='cuda:0'),
#  tensor(2.9170, device='cuda:0'),
#  tensor(2.9819, device='cuda:0'),
#  tensor(2.7829, device='cuda:0'),
#  tensor(2.6241, device='cuda:0'),
#  tensor(2.6977, device='cuda:0'),
#  tensor(2.3243, device='cuda:0'),
#  tensor(3.0008, device='cuda:0'),
#  tensor(2.7750, device='cuda:0'),
#  tensor(3.4579, device='cuda:0'),
#  tensor(2.9167, device='cuda:0'),
#  tensor(2.5323, device='cuda:0'),
#  tensor(2.8233, device='cuda:0'),
#  tensor(2.3706, device='cuda:0'),
#  tensor(2.4649, device='cuda:0'),
#  tensor(2.4066, device='cuda:0'),
#  tensor(2.7018, device='cuda:0'),
#  tensor(2.5850, device='cuda:0'),
#  tensor(2.2231, device='cuda:0'),
#  tensor(2.4849, device='cuda:0'),
#  tensor(2.7232, device='cuda:0'),
#  tensor(2.4747, device='cuda:0'),
#  tensor(2.4039, device='cuda:0'),
#  tensor(2.3735, device='cuda:0'),
#  tensor(2.4705, device='cuda:0'),
#  tensor(1.9949, device='cuda:0'),
#  tensor(2.4484, device='cuda:0'),
#  tensor(2.5190, device='cuda:0'),
#  tensor(2.4459, device='cuda:0'),
#  tensor(2.2218, device='cuda:0'),
#  tensor(1.9608, device='cuda:0'),
#  tensor(2.2780, device='cuda:0'),
#  tensor(2.3644, device='cuda:0'),
#  tensor(1.7626, device='cuda:0'),
#  tensor(2.1301, device='cuda:0'),
#  tensor(2.3436, device='cuda:0'),
#  tensor(2.3867, device='cuda:0'),
#  tensor(1.8261, device='cuda:0'),
#  tensor(2.2288, device='cuda:0'),
#  tensor(1.7455, device='cuda:0'),
#  tensor(1.9283, device='cuda:0'),
#  tensor(2.0627, device='cuda:0'),
#  tensor(2.0362, device='cuda:0'),
#  tensor(1.7516, device='cuda:0'),
#  tensor(2.0244, device='cuda:0'),
#  tensor(2.3012, device='cuda:0'),
#  tensor(2.0949, device='cuda:0'),
#  tensor(2.1381, device='cuda:0'),
#  tensor(1.7575, device='cuda:0'),
#  tensor(2.2025, device='cuda:0'),
#  tensor(1.9989, device='cuda:0'),
#  tensor(1.5129, device='cuda:0'),
#  tensor(1.6875, device='cuda:0'),
#  tensor(1.7991, device='cuda:0'),
#  tensor(2.3719, device='cuda:0'),
#  tensor(1.9973, device='cuda:0'),
#  tensor(1.6153, device='cuda:0'),
#  tensor(1.8462, device='cuda:0'),
#  tensor(1.9063, device='cuda:0'),
#  tensor(1.3983, device='cuda:0'),
#  tensor(2.0113, device='cuda:0'),
#  tensor(1.9683, device='cuda:0'),
#  tensor(1.9151, device='cuda:0'),
#  tensor(1.8364, device='cuda:0'),
#  tensor(1.7205, device='cuda:0'),
#  tensor(1.6798, device='cuda:0'),
#  tensor(1.4907, device='cuda:0'),
#  tensor(1.6336, device='cuda:0'),
#  tensor(1.7661, device='cuda:0'),
#  tensor(1.5848, device='cuda:0'),
#  tensor(1.7814, device='cuda:0'),
#  tensor(1.7647, device='cuda:0'),
#  tensor(1.3740, device='cuda:0'),
#  tensor(1.5567, device='cuda:0'),
#  tensor(1.3346, device='cuda:0'),
#  tensor(1.4752, device='cuda:0'),
#  tensor(1.7059, device='cuda:0'),
#  tensor(1.9298, device='cuda:0'),
#  tensor(1.8161, device='cuda:0'),
#  tensor(1.7469, device='cuda:0'),
#  tensor(1.5680, device='cuda:0'),
#  tensor(1.5589, device='cuda:0'),
#  tensor(1.7428, device='cuda:0'),
#  tensor(1.6627, device='cuda:0'),
#  tensor(1.5359, device='cuda:0'),
#  tensor(1.6440, device='cuda:0'),
#  tensor(1.4737, device='cuda:0'),
#  tensor(1.8028, device='cuda:0'),
#  tensor(0.8840, device='cuda:0'),
#  tensor(2.0215, device='cuda:0'),
#  tensor(1.7350, device='cuda:0'),
#  tensor(1.3122, device='cuda:0'),
#  tensor(1.6342, device='cuda:0'),
#  tensor(1.4547, device='cuda:0'),
#  tensor(1.5266, device='cuda:0'),
#  tensor(1.4673, device='cuda:0'),
#  tensor(1.2055, device='cuda:0'),
#  tensor(1.7024, device='cuda:0'),
#  tensor(1.3343, device='cuda:0'),
#  tensor(1.4545, device='cuda:0'),
#  tensor(1.2666, device='cuda:0'),
#  tensor(1.4436, device='cuda:0'),
#  tensor(1.2418, device='cuda:0'),
#  tensor(1.2955, device='cuda:0'),
#  tensor(1.5377, device='cuda:0'),
#  tensor(1.6321, device='cuda:0'),
#  tensor(1.1956, device='cuda:0'),
#  tensor(1.2491, device='cuda:0'),
#  tensor(1.6623, device='cuda:0'),
#  tensor(1.3511, device='cuda:0'),
#  tensor(1.4055, device='cuda:0'),
#  tensor(1.5673, device='cuda:0'),
#  tensor(1.2722, device='cuda:0'),
#  tensor(1.2308, device='cuda:0'),
#  tensor(1.0944, device='cuda:0'),
#  tensor(1.4790, device='cuda:0'),
#  tensor(1.6481, device='cuda:0'),
#  tensor(1.3600, device='cuda:0'),
#  tensor(1.3397, device='cuda:0'),
#  tensor(1.0993, device='cuda:0'),
#  tensor(1.2107, device='cuda:0'),
#  tensor(1.4640, device='cuda:0'),
#  tensor(1.7881, device='cuda:0'),
#  tensor(1.6345, device='cuda:0'),
#  tensor(1.1674, device='cuda:0'),
#  tensor(1.4835, device='cuda:0'),
#  tensor(1.6345, device='cuda:0'),
#  tensor(1.0274, device='cuda:0'),
#  tensor(1.7127, device='cuda:0'),
#  tensor(1.0752, device='cuda:0'),
#  tensor(1.0884, device='cuda:0'),
#  tensor(1.4579, device='cuda:0'),
#  tensor(1.1914, device='cuda:0'),
#  tensor(1.0550, device='cuda:0'),
#  tensor(1.2128, device='cuda:0'),
#  tensor(1.2649, device='cuda:0'),
#  tensor(1.5574, device='cuda:0'),
#  tensor(1.1055, device='cuda:0'),
#  tensor(1.2409, device='cuda:0'),
#  tensor(1.4952, device='cuda:0'),
#  tensor(1.3933, device='cuda:0'),
#  tensor(1.1824, device='cuda:0'),
#  tensor(1.0383, device='cuda:0'),
#  tensor(1.3241, device='cuda:0'),
#  tensor(1.0453, device='cuda:0'),
#  tensor(1.0475, device='cuda:0'),
#  tensor(1.5336, device='cuda:0'),
#  tensor(1.1457, device='cuda:0'),
#  tensor(1.3940, device='cuda:0'),
#  tensor(1.0932, device='cuda:0'),
#  tensor(1.1295, device='cuda:0'),
#  tensor(1.3681, device='cuda:0'),
#  tensor(0.8817, device='cuda:0'),
#  tensor(1.4902, device='cuda:0'),
#  tensor(1.0646, device='cuda:0'),
#  tensor(1.0292, device='cuda:0'),
#  tensor(1.5086, device='cuda:0'),
#  tensor(1.1026, device='cuda:0'),
#  tensor(0.9040, device='cuda:0'),
#  tensor(1.3073, device='cuda:0'),
#  tensor(1.2585, device='cuda:0'),
#  tensor(1.4060, device='cuda:0'),
#  tensor(1.3218, device='cuda:0'),
#  tensor(1.3923, device='cuda:0'),
#  tensor(1.1663, device='cuda:0'),
#  tensor(1.1101, device='cuda:0'),
#  tensor(0.9721, device='cuda:0'),
#  tensor(1.3405, device='cuda:0'),
#  tensor(1.1016, device='cuda:0'),
#  tensor(0.9621, device='cuda:0'),
#  tensor(1.0000, device='cuda:0'),
#  tensor(1.0767, device='cuda:0'),
#  tensor(1.4971, device='cuda:0'),
#  tensor(0.9727, device='cuda:0'),
#  tensor(1.0669, device='cuda:0'),
#  tensor(1.5980, device='cuda:0'),
#  tensor(1.5888, device='cuda:0'),
#  tensor(1.2584, device='cuda:0'),
#  tensor(1.0062, device='cuda:0'),
#  tensor(0.9365, device='cuda:0'),
#  tensor(0.8983, device='cuda:0'),
#  tensor(0.9878, device='cuda:0'),
#  tensor(1.5393, device='cuda:0'),
#  tensor(1.4328, device='cuda:0'),
#  tensor(1.6458, device='cuda:0'),
#  tensor(1.3357, device='cuda:0'),
#  tensor(0.9186, device='cuda:0'),
#  tensor(1.1156, device='cuda:0'),
#  tensor(0.7625, device='cuda:0'),
#  tensor(1.4582, device='cuda:0'),
#  tensor(0.9547, device='cuda:0'),
#  tensor(1.1969, device='cuda:0'),
#  tensor(1.4911, device='cuda:0'),
#  tensor(0.8850, device='cuda:0'),
#  tensor(1.0247, device='cuda:0'),
#  tensor(1.3897, device='cuda:0'),
#  tensor(0.8150, device='cuda:0'),
#  tensor(1.3042, device='cuda:0'),
#  tensor(1.3829, device='cuda:0'),
#  tensor(0.8253, device='cuda:0'),
#  tensor(0.9331, device='cuda:0'),
#  tensor(0.8014, device='cuda:0'),
#  tensor(0.8918, device='cuda:0'),
#  tensor(0.8257, device='cuda:0'),
#  tensor(1.1038, device='cuda:0'),
#  tensor(0.8781, device='cuda:0'),
#  tensor(0.9608, device='cuda:0'),
#  tensor(1.1003, device='cuda:0'),
#  tensor(1.3797, device='cuda:0'),
#  tensor(0.9985, device='cuda:0'),
#  tensor(1.3310, device='cuda:0'),
#  tensor(0.7840, device='cuda:0'),
#  tensor(1.3284, device='cuda:0'),
#  tensor(1.1467, device='cuda:0'),
#  tensor(1.1439, device='cuda:0'),
#  tensor(1.0967, device='cuda:0'),
#  tensor(0.9621, device='cuda:0'),
#  tensor(1.4054, device='cuda:0'),
#  tensor(1.3198, device='cuda:0'),
#  tensor(0.9882, device='cuda:0'),
#  tensor(0.7981, device='cuda:0'),
#  tensor(0.8505, device='cuda:0'),
#  tensor(0.8201, device='cuda:0'),
#  tensor(0.9958, device='cuda:0'),
#  tensor(1.3762, device='cuda:0'),
#  tensor(0.8468, device='cuda:0'),
#  tensor(0.7395, device='cuda:0'),
#  tensor(0.8764, device='cuda:0'),
#  tensor(0.9486, device='cuda:0'),
#  tensor(0.8969, device='cuda:0'),
#  tensor(1.2727, device='cuda:0'),
#  tensor(0.7492, device='cuda:0'),
#  tensor(1.1482, device='cuda:0'),
#  tensor(1.0081, device='cuda:0'),
#  tensor(0.7541, device='cuda:0'),
#  tensor(1.2690, device='cuda:0'),
#  tensor(0.7753, device='cuda:0'),
#  tensor(0.8076, device='cuda:0'),
#  tensor(0.9557, device='cuda:0'),
#  tensor(0.7953, device='cuda:0'),
#  tensor(1.3073, device='cuda:0'),
#  tensor(0.8177, device='cuda:0'),
#  tensor(0.7727, device='cuda:0'),
#  tensor(1.1625, device='cuda:0'),
#  tensor(0.8611, device='cuda:0'),
#  tensor(1.2446, device='cuda:0'),
#  tensor(1.1140, device='cuda:0'),
#  tensor(0.8608, device='cuda:0'),
#  tensor(0.8238, device='cuda:0'),
#  tensor(0.7437, device='cuda:0'),
#  tensor(1.1828, device='cuda:0'),
#  tensor(0.8534, device='cuda:0'),
#  tensor(0.7631, device='cuda:0'),
#  tensor(1.1602, device='cuda:0'),
#  tensor(1.0901, device='cuda:0'),
#  tensor(0.8469, device='cuda:0'),
#  tensor(1.0146, device='cuda:0'),
#  tensor(0.8937, device='cuda:0'),
#  tensor(0.7203, device='cuda:0'),
#  tensor(1.5382, device='cuda:0'),
#  tensor(1.0870, device='cuda:0'),
#  tensor(1.1148, device='cuda:0'),
#  tensor(0.8063, device='cuda:0'),
#  tensor(1.3106, device='cuda:0'),
#  tensor(1.3511, device='cuda:0'),
#  tensor(0.8374, device='cuda:0'),
#  tensor(0.7595, device='cuda:0'),
#  tensor(1.1236, device='cuda:0'),
#  tensor(1.2219, device='cuda:0'),
#  tensor(1.0952, device='cuda:0'),
#  tensor(0.9212, device='cuda:0'),
#  tensor(1.2365, device='cuda:0'),
#  tensor(0.8942, device='cuda:0'),
#  tensor(0.8045, device='cuda:0'),
#  tensor(0.7025, device='cuda:0'),
#  tensor(0.7383, device='cuda:0'),
#  tensor(0.7554, device='cuda:0'),
#  tensor(0.7583, device='cuda:0'),
#  tensor(1.2180, device='cuda:0'),
#  tensor(0.9275, device='cuda:0'),
#  tensor(1.3790, device='cuda:0'),
#  tensor(1.1382, device='cuda:0'),
#  tensor(0.8404, device='cuda:0'),
#  tensor(0.8016, device='cuda:0'),
#  tensor(1.2106, device='cuda:0'),
#  tensor(1.1625, device='cuda:0'),
#  tensor(1.1927, device='cuda:0'),
#  tensor(1.0832, device='cuda:0'),
#  tensor(1.1317, device='cuda:0'),
#  tensor(0.8717, device='cuda:0'),
#  tensor(0.8377, device='cuda:0'),
#  tensor(0.9863, device='cuda:0'),
#  tensor(0.8147, device='cuda:0'),
#  tensor(0.8482, device='cuda:0'),
#  tensor(1.2025, device='cuda:0'),
#  tensor(0.8357, device='cuda:0'),
#  tensor(0.7653, device='cuda:0'),
#  tensor(0.7790, device='cuda:0'),
#  tensor(1.1980, device='cuda:0'),
#  tensor(0.8511, device='cuda:0'),
#  tensor(0.7191, device='cuda:0'),
#  tensor(0.8911, device='cuda:0'),
#  tensor(1.2136, device='cuda:0'),
#  tensor(0.5874, device='cuda:0'),
#  tensor(1.0929, device='cuda:0'),
#  tensor(1.2234, device='cuda:0'),
#  tensor(0.7913, device='cuda:0'),
#  tensor(0.6789, device='cuda:0'),
#  tensor(0.7452, device='cuda:0'),
#  tensor(1.3809, device='cuda:0'),
#  tensor(1.1842, device='cuda:0'),
#  tensor(0.6311, device='cuda:0'),
#  tensor(0.7856, device='cuda:0'),
#  tensor(1.1080, device='cuda:0'),
#  tensor(1.0947, device='cuda:0'),
#  tensor(0.8069, device='cuda:0'),
#  tensor(0.7070, device='cuda:0'),
#  tensor(0.7179, device='cuda:0'),
#  tensor(0.6425, device='cuda:0'),
#  tensor(0.6830, device='cuda:0'),
#  tensor(0.7458, device='cuda:0'),
#  tensor(1.0477, device='cuda:0'),
#  tensor(1.0741, device='cuda:0'),
#  tensor(1.3023, device='cuda:0'),
#  tensor(0.7738, device='cuda:0'),
#  tensor(0.7856, device='cuda:0'),
#  tensor(1.1073, device='cuda:0'),
#  tensor(0.7515, device='cuda:0'),
#  tensor(0.7288, device='cuda:0'),
#  tensor(1.2133, device='cuda:0'),
#  tensor(1.1008, device='cuda:0'),
#  tensor(0.6686, device='cuda:0'),
#  tensor(1.0257, device='cuda:0'),
#  tensor(0.8075, device='cuda:0'),
#  tensor(1.0336, device='cuda:0'),
#  tensor(0.9321, device='cuda:0'),
#  tensor(0.8048, device='cuda:0'),
#  tensor(0.8962, device='cuda:0'),
#  tensor(1.0996, device='cuda:0'),
#  tensor(1.2652, device='cuda:0'),
#  tensor(0.6909, device='cuda:0'),
#  tensor(0.6423, device='cuda:0'),
#  tensor(1.2245, device='cuda:0'),
#  tensor(0.7236, device='cuda:0'),
#  tensor(1.0200, device='cuda:0'),
#  tensor(1.2510, device='cuda:0'),
#  tensor(1.1157, device='cuda:0'),
#  tensor(1.0917, device='cuda:0'),
#  tensor(1.1274, device='cuda:0'),
#  tensor(0.6404, device='cuda:0'),
#  tensor(1.0979, device='cuda:0'),
#  tensor(0.6745, device='cuda:0'),
#  tensor(1.1640, device='cuda:0'),
#  tensor(0.7852, device='cuda:0'),
#  tensor(0.7190, device='cuda:0'),
#  tensor(1.0256, device='cuda:0'),
#  tensor(0.6716, device='cuda:0'),
#  tensor(0.5348, device='cuda:0'),
#  tensor(1.0811, device='cuda:0'),
#  tensor(1.0822, device='cuda:0'),
#  tensor(0.6989, device='cuda:0'),
#  tensor(1.0576, device='cuda:0'),
#  tensor(1.2317, device='cuda:0'),
#  tensor(0.8131, device='cuda:0'),
#  tensor(0.7088, device='cuda:0'),
#  tensor(0.6147, device='cuda:0'),
#  tensor(1.3182, device='cuda:0'),
#  tensor(0.7258, device='cuda:0'),
#  tensor(0.6433, device='cuda:0'),
#  tensor(0.8714, device='cuda:0'),
#  tensor(1.0774, device='cuda:0'),
#  tensor(0.6152, device='cuda:0'),
#  tensor(0.6890, device='cuda:0'),
#  tensor(0.7072, device='cuda:0'),
#  tensor(1.1540, device='cuda:0'),
#  tensor(0.7034, device='cuda:0'),
#  tensor(0.6445, device='cuda:0'),
#  tensor(0.4555, device='cuda:0'),
#  tensor(0.6260, device='cuda:0'),
#  tensor(1.0001, device='cuda:0'),
#  tensor(1.0049, device='cuda:0'),
#  tensor(1.0335, device='cuda:0'),
#  tensor(0.6447, device='cuda:0'),
#  tensor(0.6810, device='cuda:0'),
#  tensor(0.7880, device='cuda:0'),
#  tensor(0.9039, device='cuda:0'),
#  tensor(1.0812, device='cuda:0'),
#  tensor(0.9974, device='cuda:0'),
#  tensor(0.6733, device='cuda:0'),
#  tensor(0.9236, device='cuda:0'),
#  tensor(1.0404, device='cuda:0'),
#  tensor(0.9645, device='cuda:0'),
#  tensor(0.6182, device='cuda:0'),
#  tensor(1.1230, device='cuda:0'),
#  tensor(0.9361, device='cuda:0'),
#  tensor(0.7644, device='cuda:0'),
#  tensor(0.9731, device='cuda:0'),
#  tensor(1.0740, device='cuda:0'),
#  tensor(0.5819, device='cuda:0'),
#  tensor(0.7014, device='cuda:0'),
#  tensor(0.4847, device='cuda:0'),
#  tensor(0.9166, device='cuda:0'),
#  tensor(1.1045, device='cuda:0'),
#  tensor(1.1824, device='cuda:0'),
#  tensor(1.0011, device='cuda:0'),
#  tensor(0.8235, device='cuda:0'),
#  tensor(0.6542, device='cuda:0'),
#  tensor(0.9415, device='cuda:0'),
#  tensor(0.8795, device='cuda:0'),
#  tensor(1.0256, device='cuda:0'),
#  tensor(1.0585, device='cuda:0'),
#  tensor(0.6922, device='cuda:0'),
#  tensor(1.0605, device='cuda:0'),
#  tensor(0.5735, device='cuda:0'),
#  tensor(0.7083, device='cuda:0'),
#  tensor(0.6357, device='cuda:0'),
#  tensor(0.6507, device='cuda:0'),
#  tensor(0.4028, device='cuda:0'),
#  tensor(0.9657, device='cuda:0'),
#  tensor(0.6165, device='cuda:0'),
#  tensor(0.8376, device='cuda:0'),
#  tensor(0.9096, device='cuda:0'),
#  tensor(0.6009, device='cuda:0'),
#  tensor(1.0836, device='cuda:0'),
#  tensor(0.6010, device='cuda:0'),
#  tensor(0.8669, device='cuda:0'),
#  tensor(0.5599, device='cuda:0'),
#  tensor(0.5512, device='cuda:0'),
#  tensor(0.6147, device='cuda:0'),
#  tensor(0.5210, device='cuda:0'),
#  tensor(0.6333, device='cuda:0'),
#  tensor(1.0813, device='cuda:0'),
#  tensor(0.7647, device='cuda:0'),
#  tensor(0.9923, device='cuda:0'),
#  tensor(1.0641, device='cuda:0'),
#  tensor(0.5759, device='cuda:0'),
#  tensor(0.5394, device='cuda:0'),
#  tensor(0.5855, device='cuda:0'),
#  tensor(1.1438, device='cuda:0'),
#  tensor(0.5626, device='cuda:0'),
#  tensor(0.5743, device='cuda:0'),
#  tensor(0.9740, device='cuda:0'),
#  tensor(1.0377, device='cuda:0'),
#  tensor(0.6329, device='cuda:0'),
#  tensor(0.4952, device='cuda:0'),
#  tensor(0.6339, device='cuda:0'),
#  tensor(1.0624, device='cuda:0'),
#  tensor(0.5041, device='cuda:0'),
#  tensor(0.9655, device='cuda:0'),
#  tensor(1.1852, device='cuda:0'),
#  tensor(0.9594, device='cuda:0'),
#  tensor(0.9483, device='cuda:0'),
#  tensor(1.0832, device='cuda:0'),
#  tensor(0.4759, device='cuda:0'),
#  tensor(0.9332, device='cuda:0'),
#  tensor(0.9905, device='cuda:0'),
#  tensor(1.0608, device='cuda:0'),
#  tensor(0.5303, device='cuda:0'),
#  tensor(0.7618, device='cuda:0'),
#  tensor(0.5948, device='cuda:0'),
#  tensor(0.5648, device='cuda:0'),
#  tensor(0.9775, device='cuda:0'),
#  tensor(0.9548, device='cuda:0'),
#  tensor(0.5429, device='cuda:0'),
#  tensor(1.0446, device='cuda:0'),
#  tensor(0.5835, device='cuda:0'),
#  tensor(0.6211, device='cuda:0'),
#  tensor(0.9013, device='cuda:0'),
#  tensor(0.8929, device='cuda:0'),
#  tensor(0.8862, device='cuda:0'),
#  tensor(0.5083, device='cuda:0'),
#  tensor(0.9922, device='cuda:0'),
#  tensor(0.6408, device='cuda:0'),
#  tensor(0.4975, device='cuda:0'),
#  tensor(0.8957, device='cuda:0'),
#  tensor(0.5546, device='cuda:0'),
#  tensor(0.9417, device='cuda:0'),
#  tensor(0.5646, device='cuda:0'),
#  tensor(0.6202, device='cuda:0'),
#  tensor(0.6036, device='cuda:0'),
#  tensor(0.8725, device='cuda:0'),
#  tensor(0.5905, device='cuda:0'),
#  tensor(0.5066, device='cuda:0'),
#  tensor(0.6308, device='cuda:0'),
#  tensor(0.9765, device='cuda:0'),
#  tensor(1.0762, device='cuda:0'),
#  tensor(0.5165, device='cuda:0'),
#  tensor(0.9172, device='cuda:0'),
#  tensor(1.0253, device='cuda:0'),
#  tensor(0.7778, device='cuda:0'),
#  tensor(0.6120, device='cuda:0'),
#  tensor(0.5361, device='cuda:0'),
#  tensor(0.5379, device='cuda:0'),
#  tensor(0.9199, device='cuda:0'),
#  tensor(0.7296, device='cuda:0'),
#  tensor(0.9578, device='cuda:0'),
#  tensor(0.9667, device='cuda:0'),
#  tensor(0.9080, device='cuda:0'),
#  tensor(0.6144, device='cuda:0'),
#  tensor(0.5534, device='cuda:0'),
#  tensor(0.5322, device='cuda:0'),
#  tensor(0.5185, device='cuda:0'),
#  tensor(0.7444, device='cuda:0'),
#  tensor(1.0187, device='cuda:0'),
#  tensor(0.5586, device='cuda:0'),
#  tensor(0.7838, device='cuda:0'),
#  tensor(0.5804, device='cuda:0'),
#  tensor(0.9537, device='cuda:0'),
#  tensor(0.5147, device='cuda:0'),
#  tensor(0.5337, device='cuda:0'),
#  tensor(0.5625, device='cuda:0'),
#  tensor(0.9698, device='cuda:0'),
#  tensor(0.4954, device='cuda:0'),
#  tensor(0.5629, device='cuda:0'),
#  tensor(0.8326, device='cuda:0'),
#  tensor(0.7733, device='cuda:0'),
#  tensor(0.6243, device='cuda:0'),
#  tensor(0.9056, device='cuda:0'),
#  tensor(0.8124, device='cuda:0'),
#  tensor(0.9853, device='cuda:0'),
#  tensor(0.4957, device='cuda:0'),
#  tensor(1.0369, device='cuda:0'),
#  tensor(0.6224, device='cuda:0'),
#  tensor(0.9582, device='cuda:0'),
#  tensor(0.7029, device='cuda:0'),
#  tensor(0.5956, device='cuda:0'),
#  tensor(0.8031, device='cuda:0'),
#  tensor(0.8619, device='cuda:0'),
#  tensor(0.5804, device='cuda:0'),
#  tensor(0.9044, device='cuda:0'),
#  tensor(0.5443, device='cuda:0'),
#  tensor(0.4905, device='cuda:0'),
#  tensor(0.4652, device='cuda:0'),
#  tensor(0.5822, device='cuda:0'),
#  tensor(0.9385, device='cuda:0'),
#  tensor(0.5150, device='cuda:0'),
#  tensor(0.7395, device='cuda:0'),
#  tensor(0.8390, device='cuda:0'),
#  tensor(0.4830, device='cuda:0'),
#  tensor(0.5893, device='cuda:0'),
#  tensor(0.9815, device='cuda:0'),
#  tensor(0.9531, device='cuda:0'),
#  tensor(0.5789, device='cuda:0'),
#  tensor(0.5833, device='cuda:0'),
#  tensor(0.8114, device='cuda:0'),
#  tensor(0.5035, device='cuda:0'),
#  tensor(0.5676, device='cuda:0'),
#  tensor(0.8318, device='cuda:0'),
#  tensor(0.4995, device='cuda:0'),
#  tensor(0.4829, device='cuda:0'),
#  tensor(0.5145, device='cuda:0'),
#  tensor(1.0189, device='cuda:0'),
#  tensor(0.5299, device='cuda:0'),
#  tensor(0.9290, device='cuda:0'),
#  tensor(0.8129, device='cuda:0'),
#  tensor(0.5886, device='cuda:0'),
#  tensor(0.8543, device='cuda:0'),
#  tensor(0.9219, device='cuda:0'),
#  tensor(0.9576, device='cuda:0'),
#  tensor(0.7633, device='cuda:0'),
#  tensor(0.4572, device='cuda:0'),
#  tensor(0.9063, device='cuda:0'),
#  tensor(0.8265, device='cuda:0'),
#  tensor(0.6411, device='cuda:0'),
#  tensor(1.1223, device='cuda:0'),
#  tensor(0.8263, device='cuda:0'),
#  tensor(0.5752, device='cuda:0'),
#  tensor(1.1095, device='cuda:0'),
#  tensor(0.7357, device='cuda:0'),
#  tensor(0.8798, device='cuda:0'),
#  tensor(0.4264, device='cuda:0'),
#  tensor(0.8638, device='cuda:0'),
#  tensor(0.5241, device='cuda:0'),
#  tensor(0.5116, device='cuda:0'),
#  tensor(0.8817, device='cuda:0'),
#  tensor(0.5531, device='cuda:0'),
#  tensor(1.0022, device='cuda:0'),
#  tensor(0.7128, device='cuda:0'),
#  tensor(0.4693, device='cuda:0'),
#  tensor(0.9243, device='cuda:0'),
#  tensor(0.8989, device='cuda:0'),
#  tensor(0.6997, device='cuda:0'),
#  tensor(0.8095, device='cuda:0'),
#  tensor(0.5308, device='cuda:0'),
#  tensor(0.4340, device='cuda:0'),
#  tensor(0.3584, device='cuda:0'),
#  tensor(0.9664, device='cuda:0'),
#  tensor(0.3412, device='cuda:0'),
#  tensor(0.5240, device='cuda:0'),
#  tensor(0.5329, device='cuda:0'),
#  tensor(0.4273, device='cuda:0'),
#  tensor(0.5856, device='cuda:0'),
#  tensor(0.3808, device='cuda:0'),
#  tensor(0.8015, device='cuda:0'),
#  tensor(0.9953, device='cuda:0'),
#  tensor(0.7930, device='cuda:0'),
#  tensor(0.6986, device='cuda:0'),
#  tensor(0.5631, device='cuda:0'),
#  tensor(0.7961, device='cuda:0'),
#  tensor(0.8374, device='cuda:0'),
#  tensor(0.7873, device='cuda:0'),
#  tensor(0.7898, device='cuda:0'),
#  tensor(0.5014, device='cuda:0'),
#  tensor(0.4504, device='cuda:0'),
#  tensor(0.5903, device='cuda:0'),
#  tensor(0.6744, device='cuda:0'),
#  tensor(0.9054, device='cuda:0'),
#  tensor(0.4990, device='cuda:0'),
#  tensor(0.7856, device='cuda:0'),
#  tensor(0.7423, device='cuda:0'),
#  tensor(0.4513, device='cuda:0'),
#  tensor(0.4837, device='cuda:0'),
#  tensor(0.8947, device='cuda:0'),
#  tensor(0.7433, device='cuda:0'),
#  tensor(0.5731, device='cuda:0'),
#  tensor(0.9257, device='cuda:0'),
#  tensor(0.7649, device='cuda:0'),
#  tensor(0.3677, device='cuda:0'),
#  tensor(0.4112, device='cuda:0'),
#  tensor(0.9027, device='cuda:0'),
#  tensor(0.4951, device='cuda:0'),
#  tensor(1.1037, device='cuda:0'),
#  tensor(0.5353, device='cuda:0'),
#  tensor(0.4625, device='cuda:0'),
#  tensor(0.9323, device='cuda:0'),
#  tensor(0.4143, device='cuda:0'),
#  tensor(0.8125, device='cuda:0'),
#  tensor(0.5112, device='cuda:0'),
#  tensor(0.7576, device='cuda:0'),
#  tensor(0.8898, device='cuda:0'),
#  tensor(0.7460, device='cuda:0'),
#  tensor(0.3945, device='cuda:0'),
#  tensor(0.5121, device='cuda:0'),
#  tensor(0.5061, device='cuda:0'),
#  tensor(0.6987, device='cuda:0'),
#  tensor(0.8296, device='cuda:0'),
#  tensor(0.8097, device='cuda:0'),
#  tensor(0.6954, device='cuda:0'),
#  tensor(0.4615, device='cuda:0'),
#  tensor(0.4249, device='cuda:0'),
#  tensor(0.8016, device='cuda:0'),
#  tensor(0.4057, device='cuda:0'),
#  tensor(0.5357, device='cuda:0'),
#  tensor(0.4724, device='cuda:0'),
#  tensor(0.5041, device='cuda:0'),
#  tensor(0.7559, device='cuda:0'),
#  tensor(0.9230, device='cuda:0'),
#  tensor(0.9265, device='cuda:0'),
#  tensor(0.4495, device='cuda:0'),
#  tensor(0.4115, device='cuda:0'),
#  tensor(0.8146, device='cuda:0'),
#  tensor(0.6472, device='cuda:0'),
#  tensor(0.4545, device='cuda:0'),
#  tensor(0.8127, device='cuda:0'),
#  tensor(0.8126, device='cuda:0'),
#  tensor(0.6314, device='cuda:0'),
#  tensor(0.6090, device='cuda:0'),
#  tensor(0.8086, device='cuda:0'),
#  tensor(0.3792, device='cuda:0'),
#  tensor(0.7517, device='cuda:0'),
#  tensor(0.4558, device='cuda:0'),
#  tensor(0.4582, device='cuda:0'),
#  tensor(0.4767, device='cuda:0'),
#  tensor(0.5445, device='cuda:0'),
#  tensor(0.4146, device='cuda:0'),
#  tensor(0.8721, device='cuda:0'),
#  tensor(0.3379, device='cuda:0'),
#  tensor(0.4369, device='cuda:0'),
#  tensor(0.4160, device='cuda:0'),
#  tensor(0.9546, device='cuda:0'),
#  tensor(0.7398, device='cuda:0'),
#  tensor(0.8882, device='cuda:0'),
#  tensor(0.4526, device='cuda:0'),
#  tensor(0.6771, device='cuda:0'),
#  tensor(0.4437, device='cuda:0'),
#  tensor(0.4104, device='cuda:0'),
#  tensor(0.4963, device='cuda:0'),
#  tensor(0.4220, device='cuda:0'),
#  tensor(0.4528, device='cuda:0'),
#  tensor(0.8301, device='cuda:0'),
#  tensor(0.4118, device='cuda:0'),
#  tensor(0.7104, device='cuda:0'),
#  tensor(0.4590, device='cuda:0')]

# %%
evaluator = Evaluator(encoder, decoder, input_lang, output_lang, 
                      MAX_LENGTH, USE_CUDA)
candidates, references = evaluator.get_candidates_and_references(pairs_test[:10000], k_beams=2)
len(candidates), len(references)
# Out:
# A Jupyter Widget

# %%
BLEU(candidates, [references])
# Out:
# (0.28063523097173265,
#  [0.6573135078342698,
#   0.37567686039915427,
#   0.22488307382629802,
#   0.13494545201862276],
#  0.953820572858132)
