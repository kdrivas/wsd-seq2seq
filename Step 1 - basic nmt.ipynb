# %%
from data import generate_batches
from data import prepare_data

from model.encoder import Encoder
from model.decoder import Decoder_luong

from BLEU import BLEU

from utils import time_since


from evaluator_dis import Evaluator

import torch
import torch.nn as nn
from torch.nn import functional
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

import numpy as np
import time
import random
import os
#from validation import Evaluator

# %load_ext autoreload
# %autoreload 2

# %%
USE_CUDA = True
MAX_LENGTH = 100
DIR_FILES = 'data/disambiguation/sense-eval2/'
DIR_TRAIN = os.path.join(DIR_FILES, 'train')
DIR_TEST = os.path.join(DIR_FILES, 'test')
DIR_RESULTS = 'results/step_1'
SPLIT_TRAIN = 0.7
SPLIT_VALID = 0.15
# The rest is for test

# %% [markdown]
# # Reading the data

# %%
input_lang, output_lang, pairs_train, pairs_test= prepare_data(max_length=MAX_LENGTH, dir_train=DIR_TRAIN, dir_test=DIR_TEST)
# Out:
# Reading lines...
# Read 9080 train pairs
# Read 4151 test pairs
# Filtered to 9058 pairs
# Creating vocab...
# Indexed 28967 words in input language, 23810 words in output

# %%
pairs_train = np.array(pairs_train)

# %% [markdown]
# # Train

# %%
def train(input_batches, target_batches, \
          encoder, decoder, encoder_optimizer, decoder_optimzier, \
          criterion, max_length=MAX_LENGTH, train=True):
    
    if train:
        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()
        
    loss = 0
    
    batch_size = input_batches.size()[1]
    
    encoder_hidden = encoder.init_hidden(batch_size)
    encoder_outputs, encoder_hidden = encoder(input_batches, encoder_hidden)
    
    decoder_context = Variable(torch.zeros(batch_size, decoder.hidden_size))   
    decoder_hidden = encoder_hidden
    
    # set the start of the sentences of the batch
    decoder_input = Variable(torch.LongTensor([input_lang.vocab.stoi['<sos>']] * batch_size))

    # store the decoder outputs to estimate the loss
    all_decoder_outputs = Variable(torch.zeros(target_batches.size()[0], batch_size, len(output_lang.vocab.stoi)))
    
    if USE_CUDA:
        decoder_input = decoder_input.cuda()
        all_decoder_outputs = all_decoder_outputs.cuda()
        decoder_context = decoder_context.cuda()  
    
    if train:
        use_teacher_forcing = random.random() < teacher_forcing_ratio
    else:
        use_teacher_forcing = False

    if use_teacher_forcing:        
        # Use targets as inputs
        for di in range(target_batches.shape[0]):
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
                decoder_input.unsqueeze(0), decoder_context, decoder_hidden, encoder_outputs)

            all_decoder_outputs[di] = decoder_output
            decoder_input = target_batches[di]
    else:        
        # Use decoder output as inputs
        for di in range(target_batches.shape[0]):            
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
                decoder_input.unsqueeze(0), decoder_context, decoder_hidden, encoder_outputs) 

            all_decoder_outputs[di] = decoder_output
            
            # Greedy approach, take the word with highest probability
            topv, topi = decoder_output.data.topk(1)            
            decoder_input = Variable(torch.LongTensor(topi.cpu()).squeeze())
            if USE_CUDA: decoder_input = decoder_input.cuda()
    
    loss = nn.NLLLoss()(all_decoder_outputs.view(-1, decoder.output_size), target_batches.contiguous().view(-1))          
    
    if train:
        loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
        torch.nn.utils.clip_grad_norm_(decoder.parameters(), clip)
        encoder_optimizer.step()
        decoder_optimizer.step()
    
    return loss.item()

# %% [markdown]
# # Model

# %%
attn_model = 'general'
hidden_size = 512
emb_size = 300
n_layers = 2
seed = 12
dropout_p = 0.2
teacher_forcing_ratio = 0.5
clip = 5.0

n_epochs = 40
batch_size = 100

# %%
torch.manual_seed(seed)
np.random.seed(seed)

# %%
encoder = Encoder(len(input_lang.vocab.stoi), hidden_size, emb_size, n_layers, dropout_p, USE_CUDA=USE_CUDA)
decoder = Decoder_luong(attn_model, hidden_size, len(output_lang.vocab.stoi), emb_size, 2 * n_layers, dropout_p, USE_CUDA=USE_CUDA)

if USE_CUDA:
    encoder = encoder.cuda()
    decoder = decoder.cuda()
    
learning_rate = 0.001
encoder_optimizer = optim.Adam(encoder.parameters())
decoder_optimizer = optim.Adam(decoder.parameters())
criterion = nn.NLLLoss()

# %%
# Keep track of time elapsed and running averages
start = time.time()
train_losses = []
validation_losses = []
validation_acc = []

plot_every = 5
start_eval = 15
print_every = 5
validate_loss_every = 25
best_acc = 0
print_loss_total = 0 # Reset every print_every
plot_loss_total = 0 # Reset every plot_every

# %%
for epoch in range(1, n_epochs): 
    # Shuffle data
    id_aux = np.random.permutation(np.arange(len(pairs_train)))
    pairs_train = pairs_train[id_aux]
    
    # Get the batches for this epoch
    input_batches, target_batches = generate_batches(input_lang, output_lang, batch_size, pairs_train, USE_CUDA=USE_CUDA)
    print_loss_total = 0
    
    for batch_ix, (input_var, target_var) in enumerate(zip(input_batches, target_batches)):
        encoder.train()
        decoder.train()

        #[input_var, _, _, _, _, _, _, _] = input_batch

        # Run the train function
        loss = train(input_var, target_var,\
                 encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, 
                 max_length=MAX_LENGTH, train=True)
        #loss = train_luong(input_var, target_var, input_var.size(1), True)
            
        torch.cuda.empty_cache()

        # Keep track of loss
        print_loss_total += loss
        plot_loss_total += loss

        if batch_ix == 0: continue

        if batch_ix % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print_summary = '%s (%d %d%%) %.4f' % (time_since(start, epoch / n_epochs), epoch, batch_ix / len(input_batches) * 100, print_loss_avg)
            train_losses.append(loss)
            print(print_summary)
    
    #input_batches, target_batches = generate_batches(input_lang, output_lang, batch_size, pairs_test, USE_CUDA=USE_CUDA)
    #print_loss_total = 0
    encoder.eval()
    decoder.eval()
    #for input_batch, target_var in zip(input_batches, target_batches):
    
    #    encoder.eval()
    #    decoder.eval()
    
    #    #[input_var, _, _, _, _, _, _, _] = input_batch
    #    input_var = input_batch
    #    # Run the train function
    #    loss = train(input_var, target_var,\
    #             encoder, decoder, encoder_optimizer, decoder_optimizer, criterion,\
    #             max_length=MAX_LENGTH, train=False)
        
    #    print_loss_total += loss
    #val_loss = print_loss_total / len(input_batches)
    #validation_losses.append(val_loss)
    # Evaluating acc
    if epoch > start_eval:
        evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
        acc = evaluator.evaluate_acc(pairs_test, k_beams=1)
        if acc > best_acc:
            best_acc = acc
            torch.save(encoder.state_dict(), f'{DIR_RESULTS}/encoder.pkl')
            torch.save(decoder.state_dict(), f'{DIR_RESULTS}/decoder.pkl')
            print('Saving weights')
        validation_acc.append(acc)
        print(f'------------- acc: {acc}')

        # Prevent overflow gpu memory
        del evaluator
# Out:
# /home/krivas/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 0m 8s (- 5m 17s) (1 5%) 6.3810
# 0m 13s (- 8m 39s) (1 10%) 3.7557
# 0m 18s (- 12m 0s) (1 16%) 4.7232
# 0m 23s (- 15m 1s) (1 21%) 3.6604
# 0m 27s (- 17m 53s) (1 27%) 3.3066
# 0m 32s (- 21m 21s) (1 32%) 2.9788
# 0m 39s (- 25m 29s) (1 38%) 2.7311
# 0m 43s (- 28m 18s) (1 43%) 3.6644
# 0m 48s (- 31m 20s) (1 49%) 3.0944
# 0m 53s (- 34m 33s) (1 54%) 3.0938
# 0m 57s (- 37m 40s) (1 60%) 3.1346
# 1m 2s (- 40m 30s) (1 65%) 3.1511
# 1m 7s (- 44m 0s) (1 71%) 2.7032
# 1m 12s (- 47m 18s) (1 76%) 2.7951
# 1m 17s (- 50m 12s) (1 82%) 3.0322
# 1m 22s (- 53m 19s) (1 87%) 2.8750
# 1m 26s (- 56m 32s) (1 93%) 2.6936
# 1m 30s (- 59m 0s) (1 98%) 3.0109
# 1m 37s (- 30m 51s) (2 5%) 3.0260
# 1m 42s (- 32m 26s) (2 10%) 2.5431
# 1m 47s (- 33m 56s) (2 16%) 2.8300
# 1m 51s (- 35m 12s) (2 21%) 2.8959
# 1m 55s (- 36m 38s) (2 27%) 2.7332
# 2m 0s (- 38m 5s) (2 32%) 2.8308
# 2m 5s (- 39m 42s) (2 38%) 2.5709
# 2m 10s (- 41m 14s) (2 43%) 2.6037
# 2m 15s (- 43m 2s) (2 49%) 2.2764
# 2m 20s (- 44m 34s) (2 54%) 2.9316
# 2m 25s (- 46m 9s) (2 60%) 2.5993
# 2m 30s (- 47m 33s) (2 65%) 3.0760
# 2m 34s (- 49m 4s) (2 71%) 2.9224
# 2m 40s (- 50m 48s) (2 76%) 2.6046
# 2m 45s (- 52m 21s) (2 82%) 2.9333
# 2m 51s (- 54m 10s) (2 87%) 2.4470
# 2m 56s (- 55m 48s) (2 93%) 2.6495
# 3m 1s (- 57m 22s) (2 98%) 2.5967
# 3m 8s (- 38m 46s) (3 5%) 2.9387
# 3m 13s (- 39m 44s) (3 10%) 2.5949
# 3m 17s (- 40m 41s) (3 16%) 2.8089
# 3m 23s (- 41m 46s) (3 21%) 2.5051
# 3m 28s (- 42m 46s) (3 27%) 2.6052
# 3m 32s (- 43m 46s) (3 32%) 2.6371
# 3m 37s (- 44m 37s) (3 38%) 2.8616
# 3m 42s (- 45m 40s) (3 43%) 2.5476
# 3m 47s (- 46m 48s) (3 49%) 2.3160
# 3m 52s (- 47m 45s) (3 54%) 2.6348
# 3m 57s (- 48m 44s) (3 60%) 2.7491
# 4m 1s (- 49m 37s) (3 65%) 2.7473
# 4m 7s (- 50m 50s) (3 71%) 2.3028
# 4m 13s (- 52m 2s) (3 76%) 2.2266
# 4m 17s (- 52m 57s) (3 82%) 2.7483
# 4m 21s (- 53m 49s) (3 87%) 2.9375
# 4m 26s (- 54m 52s) (3 93%) 2.5439
# 4m 31s (- 55m 50s) (3 98%) 2.6871
# 4m 38s (- 41m 46s) (4 5%) 2.8892
# 4m 43s (- 42m 30s) (4 10%) 2.4369
# 4m 47s (- 43m 10s) (4 16%) 2.6390
# 4m 52s (- 43m 53s) (4 21%) 2.5755
# 4m 56s (- 44m 31s) (4 27%) 2.7889
# 5m 1s (- 45m 17s) (4 32%) 2.4446
# 5m 6s (- 46m 1s) (4 38%) 2.4259
# 5m 11s (- 46m 45s) (4 43%) 2.4684
# 5m 16s (- 47m 29s) (4 49%) 2.3166
# 5m 22s (- 48m 21s) (4 54%) 2.1811
# 5m 27s (- 49m 10s) (4 60%) 2.6825
# 5m 32s (- 49m 56s) (4 65%) 2.5073
# 5m 37s (- 50m 39s) (4 71%) 2.6509
# 5m 42s (- 51m 23s) (4 76%) 2.5579
# 5m 47s (- 52m 9s) (4 82%) 2.4092
# 5m 51s (- 52m 47s) (4 87%) 2.5882
# 5m 56s (- 53m 30s) (4 93%) 2.4290
# 6m 1s (- 54m 13s) (4 98%) 2.7371
# 6m 8s (- 43m 2s) (5 5%) 3.1637
# 6m 13s (- 43m 37s) (5 10%) 2.7015
# 6m 18s (- 44m 9s) (5 16%) 2.5533
# 6m 23s (- 44m 42s) (5 21%) 2.5078
# 6m 28s (- 45m 22s) (5 27%) 2.1049
# 6m 33s (- 45m 57s) (5 32%) 2.4965
# 6m 38s (- 46m 32s) (5 38%) 2.3667
# 6m 44s (- 47m 8s) (5 43%) 2.4018
# 6m 48s (- 47m 41s) (5 49%) 2.4414
# 6m 53s (- 48m 16s) (5 54%) 2.2969
# 6m 58s (- 48m 52s) (5 60%) 2.2260
# 7m 4s (- 49m 28s) (5 65%) 2.1361
# 7m 9s (- 50m 3s) (5 71%) 2.2547
# 7m 13s (- 50m 36s) (5 76%) 2.3310
# 7m 18s (- 51m 11s) (5 82%) 2.2679
# 7m 23s (- 51m 41s) (5 87%) 2.4626
# 7m 27s (- 52m 14s) (5 93%) 2.2924
# 7m 32s (- 52m 48s) (5 98%) 2.2809
# 7m 39s (- 43m 26s) (6 5%) 2.2487
# 7m 44s (- 43m 53s) (6 10%) 2.2904
# 7m 49s (- 44m 19s) (6 16%) 2.2007
# 7m 54s (- 44m 46s) (6 21%) 2.2396
# 7m 58s (- 45m 13s) (6 27%) 2.1743
# 8m 3s (- 45m 42s) (6 32%) 1.9311
# 8m 8s (- 46m 10s) (6 38%) 2.0682
# 8m 14s (- 46m 40s) (6 43%) 1.9959
# 8m 18s (- 47m 6s) (6 49%) 2.1158
# 8m 23s (- 47m 34s) (6 54%) 2.1087
# 8m 28s (- 48m 1s) (6 60%) 2.0822
# 8m 33s (- 48m 32s) (6 65%) 2.0371
# 8m 39s (- 49m 2s) (6 71%) 2.0537
# 8m 44s (- 49m 29s) (6 76%) 2.2542
# 8m 50s (- 50m 3s) (6 82%) 1.9549
# 8m 55s (- 50m 34s) (6 87%) 2.1156
# 8m 59s (- 50m 59s) (6 93%) 2.5434
# 9m 4s (- 51m 23s) (6 98%) 2.5894
# 9m 10s (- 43m 13s) (7 5%) 2.7576
# 9m 15s (- 43m 37s) (7 10%) 2.2352
# 9m 19s (- 43m 58s) (7 16%) 2.0045
# 9m 24s (- 44m 19s) (7 21%) 2.1966
# 9m 28s (- 44m 42s) (7 27%) 2.0798
# 9m 33s (- 45m 4s) (7 32%) 1.9127
# 9m 38s (- 45m 27s) (7 38%) 1.9657
# 9m 43s (- 45m 52s) (7 43%) 1.9422

# %%
evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
acc = evaluator.evaluate_acc(pairs_test, k_beams=3, verbose=True)
# Out:
# /home/krivas/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# ['pop', 'art_art10600', 'is', 'an', 'example', '.', '<eos>']
# ----- ID
# 0
# ----- tokens input
# pop art is an example .
# ----- output predecido
# pop art_art10600 is an example . <eos>
# ----- respuesta
# ['art_pop_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['reform', 'and', 'alan', 'arts', 'funding', 'and', 'organisation', '.', '<eos>']
# ----- ID
# 1
# ----- tokens input
# reform and decentralise arts funding and organisation .
# ----- output predecido
# reform and alan arts funding and organisation . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['you', 'you', 'notice', 'how', 'all', 'art_art10600', 'on', 'on', 'people', 'in', 'trouble', '.', '<eos>']
# ----- ID
# 2
# ----- tokens input
# you ever notice how all art focuses on people in trouble .
# ----- output predecido
# you you notice how all art_art10600 on on people in trouble . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  1   --- acc: 0.0002409058058299205
# ['search', 'books', 'and', 'classes', 'teach', 'the', 'art_art10900', 'of', 'orthodox', 'oneself', 'and', ',', 'if', 'you', 'want', 'to', 'know', 'more', ',', 'turn', 'to', 'page', ',', '.', '<eos>']
# ----- ID
# 3
# ----- tokens input
# countless books and classes teach the art of asserting oneself and , if you want to know more , turn to page 120 .
# ----- output predecido
# search books and classes teach the art_art10900 of orthodox oneself and , if you want to know more , turn to page , . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  2   --- acc: 0.000481811611659841
# ['individual', 'your', 'usual', 'dominated', ',', 'who', 'probably', 'wo', "n't", 'have', 'the', 'room', 'or', 'the', 'reason', 'for', 'for', 'unusual', 'papers', 'or', ',', 'go', 'to', 'a', 'specialist', 'art', 'or', 'paper', 'shop', 'instead', ',', 'and', 'go', 'to', 'a', 'specialist', 'art', 'or', 'paper', 'shop', 'instead', '.', '<eos>']
# ----- ID
# 4
# ----- tokens input
# forsake your usual stationer , who probably wo n't have the room or the reason for stocking unusual papers or cards , and go to a specialist art or paper shop instead .
# ----- output predecido
# individual your usual dominated , who probably wo n't have the room or the reason for for unusual papers or , go to a specialist art or paper shop instead , and go to a specialist art or paper shop instead . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  2   --- acc: 0.000481811611659841
# ['thomson', 'was', 'born', 'in', '24', ',', 'india', ',', 'in', 'in', 'and', 'was', 'tokyo', 'at', 'the', 'royal', 'school', 'for', 'he', 'child_child11800', ',', 'in', ',', 'in', 'england', 'before', 'he', 'went', 'to', 'study', 'art_art10400', 'at', 'the', 'london', 'art_art10600', 'school', ',', 'english', ',', 'and', ',', 'and', 'and', ',', 'and', 'at', 'at', 'the', 'royal', 'academy', 'from', '.', '<eos>']
# ----- ID
# 5
# ----- tokens input
# thomson was born in bangalore , india , in 1894 and was educated at the royal school for deaf children , margate , in england before he went to study art at the london art school , kensington , and exhibited at the royal academy from 1920 .
# ----- output predecido
# thomson was born in 24 , india , in in and was tokyo at the royal school for he child_child11800 , in , in england before he went to study art_art10400 at the london art_art10600 school , english , and , and and , and at at the royal academy from . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  3   --- acc: 0.0007227174174897615
# ['english', ',', ',', ',', 'a', 'foreign', 'language', ',', ',', ',', 'the', ',', ',', 'history', ',', 'some', 'art_art10600', 'and', ',', ',', 'not', 'too', 'much', ',', 'and', 'and', 'games', ',', 'the', ',', ',', 'education', '.', '<eos>']
# ----- ID
# 6
# ----- tokens input
# english , mathematics , a foreign language , latin , the sciences , history , geography , some art and crafts , but not too much , pe and games , the compulsory religious education .
# ----- output predecido
# english , , , a foreign language , , , the , , history , some art_art10600 and , , not too much , and and games , the , , education . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  3   --- acc: 0.0007227174174897615
# ['imagination', 'has', 'been', 'associated', 'especially', 'with', 'the', 'art_arts10900', ',', 'and', 'thus', 'in', 'recent', 'years', 'has', 'been', 'increasingly', 'similar', '.', '<eos>']
# ----- ID
# 7
# ----- tokens input
# imagination has been associated especially with the arts , and thus in recent years has been increasingly downgraded .
# ----- output predecido
# imagination has been associated especially with the art_arts10900 , and thus in recent years has been increasingly similar . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  4   --- acc: 0.000963623223319682
# ['leonard', 'did', ',', 'however', ',', 'manage', 'to', 'get', 'a', 'grant', 'from', 'the', 'canadian', 'arts', 'council', '.', '<eos>']
# ----- ID
# 8
# ----- tokens input
# leonard did , however , manage to get a grant from the canadian arts council .
# ----- output predecido
# leonard did , however , manage to get a grant from the canadian arts council . <eos>
# ----- respuesta
# ['art_P', 'art_arts10900']
#
# --- hints:  4   --- acc: 0.000963623223319682
# ['or', 'the', 'authorities', 'art_art10600', 'ballot', 'who', 'once', 'board', 'with', "'s", 'with', 'with', 'a', 'spray', 'can', '.', '<eos>']
# ----- ID
# 9
# ----- tokens input
# or the iranian art merchant who once defaced picasso 's guernica with a spray can .
# ----- output predecido
# or the authorities art_art10600 ballot who once board with 's with with a spray can . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  5   --- acc: 0.0012045290291496024
# ['they', 'read', 'publications', 'that', 'keep_keep24200', 'them', 'aware', 'of', 'market', 'trends', ',', 'personalities', ',', '+', 'and', 'prices', 'rather', 'than', 'into', 'into', 'art_art10600', 'history', 'as', 'do', 'their', 'counterparts', 'in', 'europe', '.', '<eos>']
# ----- ID
# 10
# ----- tokens input
# they read publications that keep them abreast of market trends , personalities , lawsuits and prices rather than delving into art history as do their counterparts in europe .
# ----- output predecido
# they read publications that keep_keep24200 them aware of market trends , personalities , + and prices rather than into into art_art10600 history as do their counterparts in europe . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  6   --- acc: 0.001445434834979523
# ['blind_blind50000irrational00', ',', 'health', 'one', 'of', 'art_art10400', 'material_material12700', 'is', 'subsidies', 'in', 'the', 'united', 'states', ',', 'though', 'not', ',', 'as', 'yet', 'country', 'in', 'this', 'country', '.', '<eos>']
# ----- ID
# 11
# ----- tokens input
# highlighted , health labelling of art materials is obligatory in the united states , though not , as yet , in this country .
# ----- output predecido
# blind_blind50000irrational00 , health one of art_art10400 material_material12700 is subsidies in the united states , though not , as yet country in this country . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  7   --- acc: 0.0016863406408094434
# ['i', 'love', 'what', 'i', "'m", 'doing', 'for', 'live_live24206', 'but', 'there', 'are', 'two', 'things', 'that', 'i', 'do', 'think', 'about', ',', 'one', 'is', 'becoming', 'an', 'actress', 'and', 'the', 'other', 'is', 'going', 'to', 'to', 'to', 'study', 'art_art10600', 'history', '.', '<eos>']
# ----- ID
# 12
# ----- tokens input
# i love what i 'm doing for revlon but there are two things that i do think about , one is becoming an actress and the other is going to university to study art history .
# ----- output predecido
# i love what i 'm doing for live_live24206 but there are two things that i do think about , one is becoming an actress and the other is going to to to study art_art10600 history . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  8   --- acc: 0.001927246446639364
# ['you', 'see', 'art_art10600', 'that', "'s", 'created', 'by', 'people', 'who', 'are', 'killing', 'themselves', 'making', 'it', ',', 'and', 'i', 'always', 'how', 'how', 'it', 'would', 'turn', 'out', 'if', 'they', 'were', "n't", 'doing', 'that', '.', '<eos>']
# ----- ID
# 13
# ----- tokens input
# you see art that 's created by people who are killing themselves making it , and i always wonder how it would turn out if they were n't doing that .
# ----- output predecido
# you see art_art10600 that 's created by people who are killing themselves making it , and i always how how it would turn out if they were n't doing that . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  9   --- acc: 0.0021681522524692846
# ['perspective', 'west', 'the', 'ancient', 'art_art10900', 'of', 'beating', 'stress_stress12601', '.', '<eos>']
# ----- ID
# 14
# ----- tokens input
# mel yates the ancient art of beating stress .
# ----- output predecido
# perspective west the ancient art_art10900 of beating stress_stress12601 . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  10   --- acc: 0.002409058058299205
# ['conference', 'in', 'seattle', 'amount', 'february', 'and', 'see_see23903', 'meet', 'at', 'the', 'identification', '24', 'april', 'the', 'annual', 'conference', 'of', 'the', 'association', 'of', 'art_work_of_art10600', 'initiative', 'will', 'meet', 'at', 'the', 'car', 'gallery', 'this', 'year', 'from', '2', 'to', '4', 'april', '.', '<eos>']
# ----- ID
# 15
# ----- tokens input
# conference in seattle 46 february and britons meet at the tate 24 april the annual conference of the association of art historians will meet at the tate gallery this year from 2 to 4 april .
# ----- output predecido
# conference in seattle amount february and see_see23903 meet at the identification 24 april the annual conference of the association of art_work_of_art10600 initiative will meet at the car gallery this year from 2 to 4 april . <eos>
# ----- respuesta
# ['art_P', 'art_art_historian11800']
#
# --- hints:  10   --- acc: 0.002409058058299205
# ['some', 'will', 'no', 'doubt', 'barrier', 'wander_wander23800', 'of', 'shock', 'tactics', 'along', ',', 'lines', ',', 'but', 'and', 'has', 'has', 'the', 'the', 'view', 'that', 'performance', 'and', 'far', 'art_art10400', 'are', 'at', 'their', 'when', 'when', 'their', 'social', 'or', 'political', 'issues', 'or', 'political', 'social', 'or', 'political', 'issues', '.', '<eos>']
# ----- ID
# 16
# ----- tokens input
# some will no doubt accuse jarman of shock tactics along warhol lines , but jarman has reinforced the view that performance and installation art are at their strongest when addressing social or political issues .
# ----- output predecido
# some will no doubt barrier wander_wander23800 of shock tactics along , lines , but and has has the the view that performance and far art_art10400 are at their when when their social or political issues or political social or political issues . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  10   --- acc: 0.002409058058299205
# ['my', 'main', '1982', 'is', 'the', 'array', 'of', 'soil', 'created', 'by', 'art_art10600', 'language', 'included', 'in', 'the', 'latter', 'stages', 'a', 'group', 'with', 'which', 'harrison', 'and', 'wood', 'have', 'been', 'fine', 'involved', '.', '<eos>']
# ----- ID
# 17
# ----- tokens input
# my main gripe is the surfeit of turgid waffle by art language included in the latter stages a group with which harrison and wood have been intimately involved .
# ----- output predecido
# my main 1982 is the array of soil created by art_art10600 language included in the latter stages a group with which harrison and wood have been fine involved . <eos>
# ----- respuesta
# ['art_P', 'art_art10400']
#
# --- hints:  10   --- acc: 0.002409058058299205
# ['even', 'use_use23401', 'ltd', 'drives', 'from', 'from', 'into', 'into', 'village', ',', ',', ',', 'ancient', 'whatever', ',', ',', 'art_art10400', 'and', 'so', 'on', '.', '<eos>']
# ----- ID
# 18
# ----- tokens input
# even kasmin ltd diversified enormously from 198590 into antiquities , neolithic , ancient eskimo , tribal art and so on .
# ----- output predecido
# even use_use23401 ltd drives from from into into village , , , ancient whatever , , art_art10400 and so on . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  10   --- acc: 0.002409058058299205
# ['the', 'state', 'of', 'the', 'treasury', "'s", 'art_art10600', 'is', 'now', 'such', 'that', 'the', 'choice', 'of', 'instrument', 'to', 'use', 'depends', 'largely', 'on', 'what', 'he', 'wants', 'to', 'see', ',', 'and', 'in', 'some', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'price', '.', '<eos>']
# ----- ID
# 19
# ----- tokens input
# the state of the microscopist 's art is now such that the choice of instrument to use depends largely on what he wants to see , and in some applications the acoustic microscope may give him the sharpest pictures ever .
# ----- output predecido
# the state of the treasury 's art_art10600 is now such that the choice of instrument to use depends largely on what he wants to see , and in some the the the the the the the the the the the the the the price . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  10   --- acc: 0.002409058058299205
# ['it', "'s", 'a', 'dream', 'lewis', "'s", 'progress', ';', 'a', 'la', 'carefully', 'meditation', 'on', 'the', 'organic', 'culture', 'of', 'male', 'glory', 'and', 'the', 'the', 'art_art10900', 'of', 'the', 'deal', '.', '<eos>']
# ----- ID
# 20
# ----- tokens input
# it 's a sardonic pilgrim 's progress ; a furiously lyrical meditation on the corrupt culture of male glory and the parasitical art of the deal .
# ----- output predecido
# it 's a dream lewis 's progress ; a la carefully meditation on the organic culture of male glory and the the art_art10900 of the deal . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  11   --- acc: 0.0026499638641291254
# ['all', 'such', 'studies', 'have', 'currency', 'every', 'form', 'of', 'art_art10600', 'in', 'some', 'way', '.', '<eos>']
# ----- ID
# 21
# ----- tokens input
# all such studies have influenced every form of art in some way .
# ----- output predecido
# all such studies have currency every form of art_art10600 in some way . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  11   --- acc: 0.0026499638641291254
# ['so', 'will', 'she', 'go', 'and', 'nick', 'their', 'furniture', 'if', 'art_art10600', 'does', "n't", 'pay', '.', '<eos>']
# ----- ID
# 22
# ----- tokens input
# so will she go and nick their furniture if art does n't pay .
# ----- output predecido
# so will she go and nick their furniture if art_art10600 does n't pay . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  11   --- acc: 0.0026499638641291254
# ['a', 'few', 'years', 'back', ',', 'you', 'could', 'not', 'get', 'young', 'women', 'to', 'be', 'active', ',', 'said', 'said', 'another', ',', 'president', 'of', 'the', 'of', 'of', 'ground', ',', 'an', 'organisation', 'of', 'the', 'women', 'of', 'business', 'women', 'in', 'business', 'and', 'the', 'art_arts10900', '.', '<eos>']
# ----- ID
# 23
# ----- tokens input
# a few years back , you could not get young women to be active , said judy miller , president of the los angeles-based trusteeship , an organisation of influential women in business and the arts .
# ----- output predecido
# a few years back , you could not get young women to be active , said said another , president of the of of ground , an organisation of the women of business women in business and the art_arts10900 . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  11   --- acc: 0.0026499638641291254
# ['moving', 'the', 'contemporary', 'art_art10600', 'to', 'the', 'fifth', 'floor', 'provided', 'room', 'adjacent', 'to', 'the', 'american', 'painting', 'and', 'sculpture', 'galleries', '.', '<eos>']
# ----- ID
# 24
# ----- tokens input
# moving the contemporary art to the fifth floor provided room adjacent to the american painting and sculpture galleries .
# ----- output predecido
# moving the contemporary art_art10600 to the fifth floor provided room adjacent to the american painting and sculpture galleries . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  12   --- acc: 0.002890869669959046
# ['our', 'heat', 'location', 'costs', 'itself', 'to', 'strong', 'links', 'with', 'the', 'european', 'arts', 'and', 'and', 'i', 'am', 'that', 'we', 'we', 'develop', 'that', 'we', 'will', 'develop', 'exciting', 'all', 'in', 'all', 'areas', 'of', 'activity', '.', '<eos>']
# ----- ID
# 25
# ----- tokens input
# our geographical location lends itself to strong links with the european arts infrastructure and i am confident that we will develop exciting initiatives in all areas of activity .
# ----- output predecido
# our heat location costs itself to strong links with the european arts and and i am that we we develop that we will develop exciting all in all areas of activity . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  12   --- acc: 0.002890869669959046
# ['pope', 'punch', "'s", 'weekly', 'guide', 'to', 'the', 'art_arts10900', ',', 'entertainment', ',', 'media', 'and', 'more', '.', '<eos>']
# ----- ID
# 26
# ----- tokens input
# charivari punch 's weekly guide to the arts , entertainment , media and more .
# ----- output predecido
# pope punch 's weekly guide to the art_arts10900 , entertainment , media and more . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  13   --- acc: 0.0031317754757889667
# ['in', 'the', 'late', 'day', ',', 'himself', 'becomes', 'his', 'hot', 'and', 'set', 'off', 'as', 'a', 'travelling', 'inner', 'on', 'century', 'of', 'the', 'gallery', 'to', 'america', ',', 'hearth_hearth10600', 'the', 'states', 'with', 'a', 'of', 'of', 'practice', ',', 'finding', 'out', 'who', 'was', 'in', 'in', ',', 'was', 'out', 'who', 'and', 'in', 'in', 'in', 'from', 'the', 'local', 'from', 'the', 'local', 'museums', ',', 'and', 'and', 'people', 'who', 'did', 'did', "n't", 'get', 'to', 'new', 'york', '.', '<eos>']
# ----- ID
# 27
# ----- tokens input
# in the late sixties , kasmin swallowed his pride and set off as a travelling salesman on behalf of the gallery to america , travelling the states with a bagful of transparencies , finding out who was interested in art from the local museums , and visiting people who did n't get to new york .
# ----- output predecido
# in the late day , himself becomes his hot and set off as a travelling inner on century of the gallery to america , hearth_hearth10600 the states with a of of practice , finding out who was in in , was out who and in in in from the local from the local museums , and and people who did did n't get to new york . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  13   --- acc: 0.0031317754757889667
# ['i', 'think', 'you', 'should', 'make', 'art_art10600', 'a', 'little', 'bit', 'more', 'alive', '.', '<eos>']
# ----- ID
# 28
# ----- tokens input
# i think you should make art a little bit more alive .
# ----- output predecido
# i think you should make art_art10600 a little bit more alive . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  14   --- acc: 0.003372681281618887
# ['contemporary', 'art_art10600', 'market', '.', '<eos>']
# ----- ID
# 29
# ----- tokens input
# contemporary art market .
# ----- output predecido
# contemporary art_art10600 market . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['as', 'pointed', 'out', 'by', 'the', 'collector', 'and', 'historian', 'van', 'myself', 'writing', 'in', 'a', ',', 'where', 'so', 'could', 'relationship', 'has', 'only', 'to', 'go', 'to', 'to', 'the', 'greatest', 'art_art10600', 'the', 'present', 'time', ';', 'there', 'he', 'may', 'see', 'at', 'the', 'the', 'at', 'the', 'present', 'time', ';', 'there', 'he', 'may', 'see', 'at', 'the', 'the', 'and', 'a', ',', 'of', 'and', ',', ',', 'and', 'and', 'and', 'and', ',', ',', 'and', 'and', '<eos>']
# ----- ID
# 30
# ----- tokens input
# as pointed out by the collector and historian van mander writing in 1604 , whoever so desires nowadays has only to go to prague to the greatest art patron in the world at the present time ; there he may see at the imperial residence a remarkable number of outstanding and precious , curious , unusual , and priceless works .
# ----- output predecido
# as pointed out by the collector and historian van myself writing in a , where so could relationship has only to go to to the greatest art_art10600 the present time ; there he may see at the the at the present time ; there he may see at the the and a , of and , , and and and and , , and and <eos>
# ----- respuesta
# ['art_art10600', 'art_art10400']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['knowing', 'what', 'the', 'flight', 'knew', 'then', 'that', 'the', 'the', 'was', 'lower', 'with', 'conservative', 'model', 'and', 'already', 'the', 'target', 'of', 'a', 'energy', 'for', 'such', 'such', 'such', 'they', 'can', 'levels', 'this', 'as', 'a', 'star', 'they', 'could', 'a', 'a', 'political', 'a', 'a', 'a', 'political', 'star', 'or', ',', ',', 'indeed', ',', 'to', 'to', 'get', 'to', 'leave', 'town', ',', '.', '<eos>']
# ----- ID
# 31
# ----- tokens input
# knowing what the bushmen knew then that the nea was unpopular with conservative legislators and already the target of fundamentalist christians for subsidising offensive art they can hardly have seen this as a plum they could hand to a big contributor or a rising political star or , indeed , to anybody aiming to leave town alive .
# ----- output predecido
# knowing what the flight knew then that the the was lower with conservative model and already the target of a energy for such such such they can levels this as a star they could a a political a a a political star or , , indeed , to to get to leave town , . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['most', ',', 'if', 'not', 'all', ',', 'of', 'the', 'original', 'arts', 'are', 'natural', 'linked', 'to', 'the', 'three', 'main', 'east', 'asian', ',', ',', ',', ',', ',', ',', ',', ',', 'and', '.', '<eos>']
# ----- ID
# 32
# ----- tokens input
# most , if not all , of the martial arts are inextricably linked to the three main east asian religions , buddhism , taoism and confucianism .
# ----- output predecido
# most , if not all , of the original arts are natural linked to the three main east asian , , , , , , , , and . <eos>
# ----- respuesta
# ['art_martial_art10400']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['david', 'david', "'s", 'latest', 'work', 'of', 'art_art10600', 'arrived', 'in', 'his', 'home', 'city', 'of', 'jonathan', 'last', 'night', 'in', 'a', 'soil', 'of', 'of', 'of', 'and', 'sheets', 'of', 'of', 'paper', ',', 'and', 'to', 'the', 'sound', 'of', 'of', "'s", 'the', 'of', 'the', 'the', 'the', 'the', 'the', 'the', 'of', 'the', '<eos>']
# ----- ID
# 33
# ----- tokens input
# david hockney 's latest work of art arrived in his home city of bradford last night in a welter of spray-on glue and sheets of fax paper , and to the sound of wagner 's ride of the valkyries .
# ----- output predecido
# david david 's latest work of art_art10600 arrived in his home city of jonathan last night in a soil of of of and sheets of of paper , and to the sound of of 's the of the the the the the the of the <eos>
# ----- respuesta
# ['art_work_of_art10600']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['homes', 'and', 'housing', '33', 'transport', 'museum', 'local', 'government', 'education', 'cities', 'education', 'minority', '40', 'the', 'countryside', '40', ',', ',', 'rocks', 'and', 'the', 'round', 'the', 'environment', 'the', 'the', 'environment', 'towards', 'the', 'the', 'u', 'fund', 'fund', 'arts', 'o', '.', '<eos>']
# ----- ID
# 34
# ----- tokens input
# homes and housing 33 transport 35 local government 37 cities 38 london 40 the countryside 40 farming , forestry and fishing 41 the environment 43 towards the millennium millennium fund 44 arts 44 .
# ----- output predecido
# homes and housing 33 transport museum local government education cities education minority 40 the countryside 40 , , rocks and the round the environment the the environment towards the the u fund fund arts o . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['the', 'plan', 'is', 'to', 'convert', 'a', 'high', 'factory', 'compound', 'into', 'the', 'world', "'s", 'largest', 'museum', 'of', 'post_post10600', 'international', 'art_art10400', '.', '<eos>']
# ----- ID
# 35
# ----- tokens input
# the plan is to convert a twenty-eight-building factory compound into the world 's largest museum of post-1960 international art .
# ----- output predecido
# the plan is to convert a high factory compound into the world 's largest museum of post_post10600 international art_art10400 . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  15   --- acc: 0.0036135870874488074
# ['nor', 'is', 'this', 'feeling_feeling10300', 'only', 'detail', 'by', 'the', 'sight', 'or', 'the', 'thought', 'of', 'art_art10600', ',', 'he', 'wrote', '.', '<eos>']
# ----- ID
# 36
# ----- tokens input
# nor is this feeling only provoked by the sight or the thought of art , he wrote .
# ----- output predecido
# nor is this feeling_feeling10300 only detail by the sight or the thought of art_art10600 , he wrote . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  16   --- acc: 0.003854492893278728
# ['the', 'expertise', 'was', 'grim', ',', 'the', 'food', 'was', 'survival', ',', 'fashion', 'was', 'all', 'but', 'agriculture', ',', 'the', 'art_arts10900', 'were', 'sky', ',', ',', ',', ',', 'despite', 'the', ',', 'of', ',', 'almost', ',', 'john', ',', ',', ',', ',', ',', ',', ',', ',', 'and', 'and', 'and', ';', 'and', 'and', 'and', 'and', ';', 'and', 'and', 'and', 'and', ';', 'and', '<eos>']
# ----- ID
# 37
# ----- tokens input
# the scenery was grim , the food was unappetising , fashion was all but non-existent , the arts were struggling , almost moribund , despite the explosive qualities of kingsley amis , john osborne , colin wilson , and alan sillitoe ; and the weather was atrocious .
# ----- output predecido
# the expertise was grim , the food was survival , fashion was all but agriculture , the art_arts10900 were sky , , , , despite the , of , almost , john , , , , , , , , and and and ; and and and and ; and and and and ; and <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  17   --- acc: 0.004095398699108649
# ['art_art10600', 'la', '.', '<eos>']
# ----- ID
# 38
# ----- tokens input
# art la .
# ----- output predecido
# art_art10600 la . <eos>
# ----- respuesta
# ['art_P', 'art_art10600']
#
# --- hints:  18   --- acc: 0.004336304504938569
# ['entertainment', 'seems', 'historically', 'rather', 'than', 'essentially', 'owns', ',', 'and', 'what', 'shallow', 'is', 'a', 'recognition', 'of', 'the', 'historical', 'possibility', 'of', 'popular', 'entertainment', 'as', 'an', 'as', 'art_art10900', 'which', 'might', 'turn', 'on', 'its', 'head', 'the', 'of', 'of', 'official', ',', ',', ',', '.', '<eos>']
# ----- ID
# 39
# ----- tokens input
# entertainment seems historically rather than essentially debased , and what emerges is a recognition of the historical possibility of popular entertainment as an autonomous art which might turn on its head the seriousness of official , rational discourse .
# ----- output predecido
# entertainment seems historically rather than essentially owns , and what shallow is a recognition of the historical possibility of popular entertainment as an as art_art10900 which might turn on its head the of of official , , , . <eos>
# ----- respuesta
# ['art_art10400', 'art_art10900']
#
# --- hints:  19   --- acc: 0.00457721031076849
# ['something', 'of', 'the', 'sort', 'has', 'already', 'been', 'introduced', 'into', 'some', 'english', 'preserved', ',', 'under', 'the', 'the', 'of', 'the', 'the', 'arts', 'association', 'association', ',', 'who', 'have', 'made', 'a', 'welcome', 'start', 'with', 'such', 'work', '.', '<eos>']
# ----- ID
# 40
# ----- tokens input
# something of the sort has already been introduced into some english degrees , under the aegis of the verbal arts association , who have made a welcome start with such work .
# ----- output predecido
# something of the sort has already been introduced into some english preserved , under the the of the the arts association association , who have made a welcome start with such work . <eos>
# ----- respuesta
# ['art_P', 'art_art10900']
#
# --- hints:  19   --- acc: 0.00457721031076849
# ['could', 'it', 'be', 'that', 'there', 'was', 'then', 'more', 'ten', 'in', 'the', 'art_art10900', 'world', ',', 'and', 'that', 'black', 'artists', 'were', 'being', 'only', 'out', 'at', 'just', 'the', 'time', 'when', 'young', 'fixed', 'the', 'time', 'when', 'young', 'fires', 'the', 'from', 'british', 'were', 'finding', 'and', 'and', 'public', 'public', ',', 'and', 'public', 'public', '.', '<eos>']
# ----- ID
# 41
# ----- tokens input
# could it be that there was then more racism in the art world , and that black artists were being squeezed out at just the time when young working-class artists from the british provinces were finding unprecedented and immediate public fortune .
# ----- output predecido
# could it be that there was then more ten in the art_art10900 world , and that black artists were being only out at just the time when young fixed the time when young fires the from british were finding and and public public , and public public . <eos>
# ----- respuesta
# ['art_art10600', 'art_art10400']
#
# --- hints:  19   --- acc: 0.00457721031076849
# ['the', 'pictures', 'that', 'us', 'tried', 'for', 'decades', 'to', 'restraint_restraint10400', 'or', 'wrong', 'off', 'the', 'plans', "'s", 'walls', 'will', 'also', 'travel', 'to', 'the', 'the', 'in', 'in', 'paris', 'and', 'then', 'to', 'the', 'museum', 'of', 'western', 'art_art10600', 'in', 'tokyo', '.', '<eos>']
# ----- ID
# 42
# ----- tokens input
# the pictures that curators tried for decades to coax or pry off the barnes 's walls will also travel to the muse d'orsay in paris and then to the museum of western art in tokyo .
# ----- output predecido
# the pictures that us tried for decades to restraint_restraint10400 or wrong off the plans 's walls will also travel to the the in in paris and then to the museum of western art_art10600 in tokyo . <eos>
# ----- respuesta
# ['art_P', 'art_art10600']
#
# --- hints:  20   --- acc: 0.00481811611659841
# ['faced', ',', 'as', 'far', 'as', 'he', 'can', 'see', ',', 'with', 'a', 'future', 'of', 'minimum', 'and', 'and', 'maximum', 'creating', ',', 'he', 'has', 'decided', 'to', 'sell', 'his', 'gallery', 'at', ',', 'later', 'street', 'as', 'an', 'art_art10600', 'object', '.', '<eos>']
# ----- ID
# 43
# ----- tokens input
# faced , as far as he can see , with a future of minimum inflow and maximum outflow , he has decided to sell his gallery at 22 cork street as an art object .
# ----- output predecido
# faced , as far as he can see , with a future of minimum and and maximum creating , he has decided to sell his gallery at , later street as an art_art10600 object . <eos>
# ----- respuesta
# ['art_U', 'art_art10600']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['gavin', 'techniques', 'combined', 'studies', 'in', 'art_art10600', 'and', 'design', 'application', 'through', 'personalities', '.', '<eos>']
# ----- ID
# 44
# ----- tokens input
# ba hons combined studies in art and design application through adar .
# ----- output predecido
# gavin techniques combined studies in art_art10600 and design application through personalities . <eos>
# ----- respuesta
# ['art_P', 'art_art10400']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['among', 'the', 'technical', 'art_arts10900', 'including', 'in', 'some', 'continental', 'schools', 'that', 'begin_begin23000', 'to', 'affect', 'england', 'soon', 'after', 'the', 'men', 'full', 'were', 'those', 'of', 'what', 'and', 'and', '.', '<eos>']
# ----- ID
# 45
# ----- tokens input
# among the technical arts cultivated in some continental schools that began to affect england soon after the norman conquest were those of measurement and calculation .
# ----- output predecido
# among the technical art_arts10900 including in some continental schools that begin_begin23000 to affect england soon after the men full were those of what and and . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['case', 'history', 'watercolour', 'street', 'baths', ',', 'these', 'these', 'hill', 'were', 'turned', 'into', 'a', 'handsome', 'arts', 'art_arts10900', 'and', 'develop_develop23600', 'complex', 'after', 'they', 'were', 'suddenly', 'the', 'children', 'train', 'by', 'the', 'navy', '.', '<eos>']
# ----- ID
# 46
# ----- tokens input
# case history pitt street baths , portsmouth these baths were turned into a handsome edwardian arts and crafts complex after they were suddenly vacated by the navy .
# ----- output predecido
# case history watercolour street baths , these these hill were turned into a handsome arts art_arts10900 and develop_develop23600 complex after they were suddenly the children train by the navy . <eos>
# ----- respuesta
# ['art_art10600', 'art_art10400']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['their', 'enhanced', 'and', 'fall', 'sell', 'by', 'the', '1976', ',', 'they', "'ve", 'done', 'cover', 'art_art10400', 'for', 'former', ',', 'struggle', 'and', 'boy', 'george', 'and', 'yet', 'this', 'month', 'the', 'the', 'first', 'of', 'first', 'the', 'first', 'ever', 'their', 'first', 'of', 'their', 'work', '.', '<eos>']
# ----- ID
# 47
# ----- tokens input
# their postcards and t-shirts sell by the crateload , they 've done cover art for marc almond , erasure and boy george and yet this month sees the first ever uk exhibition of their work .
# ----- output predecido
# their enhanced and fall sell by the 1976 , they 've done cover art_art10400 for former , struggle and boy george and yet this month the the first of first the first ever their first of their work . <eos>
# ----- respuesta
# ['art_art11000']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['the', 'art_art10900', 'critic', 'is', 'thus', 'bound', 'to', 'consider', 'with', 'care', 'what', 'standards', 'of', 'comparison', 'should', 'be', 'used', '.', '<eos>']
# ----- ID
# 48
# ----- tokens input
# the art critic is thus bound to consider with care what standards of comparison should be used .
# ----- output predecido
# the art_art10900 critic is thus bound to consider with care what standards of comparison should be used . <eos>
# ----- respuesta
# ['art_art_critic11800']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['all', 'my', 'life', ',', 'he', 'wrote', ',', 'i', 'have', 'used', 'art_art10600', 'to', 'fight', 'against', 'myself', '.', '<eos>']
# ----- ID
# 49
# ----- tokens input
# all my life , he wrote , i have used art to fight against myself .
# ----- output predecido
# all my life , he wrote , i have used art_art10600 to fight against myself . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  21   --- acc: 0.00505902192242833
# ['disappointed', 'yet', 'again', ',', 'the', 'british', 'intellectual', 'left', 'will', 'be', 'get', 'to', 'build', 'up', 'its', 'own', 'own', 'in', 'higher', 'education', ',', 'local', 'government', ',', 'scientific', 'research', 'and', 'the', 'art_arts10900', 'and', 'and', 'the', 'world', 'outside', '.', '<eos>']
# ----- ID
# 50
# ----- tokens input
# disappointed yet again , the british intellectual left will be tempted to build up its own dukes in higher education , local government , scientific research and the arts and damn the world outside .
# ----- output predecido
# disappointed yet again , the british intellectual left will be get to build up its own own in higher education , local government , scientific research and the art_arts10900 and and the world outside . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['perhaps', 'we', 'could', 'regard', 'an', 'organized', 'church', ',', 'with', 'its', 'architecture', ',', ',', ',', 'laws', ',', 'music', ',', 'art_art10400', ',', 'and', 'written', 'tradition', ',', 'as', 'a', ',', 'set', 'of', 'of', 'of', '.', '<eos>']
# ----- ID
# 51
# ----- tokens input
# perhaps we could regard an organized church , with its architecture , rituals , laws , music , art , and written tradition , as a co-adapted stable set of mutually-assisting memes .
# ----- output predecido
# perhaps we could regard an organized church , with its architecture , , , laws , music , art_art10400 , and written tradition , as a , set of of of . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['these', 'highlanders', 'were', 'traditional', 'by', 'their', 'respective', 'and', 'and', 'were', 'chosen', 'by', 'the', 'the', 'to', 'the', 'the', 'art_art10400', 'produced', 'and', 'the', 'by', 'by', 'by', 'three', 'of', 'types', 'of', 'regime', 'of', 'regime', '.', '<eos>']
# ----- ID
# 52
# ----- tokens input
# these spaces were commissioned by their respective rulers and were chosen by the authors to illustrate the art produced and the ideology disseminated by three distinctive types of regime .
# ----- output predecido
# these highlanders were traditional by their respective and and were chosen by the the to the the art_art10400 produced and the by by by three of types of regime of regime . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['as', 'far', 'as', 'the', 'primary', 'phase', 'of', 'important', 'was', 'concerned', ',', 'the', 'plan', 'of', 'development', 'favoured', 'the', 'same', 'activities', 'as', 'were', 'listed', 'in', 'a', 'framework', 'for', 'the', 'school', ',', ',', 'except', 'that', 'more', 'held', 'was', 'devoted', 'to', 'history', 'and', 'and', ',', 'science', ',', 'and', 'to', 'the', 'need', 'and', 'clearly', 'the', 'need', 'and', 'clearly', 'in', 'work', 'in', 'these', 'these', 'of', 'the', 'the', '.', '<eos>']
# ----- ID
# 53
# ----- tokens input
# as far as the primary phase of schooling was concerned , the plan of development favoured the same activities as were listed in a framework for the school curriculum , except that more attention was devoted to history and geography , to expressive arts , and to science , and to the need for clearly structured and progressively demanding work in these areas of the curriculum .
# ----- output predecido
# as far as the primary phase of important was concerned , the plan of development favoured the same activities as were listed in a framework for the school , , except that more held was devoted to history and and , science , and to the need and clearly the need and clearly in work in these these of the the . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['the', 'phrase', 'suggests', 'that', 'b', 'was', 'in', 'in', 'an', 'activity', 'other', 'than', 'art_art10600', '.', '<eos>']
# ----- ID
# 54
# ----- tokens input
# the phrase suggests that brunelleschi was engaging in an activity other than art .
# ----- output predecido
# the phrase suggests that b was in in an activity other than art_art10600 . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['the', 'campaign', 'to', 'save', 'a', 'local_local30101', 'art_p', 'centre', 'beauty', 'that', 'enough', ',', 'but', 'soon', 'becomes', 'the', 'target', 'for', 'party', ',', 'and', 'jane', 'whatever', 'herself', 'in', 'increasing', 'danger', 'as', 'she', 'gave', 'of', 'of', 'that', 'spread', 'from', 'an', 'local', 'college', 'to', 'the', 'houses', 'of', 'parliament', '.', 'to', '<eos>']
# ----- ID
# 55
# ----- tokens input
# the campaign to save a local arts centre starts innocently enough , but soon becomes the target for intimidation , and jane finds herself in increasing danger as she uncovers layers of corruption that spread from an oxford college to the houses of parliament .
# ----- output predecido
# the campaign to save a local_local30101 art_p centre beauty that enough , but soon becomes the target for party , and jane whatever herself in increasing danger as she gave of of that spread from an local college to the houses of parliament . to <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['the', 'art_p', 'criticism', 'of', 'the', 'day_day12805', 'is', 'fully', 'described', 'in', 'the', 'structures', ',', 'and', 'some', 'of', 'the', 'underlying', 'reasons', 'for', 'its', 'mainly', 'aggressive', 'character', 'are', ';', ';', 'these', 'include', 'and', 'the', 'and', 'and', 'the', 'and', 'and', 'the', 'and', 'the', 'some', 'nuclear', 'of', 'some', '.', '<eos>']
# ----- ID
# 56
# ----- tokens input
# the art criticism of the day is fully described in the monograph , and some of the underlying reasons for its mainly aggressive character are outlined ; these include anti-semitism and the fierce dislike of the monument by some academic sculptors .
# ----- output predecido
# the art_p criticism of the day_day12805 is fully described in the structures , and some of the underlying reasons for its mainly aggressive character are ; ; these include and the and and the and and the and the some nuclear of some . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['salon', 'de', 'firms', 'scheduled', 'to', 'avoid', 'france', "'s", 'pope', "'s", 'this', 'year', 'facing', 'de', 'area', 'arts', 'and', 'popularity', 'fair', ',', 'held', 'as', 'ever', 'under', 'several', ',', 'of', 'the', 'the', ',', 'the', "'s", 'abilities', 'wallabies', 'from', "'s", 'march', 'on', 'the', 'the', 'abilities', 'abilities', "'s", 'march', 'to', ',', "'s", ',', 'is', 'a', ',', 'is', 'a', 'economy', 'is', 'than', 'last', 'year', "'s", "'s", 'year', "'s", '.', '<eos>']
# ----- ID
# 57
# ----- tokens input
# salon de mars scheduled to avoid france 's pre-election jitters this year 's fifth annual salon de mars arts and antiques fair , held as ever under several acres of white tenting on the champ de mars near the eiffel tower from 31 march to 5 april , is a smaller edition than last year 's .
# ----- output predecido
# salon de firms scheduled to avoid france 's pope 's this year facing de area arts and popularity fair , held as ever under several , of the the , the 's abilities wallabies from 's march on the the abilities abilities 's march to , 's , is a , is a economy is than last year 's 's year 's . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['those', 'works', 'include', 'sculpture', 'by', 'richard', 'accelerated', ',', 'joseph', 'dry', ',', 'its', 'minor', 'and', 'a', 'painting', 'by', 'land', 'and', 'have', 'been', 'hung', 'with', 'recent', 'with', 'of', 'and', 'been', 'been', 'by', 'and', 'recent', 'by', 'and', 'other', 'by', 'artists', '.', '<eos>']
# ----- ID
# 58
# ----- tokens input
# those works include sculpture by richard deacon , julian opie , grenville davey and richard wentworth and a painting by lisa milroy and have been hung with recent purchases of contemporary art by ashley bickerton , damien hirst and other younger artists .
# ----- output predecido
# those works include sculpture by richard accelerated , joseph dry , its minor and a painting by land and have been hung with recent with of and been been by and recent by and other by artists . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  22   --- acc: 0.005299927728258251
# ['concert', 'hopes', ',', 'art_arts10900', 'centres', 'or', 'community', 'centres', ',', 'if', 'during', 'designed', ',', 'are', 'probably', 'the', 'most', 'appropriate', ',', 'but', 'these', 'are', 'likely', 'to', 'to', 'on', ',', 'individual', 'on', 'individual', 'or', 'disturbed', 'any', 'more', 'than', 'one', 'of', 'any', 'one', 'type', 'than', 'one', 'of', 'any', 'one', 'type', '.', '<eos>']
# ----- ID
# 59
# ----- tokens input
# concert halls , arts centres or community centres , if sympathetically designed , are probably the most appropriate , but these are likely to depend on grants or donations , and most towns will not require more than one of any one type .
# ----- output predecido
# concert hopes , art_arts10900 centres or community centres , if during designed , are probably the most appropriate , but these are likely to to on , individual on individual or disturbed any more than one of any one type than one of any one type . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  23   --- acc: 0.0055408335340881715
# ['it', 'really', 'that', ',', 'even', 'at', 'a', 'workers', 'rate', ',', 'on', 'on', 'aircraft', 'from', 'outside', 'the', 'ec', 'would', 'the', 'damage', 'the', 'london', 'art_art10600', 'the', 'london', 'art_art10600', 'market', '.', '<eos>']
# ----- ID
# 60
# ----- tokens input
# it argues that , even at a reduced rate , vat on imports from outside the ec would seriously damage the london art market .
# ----- output predecido
# it really that , even at a workers rate , on on aircraft from outside the ec would the damage the london art_art10600 the london art_art10600 market . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  24   --- acc: 0.005781739339918092
# ['us', 'arrests', 'technical', 'artist', 'by', 'david', 'managed', ',', 'art_arts10900', 'correspondent', '.', '<eos>']
# ----- ID
# 61
# ----- tokens input
# us arrests mural artist by david lister , arts correspondent .
# ----- output predecido
# us arrests technical artist by david managed , art_arts10900 correspondent . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  24   --- acc: 0.005781739339918092
# ['total', 'art_art10600', '.', '<eos>']
# ----- ID
# 62
# ----- tokens input
# total art wank .
# ----- output predecido
# total art_art10600 . <eos>
# ----- respuesta
# ['art_art10600', 'art_U']
#
# --- hints:  25   --- acc: 0.006022645145748013
# ['meanwhile', 'at', 'odds', 'with', 'his', 'own', 'foundation', 'french', 'under', ',', 'age', 'themes', ',', 'leading', 'day_day12801', 'artist', 'of', 'the', 'of', 'and', '1970s', ',', 'and', 'of', 'very', 'very', 'strengthened', 'strengthened', 'of', 'thebasis', 'and', 'and', ',', 'and', 'and', ',', 'state', 'and', 'state', ',', 'of', ',', 'the', ',', 'on', 'on', 'the', 'president', 'of', 'his', 'own', 'arts', '.', '<eos>']
# ----- ID
# 63
# ----- tokens input
# vasarely at odds with his own foundation victor vasarely , age eighty-six , leading optical artist of the 1960s and 1970s , author of very numerous brightly coloured geometrical trompe l'oeil works and large scale state commissions , has declared legal war on the president of his own arts foundation at aix-en-provence , charles debbasch .
# ----- output predecido
# meanwhile at odds with his own foundation french under , age themes , leading day_day12801 artist of the of and 1970s , and of very very strengthened strengthened of thebasis and and , and and , state and state , of , the , on on the president of his own arts . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  25   --- acc: 0.006022645145748013
# ['setting', 'red', '12', 'low', 'also', 'a', 'a', 'of', 'older', 'of', 'systems', 'contemporary', 'american', 'art', '.', 'american', '<eos>']
# ----- ID
# 64
# ----- tokens input
# iris von der tann also offers a combination of older and thoroughly contemporary american art .
# ----- output predecido
# setting red 12 low also a a of older of systems contemporary american art . american <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  25   --- acc: 0.006022645145748013
# ['king', 'the', 'art_art10900', 'of', 'love', '.', '<eos>']
# ----- ID
# 65
# ----- tokens input
# king the art of love .
# ----- output predecido
# king the art_art10900 of love . <eos>
# ----- respuesta
# ['art_P', 'art_art10900']
#
# --- hints:  26   --- acc: 0.006263550951577933
# ['a', 'new', 'ministry', 'of', 'art_arts10900', 'and', 'la', 'should', 'be', 'created', 'to', 'michael', 'this', 'new', 'empire', ',', 'separated', 'from', 'the', 'ministry', 'of', 'education', 'and', 'enemies', 'that', 'ministry', "'s", 'current', ',', 'the', 'art_arts10900', 'council', ',', 'the', 'art_arts10900', 'council', ',', 'the', 'art_arts10900', 'council', ',', 'and', 'similar', 'and', '.', '<eos>']
# ----- ID
# 66
# ----- tokens input
# a new ministry of arts and sciences should be created to superintend this new empire , separated from the ministry of education and assuming that ministry 's current responsibilities for the research councils , the arts council , and similar bodies .
# ----- output predecido
# ...
# ----- respuesta
# ['bar_U']
#
# --- hints:  113   --- acc: 0.027222356058781018
# ['hold', 'the', 'bar_bar10604', 'with', 'an', 'tell', 'grip_grip10700', ',', 'that', 'is', 'one', 'palm', 'face_face23200', 'developed', 'and', 'one', 'face_face23200', 'owned', '.', '<eos>']
# ----- ID
# 256
# ----- tokens input
# hold the bar with an alternate grip , that is one palm facing outwards and one facing inwards .
# ----- output predecido
# hold the bar_bar10604 with an tell grip_grip10700 , that is one palm face_face23200 developed and one face_face23200 owned . <eos>
# ----- respuesta
# ['bar_bar10600']
#
# --- hints:  113   --- acc: 0.027222356058781018
# ['for', 'those', 'who', 'do', "n't", 'want', 'to', 'cook', 'for', 'themselves', ',', 'the', 'bar_bar10605', 'bar_coffee_bar10600', 'figures', '.', '<eos>']
# ----- ID
# 257
# ----- tokens input
# for those who do n't want to cook for themselves , the bar serves snacks .
# ----- output predecido
# for those who do n't want to cook for themselves , the bar_bar10605 bar_coffee_bar10600 figures . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  113   --- acc: 0.027222356058781018
# ['we', 'considered', 'buying', 'a', 'coffee', 'bar_bar10604', 'and', 'being', 'a', 'presence', 'in', 'the', 'market', 'place', ',', 'but', 'we', 'realised', 'this', 'would', 'not', 'be', 'a', 'suitable', 'place', 'for', 'sunday', ',', ',', 'and', 'our', 'and', 'buy', 'a', 'a', 'shop', 'were', 'consistently', 'blocked', '.', '<eos>']
# ----- ID
# 258
# ----- tokens input
# we considered buying a coffee bar and being a presence in the market place , but we realised this would not be a suitable place for sunday worship , and our attempts to buy a suitable shop were consistently blocked .
# ----- output predecido
# we considered buying a coffee bar_bar10604 and being a presence in the market place , but we realised this would not be a suitable place for sunday , , and our and buy a a shop were consistently blocked . <eos>
# ----- respuesta
# ['bar_coffee_bar10600']
#
# --- hints:  113   --- acc: 0.027222356058781018
# ['the', 'first', 'block', 'is', 'about', '100', 'metres', 'and', 'the', 'second', 'about', '500', 'metres', 'from', 'the', 'main', 'road', 'and', 'a', 'host', 'of', 'restaurants', 'and', 'bar_bar10604', 'can', 'be', 'found', 'nearby', '.', '<eos>']
# ----- ID
# 259
# ----- tokens input
# the first block is about 100 metres and the second about 500 metres from the main road and a host of restaurants and bars can be found nearby .
# ----- output predecido
# the first block is about 100 metres and the second about 500 metres from the main road and a host of restaurants and bar_bar10604 can be found nearby . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  114   --- acc: 0.027463261864610938
# ['maggie', 'sat', 'with', 'the', 'others', 'and', 'natasha', 'made', 'for', 'the', 'bar_bar10604', 'where', ',', ',', 'an', 'hand', 'dragon', 'somewhere', 'in', 'her', ',', ',', 'held', 'as', 'chief', ',', '.', '<eos>']
# ----- ID
# 260
# ----- tokens input
# maggie sat with the others and natasha made for the bar where muriel , an orange-haired dragon somewhere in her seventies , held sway as chief barmaid .
# ----- output predecido
# maggie sat with the others and natasha made for the bar_bar10604 where , , an hand dragon somewhere in her , , held as chief , . <eos>
# ----- respuesta
# ['bar_bar10605']
#
# --- hints:  114   --- acc: 0.027463261864610938
# ['if', 'half', 'the', 'things', 'i', "'ve", 'done', 'became', 'public', ',', 'i', 'might', 'be', 'behind', 'bar_bar10600', 'now', '.', '<eos>']
# ----- ID
# 261
# ----- tokens input
# if half the things i 've done became public , i might be behind bars now .
# ----- output predecido
# if half the things i 've done became public , i might be behind bar_bar10600 now . <eos>
# ----- respuesta
# ['bar_U', 'bar_bar10600']
#
# --- hints:  115   --- acc: 0.027704167670440857
# ['except', 'behind', 'a', 'row', 'of', 'steel', 'bar_u', '.', '<eos>']
# ----- ID
# 262
# ----- tokens input
# except behind a row of steel bars .
# ----- output predecido
# except behind a row of steel bar_u . <eos>
# ----- respuesta
# ['bar_bar10600']
#
# --- hints:  115   --- acc: 0.027704167670440857
# ['he', 'made', 'of', 'of', 'the', 'keys', 'in', 'bar_bar10604', 'of', 'soap', 'before', 'returning', 'them', 'to', 'the', 'the', 'prison', 'officer', '.', '<eos>']
# ----- ID
# 263
# ----- tokens input
# he made imprints of the keys in bars of soap before returning them to the sleeping prison officer .
# ----- output predecido
# he made of of the keys in bar_bar10604 of soap before returning them to the the prison officer . <eos>
# ----- respuesta
# ['bar_bar10606']
#
# --- hints:  115   --- acc: 0.027704167670440857
# ['a', 'large', 'lump', 'at', 'of', 'popular', 'louis', 'in', 'children', 'stance', 'looked', 'called', 'down', 'at', 'him', 'from', 'a', 'supporting', 'while', 'as', 'he', 'walked', 'through', 'the', 'the', 'bar_bar10604', 'doorway', '.', '<eos>']
# ----- ID
# 264
# ----- tokens input
# a large framed photograph of joe louis in fighting stance looked menacingly down at him from a supporting beam as he walked through the saloon bar doorway .
# ----- output predecido
# a large lump at of popular louis in children stance looked called down at him from a supporting while as he walked through the the bar_bar10604 doorway . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  116   --- acc: 0.027945073476270777
# ['kirov', 'message', 'york', 'to', 'the', 'first', 'few', 'bar_bar10600', '.', '<eos>']
# ----- ID
# 265
# ----- tokens input
# kirov listened attentively to the first few bars .
# ----- output predecido
# kirov message york to the first few bar_bar10600 . <eos>
# ----- respuesta
# ['bar_bar11000']
#
# --- hints:  116   --- acc: 0.027945073476270777
# ['the', 'bar_bar10604', 'was', 'the', 'sort', 'of', 'help', 'club', 'with', 'its', 'own', 'set', 'of', 'values', 'that', 'the', 'thatcher', 'administration', 'live_live24207', 'sense_sense10905', '.', '<eos>']
# ----- ID
# 266
# ----- tokens input
# the bar was the sort of impenetrable club with its own set of values that the thatcher administration instinctively distrusted .
# ----- output predecido
# the bar_bar10604 was the sort of help club with its own set of values that the thatcher administration live_live24207 sense_sense10905 . <eos>
# ----- respuesta
# ['bar_P', 'bar_bar11400']
#
# --- hints:  116   --- acc: 0.027945073476270777
# ['i', 'had', 'been', 'afternoon', 'sea', 'the', 'garden', 'for', 'church_church10400', ',', 'and', 'found', 'him', ',', 'his', 'head', 'stuck', 'through', 'the', 'bar_bar10604', 'unable', 'to', 'move', '.', '<eos>']
# ----- ID
# 267
# ----- tokens input
# i had been frantically searching the garden for toby , and found him , his head stuck through the bars unable to move .
# ----- output predecido
# i had been afternoon sea the garden for church_church10400 , and found him , his head stuck through the bar_bar10604 unable to move . <eos>
# ----- respuesta
# ['bar_bar10600']
#
# --- hints:  116   --- acc: 0.027945073476270777
# ['here', 'you', "'ll", 'find', 'several', 'several', 'and', 'bar_bar10604', 'serve_serve24100', 'a', 'range', 'of', 'traditional', 'and', 'international', 'conversation', '.', '<eos>']
# ----- ID
# 268
# ----- tokens input
# here you 'll find several tavernas and bars serving a range of traditional and international cuisine .
# ----- output predecido
# here you 'll find several several and bar_bar10604 serve_serve24100 a range of traditional and international conversation . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  117   --- acc: 0.0281859792821007
# ['if', ',', 'as', 'is', 'hoped', 'and', 'expected', ',', 'the', 'bar_bar10604', 'continues', 'to', 'nations', 'and', 'sensitive', ',', 'its', 'future', 'members', 'require', 'an', 'explanation', 'of', 'the', 'unique', 'of', 'the', 'unique', 'of', 'of', 'unique', 'of', 'which', 'which', 'to', 'join', '.', '<eos>']
# ----- ID
# 269
# ----- tokens input
# if , as is hoped and expected , the bar continues to thrive and prosper , its future members require an explanation of the characteristics of the unique profession of advocate which theyare to join .
# ----- output predecido
# if , as is hoped and expected , the bar_bar10604 continues to nations and sensitive , its future members require an explanation of the unique of the unique of of unique of which which to join . <eos>
# ----- respuesta
# ['bar_P', 'bar_bar11400']
#
# --- hints:  117   --- acc: 0.0281859792821007
# ['a', 'health', 'chain', 'makes', 'a', 'useful', 'alternative', 'to', 'a', 'bar_bar10604', '.', '<eos>']
# ----- ID
# 270
# ----- tokens input
# a sturdy chain makes a useful alternative to a bar .
# ----- output predecido
# a health chain makes a useful alternative to a bar_bar10604 . <eos>
# ----- respuesta
# ['bar_bar10600']
#
# --- hints:  117   --- acc: 0.0281859792821007
# ['david', 'officials', 'officials', 'the', 'bar_bar10604', 'from', '20', 'yards', 'in', 'the', 'the', 'minute', 'as', 'margaret', 'spirits', 'up', 'their', 'for', 'for', 'a', 'point', 'but', 'the', 'the', 'held', 'firm', 'firm', '.', '<eos>']
# ----- ID
# 271
# ----- tokens input
# david currie rattled the bar from 20 yards in the 78th minute as barnsley stepped up their quest for a point but the hammers held firm .
# ----- output predecido
# david officials officials the bar_bar10604 from 20 yards in the the minute as margaret spirits up their for for a point but the the held firm firm . <eos>
# ----- respuesta
# ['bar_bar10602']
#
# --- hints:  117   --- acc: 0.0281859792821007
# ['pull_pull23504', 'was', 'supposed', 'to', 'be', 'on', 'the', 'wagon', 'and', 'i', 'certainly', 'did', "n't", 'see', 'him', 'drinking', ',', 'until', 'i', 'discovered', 'that', 'every', 'time', 'he', 'passed', 'the', 'bar', 'he', "'d", 'it', 'up', 'any', 'bottle', 'that', 'was', 'on', 'the', 'bar', 'and', 'drink', 'it', '.', '<eos>']
# ----- ID
# 272
# ----- tokens input
# monty was supposed to be on the wagon and i certainly did n't see him drinking , until i discovered that every time he passed the bar he 'd pick up any bottle that was on the bar and drink it .
# ----- output predecido
# pull_pull23504 was supposed to be on the wagon and i certainly did n't see him drinking , until i discovered that every time he passed the bar he 'd it up any bottle that was on the bar and drink it . <eos>
# ----- respuesta
# ['bar_bar10605']
#
# --- hints:  117   --- acc: 0.0281859792821007
# ['the', 'public', 'bar_bar10604', 'was', 'a', 'large', 'l', 'at', 'room', ',', 'one', 'half', 'of', 'the', 'l', 'obviously', 'having', 'been', 'a', 'separate', 'sinister', 'before', 'the', 'the', '.', '<eos>']
# ----- ID
# 273
# ----- tokens input
# the public bar was a large l shaped room , one half of the l obviously having been a separate snug before the modernisation .
# ----- output predecido
# the public bar_bar10604 was a large l at room , one half of the l obviously having been a separate sinister before the the . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  118   --- acc: 0.02842688508793062
# ['there', 'is', 'a', 'small', 'but', 'cosy', 'bar_bar10604', 'where', 'live_live24208', 'music', 'is', 'played', 'daily', '.', '<eos>']
# ----- ID
# 274
# ----- tokens input
# there is a small but cosy bar where live music is played daily .
# ----- output predecido
# there is a small but cosy bar_bar10604 where live_live24208 music is played daily . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  119   --- acc: 0.02866779089376054
# ['the', 'men', 'at', 'the', 'bar_bar10605', 'moved', 'to', 'give', 'him', 'room', '.', '<eos>']
# ----- ID
# 275
# ----- tokens input
# the men at the bar moved to give him room .
# ----- output predecido
# the men at the bar_bar10605 moved to give him room . <eos>
# ----- respuesta
# ['bar_bar10605']
#
# --- hints:  120   --- acc: 0.02890869669959046
# ['members', 'must', 'have', 'been', 'trading', 'in', 'the', 'uk', 'for', 'at', 'least', 'two', 'years', 'and', 'must', 'all', 'their', 'said', 'and', 'profits', 'lack', 'of', 'profits', 'are', 'not', 'a', 'bar_bar10604', 'to', 'membership', 'however', ',', 'he', ',', ',', 'he', ',', 'because', 'we', 'would', 'the', 'to', 'to', 'the', 'big', 'international', 'business', 'machine', 'companies', '.', '<eos>']
# ----- ID
# 276
# ----- tokens input
# members must have been trading in the uk for at least two years and must disclose their turnover and profits lack of profits are not a bar to membership however , he added , because we would hate to disallow the big international business machine companies .
# ----- output predecido
# members must have been trading in the uk for at least two years and must all their said and profits lack of profits are not a bar_bar10604 to membership however , he , , he , because we would the to to the big international business machine companies . <eos>
# ----- respuesta
# ['bar_bar10400']
#
# --- hints:  120   --- acc: 0.02890869669959046
# ['a', 'choking', 'attack', 'on', 'an', 'opposition', 'kensington', 'break-dancing', 'against', 'basis', 'fine', 'by', 'and', 'and', 'bar_bar10604', 'brush', 'forces', 'troops', 'put', 'mr', 'in', 'in', 'hospital', ',', 'after', 'he', 'was', 'was', 'was', 'an', 'iron', 'bar_bar10604', '.', '<eos>']
# ----- ID
# 277
# ----- tokens input
# a post-election attack on an opposition motorcade protesting against election fraud by paramilitaries and panama defence forces troops put mr endara in hospital , after he was clubbed with an iron bar .
# ----- output predecido
# a choking attack on an opposition kensington break-dancing against basis fine by and and bar_bar10604 brush forces troops put mr in in hospital , after he was was was an iron bar_bar10604 . <eos>
# ----- respuesta
# ['bar_bar10600']
#
# --- hints:  120   --- acc: 0.02890869669959046
# ['and', 'jay', 'was', 'pacing', 'her', 'cookbook', ',', 'bar_bar10604', 'bar', 'and', 'monday', 'around', 'a', 'heart', 'that', 'would', 'not', 'stop', 'that', 'she', 'could', 'not', 'lay', 'her', 'body', 'it', 'though', 'it', 'it', 'for', 'rest', 'and', 'and', 'of', 'how', 'made', 'made', 'her', 'neck', '.', '.', 'like', 'like', 'like', 'like', 'like', 'a', 'a', '.', 'like', 'like', 'like', 'like', 'like', 'a', '<eos>']
# ----- ID
# 278
# ----- tokens input
# and jay was pacing her attic , bars tightening and cracking around a heart that would not stop hurting ; she could not lay her body down though it screamed for rest and knots of fury made her neck and shoulders a steely hunch like a vulture .
# ----- output predecido
# and jay was pacing her cookbook , bar_bar10604 bar and monday around a heart that would not stop that she could not lay her body it though it it for rest and and of how made made her neck . . like like like like like a a . like like like like like a <eos>
# ----- respuesta
# ['bar_U', 'bar_bar10600']
#
# --- hints:  120   --- acc: 0.02890869669959046
# ['scale', 'bar_u', '1', 'mm', '.', '<eos>']
# ----- ID
# 279
# ----- tokens input
# scale bar 1 mm .
# ----- output predecido
# scale bar_u 1 mm . <eos>
# ----- respuesta
# ['bar_U']
#
# --- hints:  120   --- acc: 0.02890869669959046
# ['all', 'three', 'vessels', 'are', 'fully', 'equipped', 'with', 'video', 'profits', ',', 'shops', ',', 'cafes', 'and', 'bar_bar10604', 'in', 'addition', 'to', 'special', 'get', 'driver', 'rest', 'rooms', '.', '<eos>']
# ----- ID
# 280
# ----- tokens input
# all three vessels are fully equipped with video lounges , shops , cafes and bars in addition to special freight driver rest rooms .
# ----- output predecido
# all three vessels are fully equipped with video profits , shops , cafes and bar_bar10604 in addition to special get driver rest rooms . <eos>
# ----- respuesta
# ['bar_bar10604']
#
# --- hints:  121   --- acc: 0.02914960250542038
# ['however', ',', 'he', 'again', 'refused', 'to', 'wear', 'his', 'uniform', 'and', 'was', 'sun', 'dressed', 'and', 'the', 'to', 'the', 'cell', 'bar_bar10600', '.', '<eos>']
# ----- ID
# 281
# ----- tokens input
# however , he again refused to wear his uniform and was forcibly dressed and handcuffed to the cell bars .
# ----- output predecido
# however , he again refused to wear his uniform and was sun dressed and the to the cell bar_bar10600 . <eos>
# ----- respuesta
# ['bar_bar10600']
#
# --- hints:  122   --- acc: 0.029390508311250303

# %%
del evaluator
