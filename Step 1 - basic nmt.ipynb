# %%
from data import generate_batches
from data import prepare_data

from model.encoder import Encoder
from model.decoder import Decoder_luong

from BLEU import BLEU

from utils import time_since


from evaluator_dis import Evaluator

import torch
import torch.nn as nn
from torch.nn import functional
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

import numpy as np
import time
import random
import os
#from validation import Evaluator

# %load_ext autoreload
# %autoreload 2

# %%
USE_CUDA = True
MAX_LENGTH = 100
DIR_FILES = 'data/disambiguation/sense-eval2/'
DIR_TRAIN = os.path.join(DIR_FILES, 'train')
DIR_TEST = os.path.join(DIR_FILES, 'test')
DIR_RESULTS = 'results/step_1'
SPLIT_TRAIN = 0.7
SPLIT_VALID = 0.15
# The rest is for test

# %% [markdown]
# # Reading the data

# %%
input_lang, output_lang, pairs = prepare_data('en', 'spa', max_length=MAX_LENGTH, dir=DIR_TRAIN)
# Out:
# Reading lines...
# Read 9080 sentence pairs
# Filtered to 9058 pairs
# Creating vocab...
# Indexed 23115 words in input language, 23811 words in output

# %%
pairs_train = np.array(pairs)
pairs_test = read_test(DIR_TEST)

# %% [markdown]
# # Train

# %%
def train(input_batches, target_batches, \
          encoder, decoder, encoder_optimizer, decoder_optimzier, \
          criterion, max_length=MAX_LENGTH, train=True):
    
    if train:
        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()
        
    loss = 0
    
    batch_size = input_batches.size()[1]
    
    encoder_hidden = encoder.init_hidden(batch_size)
    encoder_outputs, encoder_hidden = encoder(input_batches, encoder_hidden)
    
    decoder_context = Variable(torch.zeros(batch_size, decoder.hidden_size))   
    decoder_hidden = encoder_hidden
    
    # set the start of the sentences of the batch
    decoder_input = Variable(torch.LongTensor([input_lang.vocab.stoi['<sos>']] * batch_size))

    # store the decoder outputs to estimate the loss
    all_decoder_outputs = Variable(torch.zeros(target_batches.size()[0], batch_size, len(output_lang.vocab.stoi)))
    
    if USE_CUDA:
        decoder_input = decoder_input.cuda()
        all_decoder_outputs = all_decoder_outputs.cuda()
        decoder_context = decoder_context.cuda()  
    
    if train:
        use_teacher_forcing = random.random() < teacher_forcing_ratio
    else:
        use_teacher_forcing = False

    if use_teacher_forcing:        
        # Use targets as inputs
        for di in range(target_batches.shape[0]):
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
                decoder_input.unsqueeze(0), decoder_context, decoder_hidden, encoder_outputs)

            all_decoder_outputs[di] = decoder_output
            decoder_input = target_batches[di]
    else:        
        # Use decoder output as inputs
        for di in range(target_batches.shape[0]):            
            decoder_output, decoder_context, decoder_hidden, decoder_attention = decoder(
                decoder_input.unsqueeze(0), decoder_context, decoder_hidden, encoder_outputs) 

            all_decoder_outputs[di] = decoder_output
            
            # Greedy approach, take the word with highest probability
            topv, topi = decoder_output.data.topk(1)            
            decoder_input = Variable(torch.LongTensor(topi.cpu()).squeeze())
            if USE_CUDA: decoder_input = decoder_input.cuda()
    
    loss = nn.NLLLoss()(all_decoder_outputs.view(-1, decoder.output_size), target_batches.contiguous().view(-1))          
    
    if train:
        loss.backward()
        torch.nn.utils.clip_grad_norm_(encoder.parameters(), clip)
        torch.nn.utils.clip_grad_norm_(decoder.parameters(), clip)
        encoder_optimizer.step()
        decoder_optimizer.step()
    
    return loss.item()

# %% [markdown]
# # Model

# %%
attn_model = 'general'
hidden_size = 1024
emb_size = 300
n_layers = 2
seed = 12
dropout_p = 0.1
teacher_forcing_ratio = 0.5
clip = 5.0

n_epochs = 40
batch_size = 100

# %%
torch.manual_seed(seed)
np.random.seed(seed)

# %%
encoder = Encoder(len(input_lang.vocab.stoi), hidden_size, emb_size, n_layers, dropout_p, input_lang, USE_CUDA)
decoder = Decoder_luong(attn_model, hidden_size, len(output_lang.vocab.stoi), emb_size, 2 * n_layers, dropout_p, output_lang, USE_CUDA)

if USE_CUDA:
    encoder = encoder.cuda()
    decoder = decoder.cuda()
    
learning_rate = 0.001
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()

# %%
# Keep track of time elapsed and running averages
start = time.time()
train_losses = []
validation_losses = []
validation_acc = []

plot_every = 5
print_every = 5
validate_loss_every = 25
best_acc = 0
print_loss_total = 0 # Reset every print_every
plot_loss_total = 0 # Reset every plot_every

# %%
for epoch in range(1, n_epochs): 
    # Shuffle data
    id_aux = np.random.permutation(np.arange(len(pairs_train)))
    pairs_train = pairs_train[id_aux]
    
    # Get the batches for this epoch
    input_batches, target_batches = generate_batches(input_lang, output_lang, batch_size, pairs_train, USE_CUDA=USE_CUDA)
    print_loss_total = 0
    
    for batch_ix, (input_var, target_var) in enumerate(zip(input_batches, target_batches)):
        encoder.train()
        decoder.train()

        #[input_var, _, _, _, _, _, _, _] = input_batch

        # Run the train function
        loss = train(input_var, target_var,\
                 encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, 
                 max_length=MAX_LENGTH, train=True)
        #loss = train_luong(input_var, target_var, input_var.size(1), True)
            
        torch.cuda.empty_cache()

        # Keep track of loss
        print_loss_total += loss
        plot_loss_total += loss

        if batch_ix == 0: continue

        if batch_ix % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print_summary = '%s (%d %d%%) %.4f' % (time_since(start, epoch / n_epochs), epoch, batch_ix / len(input_batches) * 100, print_loss_avg)
            train_losses.append(loss)
            print(print_summary)
    
    #input_batches, target_batches = generate_batches(input_lang, output_lang, batch_size, pairs_test, USE_CUDA=USE_CUDA)
    #print_loss_total = 0
    encoder.eval()
    decoder.eval()
    #for input_batch, target_var in zip(input_batches, target_batches):
    
    #    encoder.eval()
    #    decoder.eval()
    
    #    #[input_var, _, _, _, _, _, _, _] = input_batch
    #    input_var = input_batch
    #    # Run the train function
    #    loss = train(input_var, target_var,\
    #             encoder, decoder, encoder_optimizer, decoder_optimizer, criterion,\
    #             max_length=MAX_LENGTH, train=False)
        
    #    print_loss_total += loss
    #val_loss = print_loss_total / len(input_batches)
    #validation_losses.append(val_loss)
    # Evaluating acc
    evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
    acc = evaluator.evaluate_acc(pairs_test, k_beams=1)
    if acc > best_acc:
        best_acc = acc
        torch.save(encoder.state_dict(), f'{DIR_RESULTS}/encoder.pkl')
        torch.save(decoder.state_dict(), f'{DIR_RESULTS}/decoder.pkl')
        print('Saving weights')
    validation_acc.append(acc)
    print(f'------------- acc: {acc}')

    # Prevent overflow gpu memory
    del evaluator
# Out:
# /home/krivas/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# 4154m 33s (- 6231m 50s) (16 5%) 0.2855
# 4154m 40s (- 6232m 0s) (16 10%) 0.2224
# 4154m 47s (- 6232m 11s) (16 16%) 0.1910
# 4154m 55s (- 6232m 22s) (16 21%) 0.2061
# 4155m 2s (- 6232m 33s) (16 27%) 0.2113
# 4155m 10s (- 6232m 45s) (16 32%) 0.1890
# 4155m 18s (- 6232m 57s) (16 38%) 0.0859
# 4155m 25s (- 6233m 8s) (16 43%) 0.3058
# 4155m 33s (- 6233m 19s) (16 49%) 0.1012
# 4155m 39s (- 6233m 29s) (16 54%) 0.1621
# 4155m 46s (- 6233m 40s) (16 60%) 0.2343
# 4155m 53s (- 6233m 50s) (16 65%) 0.1759
# 4156m 2s (- 6234m 4s) (16 71%) 0.2482
# 4156m 9s (- 6234m 14s) (16 76%) 0.1244
# 4156m 16s (- 6234m 25s) (16 82%) 0.1531
# 4156m 24s (- 6234m 36s) (16 87%) 0.2695
# 4156m 33s (- 6234m 49s) (16 93%) 0.2628
# 4156m 38s (- 6234m 58s) (16 98%) 0.1589
# ------------- acc: 0.2500602264514575
# 4160m 8s (- 5628m 25s) (17 5%) 0.1273
# 4160m 15s (- 5628m 34s) (17 10%) 0.2639
# 4160m 22s (- 5628m 45s) (17 16%) 0.1893
# 4160m 30s (- 5628m 54s) (17 21%) 0.2094
# 4160m 37s (- 5629m 4s) (17 27%) 0.1812
# 4160m 44s (- 5629m 14s) (17 32%) 0.0738
# 4160m 51s (- 5629m 23s) (17 38%) 0.1822
# 4161m 0s (- 5629m 35s) (17 43%) 0.0934
# 4161m 7s (- 5629m 45s) (17 49%) 0.1094

# %%
epoch
# Out:
# 16

# %%
evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
acc = evaluator.evaluate_acc(pairs_test, k_beams=1, verbose=True)
# Out:
# /home/krivas/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py:995: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# ['gametocide', '_', 'is', 'an', 'an', 'example', '.', '<eos>']
# ----- ID
# 0
# ----- tokens input
# Pop Art is an example .
# ----- output predecido
# gametocide _ is an an example . <eos>
# ----- respuesta
# ['art_pop_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['and', 'and', 'authority', 'art', '_', 'art10400', 'funding', 'and', 'organisation', '.', '<eos>']
# ----- ID
# 1
# ----- tokens input
# Reform and decentralise arts funding and organisation .
# ----- output predecido
# and and authority art _ art10400 funding and organisation . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['mostbrokers', 'ever', 'notice', 'how', 'all', 'art', '_', 'art10400', 'issues', 'on', 'people', 'in', 'trouble', '.', '<eos>']
# ----- ID
# 2
# ----- tokens input
# You ever notice how all art focuses on people in trouble .
# ----- output predecido
# mostbrokers ever notice how all art _ art10400 issues on people in trouble . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['buoncamino', 'books', 'and', 'classes', 'teach', 'the', 'art', '_', 'art10900', 'of', 'formulate', 'mankind', 'and', ',', 'if', 'you', 'want', 'to', 'know', 'more', ',', 'turn', 'to', 'page', 'siddo', '.', '<eos>']
# ----- ID
# 3
# ----- tokens input
# Countless books and classes teach the art of asserting oneself and , if you want to know more , turn to page 120 .
# ----- output predecido
# buoncamino books and classes teach the art _ art10900 of formulate mankind and , if you want to know more , turn to page siddo . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['b-box', 'your', 'usual', ',', ',', 'who', 'probably', 'wo', "n't", 'have', 'the', 'room', 'or', 'the', 'reason', 'for', 'for', 'unusual', 'papers', 'or', 'cards', ',', 'and', 'go', 'to', 'a', 'specialist', 'art', '_', 'art10400', 'or', 'paper', 'shop', 'instead', '.', '<eos>']
# ----- ID
# 4
# ----- tokens input
# Forsake your usual stationer , who probably wo n't have the room or the reason for stocking unusual papers or cards , and go to a specialist art or paper shop instead .
# ----- output predecido
# b-box your usual , , who probably wo n't have the room or the reason for for unusual papers or cards , and go to a specialist art _ art10400 or paper shop instead . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['piepsam', 'was', 'born', 'in', 'in', ',', 'in', ',', 'in', 'in', 'and', 'and', 'taught', 'at', 'the', 'the', 'the', 'for', 'for', 'for', 'for', 'for', ',', ',', ',', ',', 'in', 'in', 'before', 'he', 'went', 'to', 'study', 'art', '_', 'at', 'at', 'the', 'the', 'the', 'the', ',', ',', ',', ',', ',', 'and', 'at', 'at', 'the', 'the', 'the', 'from', 'from', 'from', '.', '<eos>']
# ----- ID
# 5
# ----- tokens input
# Thomson was born in Bangalore , India , in 1894 and was educated at the Royal School for Deaf Children , Margate , in England before he went to study art at the London Art School , Kensington , and exhibited at the Royal Academy from 1920 .
# ----- output predecido
# piepsam was born in in , in , in in and and taught at the the the for for for for for , , , , in in before he went to study art _ at at the the the the , , , , , and at at the the the from from from . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['rosiedied', ',', 'mathematics', ',', 'a', 'foreign', 'language', ',', ',', ',', 'the', 'fujitsu', ',', 'history', ',', ',', ',', 'some', 'art', '_', 'art10400', 'and', 'art', ',', 'but', 'not', 'too', 'much', ',', ',', 'and', 'but', 'not', 'too', 'much', ',', 'and', 'and', 'games', ',', 'the', ',', 'religious', 'education', '.', '<eos>']
# ----- ID
# 6
# ----- tokens input
# English , mathematics , a foreign language , Latin , the sciences , history , geography , some art and crafts , but not too much , PE and games , the compulsory religious education .
# ----- output predecido
# rosiedied , mathematics , a foreign language , , , the fujitsu , history , , , some art _ art10400 and art , but not too much , , and but not too much , and and games , the , religious education . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['recently', 'has', 'been', 'develop', 'especially', 'with', 'the', 'art', '_', 'arts10900', ',', 'and', 'thus', 'in', 'recent', 'years', 'has', 'been', 'increasingly', 'established', '.', '<eos>']
# ----- ID
# 7
# ----- tokens input
# Imagination has been associated especially with the arts , and thus in recent years has been increasingly downgraded .
# ----- output predecido
# recently has been develop especially with the art _ arts10900 , and thus in recent years has been increasingly established . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['house-senate', 'did', ',', 'however', ',', 'manage', 'to', 'get', 'a', 'grant', 'from', 'the', '_', '_', '_', '_', '_', '_', '_', '<eos>']
# ----- ID
# 8
# ----- tokens input
# Leonard did , however , manage to get a grant from the Canadian Arts Council .
# ----- output predecido
# house-senate did , however , manage to get a grant from the _ _ _ _ _ _ _ <eos>
# ----- respuesta
# ['art_P', 'art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['interwiring', 'the', 'art', 'art', '_', 'art10400', 'who', 'who', 'a', 'a', "'s", "'s", 'with', 'a', 'spray', 'can', '.', '<eos>']
# ----- ID
# 9
# ----- tokens input
# Or the Iranian art merchant who once defaced Picasso 's Guernica with a spray can .
# ----- output predecido
# interwiring the art art _ art10400 who who a a 's 's with a spray can . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['nail-biting', 'read', 'publications', 'that', 'keep', 'them', '_', 'of', 'market', 'trends', ',', 'telegraph', ',', 'violations', 'and', 'prices', 'rather', 'than', 'and', 'into', 'art', '_', 'art10400', 'history', 'as', 'do', 'their', 'counterparts', 'history', 'as', 'do', 'their', 'counterparts', 'in', 'in', '.', '<eos>']
# ----- ID
# 10
# ----- tokens input
# They read publications that keep them abreast of market trends , personalities , lawsuits and prices rather than delving into art history as do their counterparts in Europe .
# ----- output predecido
# nail-biting read publications that keep them _ of market trends , telegraph , violations and prices rather than and into art _ art10400 history as do their counterparts history as do their counterparts in in . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['formally', ',', 'health', 'consists', 'of', 'art', '_', 'art10400', 'materials', 'is', 'common', 'in', 'the', 'in', ',', ',', 'though', 'not', ',', 'as', 'yet', ',', 'in', 'this', 'country', '.', '<eos>']
# ----- ID
# 11
# ----- tokens input
# highlighted , health labelling of art materials is obligatory in the United States , though not , as yet , in this country .
# ----- output predecido
# formally , health consists of art _ art10400 materials is common in the in , , though not , as yet , in this country . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['emailinc', 'love', 'what', "'s", "'m", 'doing', 'for', 'for', 'two', 'things', 'that', "n't", 'do', 'think', 'about', ',', 'one', 'is', 'becoming', 'an', 'actress', 'and', 'the', 'other', 'is', 'going', 'to', 'university', 'to', 'study', 'art', '_', 'art10400', 'history', 'history', 'history', 'history', '.', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', 'art', '<eos>']
# ----- ID
# 12
# ----- tokens input
# I love what I 'm doing for Revlon but there are two things that I do think about , one is becoming an actress and the other is going to university to study art history .
# ----- output predecido
# emailinc love what 's 'm doing for for two things that n't do think about , one is becoming an actress and the other is going to university to study art _ art10400 history history history history . art art art art art art art art art art art art art art <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'see', 'art', '_', 'art10400', 'that', "'s", 'created', 'by', 'people', 'who', 'are', 'killing', 'themselves', 'making', 'it', ',', 'and', 'it', 'always', 'wonder', 'how', 'it', 'would', 'turn', 'out', 'if', 'they', 'were', "n't", 'doing', 'that', '.', '<eos>']
# ----- ID
# 13
# ----- tokens input
# You see art that 's created by people who are killing themselves making it , and I always wonder how it would turn out if they were n't doing that .
# ----- output predecido
# drillien see art _ art10400 that 's created by people who are killing themselves making it , and it always wonder how it would turn out if they were n't doing that . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['interwiring', 'phases', 'the', 'ancient', 'art', 'of', 'of', 'stress', '_', 'u', '.', '<eos>']
# ----- ID
# 14
# ----- tokens input
# Mel Yates the ancient art of beating stress .
# ----- output predecido
# interwiring phases the ancient art of of stress _ u . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['conference', 'in', 'begin', 'ended', 'and', 'cd-rom', 'meet', 'at', 'the', 'at', '24', "'s", "'s", 'annual', 'conference', 'of', 'the', 'of', 'of', 'at', 'will', 'will', 'meet', 'at', 'the', 'at', 'the', 'this', 'year', 'from', '2', 'to', '4', '_', 'p', 'to', '4', 'to', '.', '<eos>']
# ----- ID
# 15
# ----- tokens input
# conference in Seattle 46 February and Britons meet at the Tate 24 April The annual conference of the Association of Art Historians will meet at the Tate Gallery this year from 2 to 4 April .
# ----- output predecido
# conference in begin ended and cd-rom meet at the at 24 's 's annual conference of the of of at will will meet at the at the this year from 2 to 4 _ p to 4 to . <eos>
# ----- respuesta
# ['art_P', 'art_art_historian11800']
#
# --- hints:  0   --- acc: 0.0
# ['replacing', 'will', 'no', 'doubt', 'of', 'of', 'of', 'shock', 'tactics', 'along', ',', 'lines', ',', 'but', '_', 'merely', 'the', 'view', 'the', 'view', 'that', 'component', 'and', 'installation', 'art', '_', 'art10400', 'are', 'at', 'their', 'at', 'when', 'issues', 'social', 'or', 'political', 'issues', '.', '<eos>']
# ----- ID
# 16
# ----- tokens input
# Some will no doubt accuse Jarman of shock tactics along Warhol lines , but Jarman has reinforced the view that performance and installation art are at their strongest when addressing social or political issues .
# ----- output predecido
# replacing will no doubt of of of shock tactics along , lines , but _ merely the view the view that component and installation art _ art10400 are at their at when issues social or political issues . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['vital', 'main', 'vital50000indispensable00', 'is', 'the', 'treat23100', 'of', 'gametocide', 'gametocide', 'by', '_', 'see23902', 'included', 'in', 'the', 'latter', 'stages', 'a', 'group', 'with', 'which', 'with', 'and', 'and', 'which', 'been', 'have', 'have', 'involved', 'involved', '.', '<eos>']
# ----- ID
# 17
# ----- tokens input
# My main gripe is the surfeit of turgid waffle by Art Language included in the latter stages a group with which Harrison and Wood have been intimately involved .
# ----- output predecido
# vital main vital50000indispensable00 is the treat23100 of gametocide gametocide by _ see23902 included in the latter stages a group with which with and and which been have have involved involved . <eos>
# ----- respuesta
# ['art_P', 'art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['r1', 'f10', 'demonstrated', '_', 'work23601', 'enormously', 'from', 'from', 'from', 'single-cell', ',', ',', ',', 'ancient', ',', ',', 'traditions', ',', 'traditions', 'art', 'and', 'so', 'on', '.', '<eos>']
# ----- ID
# 18
# ----- tokens input
# Even Kasmin Ltd diversified enormously from 198590 into antiquities , neolithic , ancient Eskimo , tribal art and so on .
# ----- output predecido
# r1 f10 demonstrated _ work23601 enormously from from from single-cell , , , ancient , , traditions , traditions art and so on . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'state', 'of', 'the', 'pocketfamily', "'s", 'art', 'is', 'now', 'such', 'that', 'the', 'choice', 'of', 'instrument', 'to', 'use', '_', 'use23401', 'depends', 'largely', 'on', 'what', 'he', 'wants', 'to', 'see', ',', 'and', 'in', 'some', 'applications', 'the', 'the', 'the', 'may', 'give', 'him', 'the', 'the', 'thought', 'be', '.', '<eos>']
# ----- ID
# 19
# ----- tokens input
# The state of the microscopist 's art is now such that the choice of instrument to use depends largely on what he wants to see , and in some applications the acoustic microscope may give him the sharpest pictures ever .
# ----- output predecido
# drillien state of the pocketfamily 's art is now such that the choice of instrument to use _ use23401 depends largely on what he wants to see , and in some applications the the the may give him the the thought be . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['gatoil', "'s", 'a', 'a', "'s", "'s", 'progress', ';', 'a', 'subdued', 'progression', 'meditation', 'on', 'the', 'the', 'culture', 'of', 'male', 'of', 'and', 'the', 'and', 'art', '_', 'art10900', 'of', 'the', 'deal', '.', '<eos>']
# ----- ID
# 20
# ----- tokens input
# It 's a sardonic pilgrim 's progress ; a furiously lyrical meditation on the corrupt culture of male glory and the parasitical art of the deal .
# ----- output predecido
# gatoil 's a a 's 's progress ; a subdued progression meditation on the the culture of male of and the and art _ art10900 of the deal . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['somescientists', 'such', 'studies', 'have', 'reflect', 'every', 'form', 'of', 'art', '_', 'art10400', 'in', 'some', 'way', '.', '<eos>']
# ----- ID
# 21
# ----- tokens input
# All such studies have influenced every form of art in some way .
# ----- output predecido
# somescientists such studies have reflect every form of art _ art10400 in some way . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ["c'mon", 'will', 'she', 'go', 'and', 'nick', 'their', 'furniture', 'if', 'art', '_', 'p', 'does', "n't", 'pay', '.', '<eos>']
# ----- ID
# 22
# ----- tokens input
# So will she go and nick their furniture if art does n't pay .
# ----- output predecido
# c'mon will she go and nick their furniture if art _ p does n't pay . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['1', 'few', 'years', 'back', ',', 'you', 'could', 'not', 'get', 'young', 'women', 'to', 'be', 'active', ',', 'said', ',', 'an', 'organisation', 'of', 'the', 'women', 'the', 'the', ',', 'an', 'organisation', 'of', 'best', 'women', 'in', 'business', 'and', 'the', 'art', '_', 'art10400', '.', '<eos>']
# ----- ID
# 23
# ----- tokens input
# A few years back , you could not get young women to be active , said Judy Miller , president of the Los Angeles-based Trusteeship , an organisation of influential women in business and the arts .
# ----- output predecido
# 1 few years back , you could not get young women to be active , said , an organisation of the women the the , an organisation of best women in business and the art _ art10400 . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['interwiring', 'the', 'the', 'art', '_', 'art10400', 'to', 'the', 'fifth', 'floor', 'provided', 'room', 'adjacent', 'to', 'the', 'to', 'and', 'and', 'and', 'galleries', '.', '<eos>']
# ----- ID
# 24
# ----- tokens input
# Moving the Contemporary art to the fifth floor provided room adjacent to the American Painting and Sculpture galleries .
# ----- output predecido
# interwiring the the art _ art10400 to the fifth floor provided room adjacent to the to and and and galleries . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', 'claim', 'location', 'suggests', 'itself', 'to', 'strong', 'links', 'with', 'the', 'university', 'art', '_', 'p', 'and', 'and', 'and', 'am', 'confident', 'that', 'we', 'will', 'develop', 'exciting', 'together', 'in', 'all', 'areas', 'of', 'activity', '.', '<eos>']
# ----- ID
# 25
# ----- tokens input
# Our geographical location lends itself to strong links with the European arts infrastructure and I am confident that we will develop exciting initiatives in all areas of activity .
# ----- output predecido
# therecent claim location suggests itself to strong links with the university art _ p and and and am confident that we will develop exciting together in all areas of activity . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['fast-food', "'s", "'s", 'chic', 'guide', 'to', 'the', 'art', '_', 'p', ',', 'entertainment', ',', 'media', 'and', 'more', '.', '<eos>']
# ----- ID
# 26
# ----- tokens input
# Charivari Punch 's weekly guide to the arts , entertainment , media and more .
# ----- output predecido
# fast-food 's 's chic guide to the art _ p , entertainment , media and more . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['buoncamino', 'the', 'late', '16th', ',', "'s", 'penetrated', 'his', 'dope', 'and', 'set', 'off', 'as', 'a', 'travelling', 'career', 'on', 'behalf', 'of', 'the', 'gallery', 'to', 'the', ',', 'pilgrims', 'the', 'the', 'with', 'a', 'a', 'a', 'of', ',', ',', 'found', 'out', 'who', 'was', 'in', 'in', 'art', '_', 'p', 'from', 'the', 'local', 'museums', ',', 'and', 'taught', 'people', 'who', 'did', "n't", 'get', 'to', 'to', 'to', '.', '<eos>']
# ----- ID
# 27
# ----- tokens input
# In the late Sixties , Kasmin swallowed his pride and set off as a travelling salesman on behalf of the gallery to America , travelling the States with a bagful of transparencies , finding out who was interested in art from the local museums , and visiting people who did n't get to New York .
# ----- output predecido
# buoncamino the late 16th , 's penetrated his dope and set off as a travelling career on behalf of the gallery to the , pilgrims the the with a a a of , , found out who was in in art _ p from the local museums , and taught people who did n't get to to to . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['think', 'think', 'you', 'should', 'make', 'art', '_', 'art', '_', 'little', 'a', 'little', 'bit', 'more', 'alive', '.', '<eos>']
# ----- ID
# 28
# ----- tokens input
# I think you should make art a little bit more alive .
# ----- output predecido
# think think you should make art _ art _ little a little bit more alive . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['=', '_', 'see23800', '.', '<eos>']
# ----- ID
# 29
# ----- tokens input
# Contemporary Art Market .
# ----- output predecido
# = _ see23800 . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['buoncamino', 'pointed', 'out', 'by', 'the', 'collector', 'and', 'librarian', 'van', "'s", 'writing', 'in', 'in', ',', 'and', 'so', 'desires', 'known', 'has', 'only', 'to', 'go', 'to', 'to', 'to', 'the', 'the', 'art', '_', 'art10400', 'the', 'in', 'the', 'world', 'at', 'the', 'present', 'time', ';', 'there', 'he', 'may', 'see', 'at', 'the', 'beginning', 'of', 'a', 'strikingly', 'number', 'of', 'outstanding', 'and', 'precious', ',', ',', ',', 'rich', ',', 'very', 'and', 'works', 'and', 'works', 'works', 'works', 'works', ',', ',', ',', 'rich', ',', 'and', 'and', 'works', '.', '<eos>']
# ----- ID
# 30
# ----- tokens input
# As pointed out by the collector and historian van Mander writing in 1604 , Whoever so desires nowadays has only to go to Prague to the greatest art patron in the world at the present time ; there he may see at the Imperial residence a remarkable number of outstanding and precious , curious , unusual , and priceless works .
# ----- output predecido
# buoncamino pointed out by the collector and librarian van 's writing in in , and so desires known has only to go to to to the the art _ art10400 the in the world at the present time ; there he may see at the beginning of a strikingly number of outstanding and precious , , , rich , very and works and works works works works , , , rich , and and works . <eos>
# ----- respuesta
# ['art_art10600', 'art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['killpath', 'what', 'the', 'the', 'knew', 'then', 'that', 'the', 'the', 'was', 'secrecy', 'with', 'conservative', 'of', 'and', 'that', 'for', "n't", 'for', "n't", 'for', "n't", 'for', 'art', '_', 'art10400', 'they', 'can', 'be', 'have', 'seen', 'this', 'as', 'a', 'a', 'they', 'could', 'hand', 'to', 'a', 'big', 'a', 'a', 'a', 'as', 'of', 'star', 'star', 'star', 'or', ',', 'indeed', ',', 'to', 'anybody', 'to', 'to', 'leave', 'town', 'alive', '.', '<eos>']
# ----- ID
# 31
# ----- tokens input
# Knowing what the Bushmen knew then that the NEA was unpopular with conservative legislators and already the target of fundamentalist Christians for subsidising offensive art they can hardly have seen this as a plum they could hand to a big contributor or a rising political star or , indeed , to anybody aiming to leave town alive .
# ----- output predecido
# killpath what the the knew then that the the was secrecy with conservative of and that for n't for n't for n't for art _ art10400 they can be have seen this as a a they could hand to a big a a a as of star star star or , indeed , to anybody to to leave town alive . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', ',', 'if', 'not', 'all', ',', 'of', 'the', 'martial', 'art', '_', 'art10400', 'are', 'the', 'linked', 'to', 'the', 'three', 'main', 'provideda', '1966', 'hierarchy', ',', ',', ',', ',', 'and', 'and', 'and', 'and', '.', '<eos>']
# ----- ID
# 32
# ----- tokens input
# Most , if not all , of the martial arts are inextricably linked to the three main East Asian religions , Buddhism , Taoism and Confucianism .
# ----- output predecido
# therecent , if not all , of the martial art _ art10400 are the linked to the three main provideda 1966 hierarchy , , , , and and and and . <eos>
# ----- respuesta
# ['art_martial_art10400']
#
# --- hints:  0   --- acc: 0.0
# ["d'arcy", "'s", "'s", 'latest', 'work', 'of', 'art', '_', 'p', 'arrived', 'in', 'his', 'home', 'city', 'of', 'of', 'last', 'night', 'in', 'a', 'in', 'of', 'of', 'of', 'last', 'paper', 'and', 'sheets', 'of', 'calls', 'paper', ',', 'and', 'to', 'the', 'sound', 'of', 'of', "'s", 'of', 'of', 'the', 'of', '.', '<eos>']
# ----- ID
# 33
# ----- tokens input
# DAVID Hockney 's latest work of art arrived in his home city of Bradford last night in a welter of spray-on glue and sheets of fax paper , and to the sound of Wagner 's Ride of the Valkyries .
# ----- output predecido
# d'arcy 's 's latest work of art _ p arrived in his home city of of last night in a in of of of last paper and sheets of calls paper , and to the sound of of 's of of the of . <eos>
# ----- respuesta
# ['art_work_of_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['whereas', 'and', 'housing', 'tax-free', '65', '35', '_', '35', 'government', 'single-cell', 'fast-food', '30-second', 'single-cell', 'and', 'countryside', 'and', 'and', ',', 'sectors', 'and', 'and', 'environment', 'and', 'and', 'environment', 'and', 'and', 'environment', 'and', 'and', '.', '<eos>']
# ----- ID
# 34
# ----- tokens input
# Homes and housing 33 Transport 35 Local government 37 Cities 38 London 40 The countryside 40 Farming , forestry and fishing 41 The environment 43 TOWARDS THE MILLENNIUM Millennium Fund 44 Arts 44 .
# ----- output predecido
# whereas and housing tax-free 65 35 _ 35 government single-cell fast-food 30-second single-cell and countryside and and , sectors and and environment and and environment and and environment and and . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['broad-band', 'plan', 'is', 'to', 'convert', 'a', 'phase-out', 'factory', 'compound', 'into', 'the', 'world', "'s", 'largest', 'museum', 'of', 'art', 'international', 'art', '_', 'p', '.', '<eos>']
# ----- ID
# 35
# ----- tokens input
# The plan is to convert a twenty-eight-building factory compound into the world 's largest museum of post-1960 international art .
# ----- output predecido
# broad-band plan is to convert a phase-out factory compound into the world 's largest museum of art international art _ p . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['broad-band', 'is', 'this', 'feeling', 'only', 'the', 'by', 'the', 'sight', 'or', 'the', 'thought', 'of', 'art', '_', 'art10400', ',', 'he', 'wrote', '.', '<eos>']
# ----- ID
# 36
# ----- tokens input
# Nor is this feeling only provoked by the sight or the thought of art , he wrote .
# ----- output predecido
# broad-band is this feeling only the by the sight or the thought of art _ art10400 , he wrote . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'was', 'was', 'grim', ',', 'the', 'food', 'was', 'was', ',', 'fashion', 'was', 'all', 'but', 'well', ',', 'the', 'art', '_', 'p', 'were', 'struggling', ',', 'almost', 'pilgrims', ',', 'despite', 'the', '1666', 'qualities', 'of', ',', ',', ',', ',', ',', ',', ',', 'unsuccessful', 'the', 'bleached', 'qualities', 'of', ',', ',', ',', ',', ',', ',', ',', ',', 'and', 'and', 'and', 'and', 'and', 'and', '<eos>']
# ----- ID
# 37
# ----- tokens input
# The scenery was grim , the food was unappetising , fashion was all but non-existent , the arts were struggling , almost moribund , despite the explosive qualities of Kingsley Amis , John Osborne , Colin Wilson , and Alan Sillitoe ; and the weather was atrocious .
# ----- output predecido
# drillien was was grim , the food was was , fashion was all but well , the art _ p were struggling , almost pilgrims , despite the 1666 qualities of , , , , , , , unsuccessful the bleached qualities of , , , , , , , , and and and and and and <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['=', '_', 'u', '.', '<eos>']
# ----- ID
# 38
# ----- tokens input
# Art LA .
# ----- output predecido
# = _ u . <eos>
# ----- respuesta
# ['art_P', 'art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['iditis', 'seems', 'existed', 'rather', 'than', 'essentially', ',', ',', 'and', 'what', 'broaches', 'is', 'a', 'recognition', 'of', 'the', 'historical', 'possibility', 'of', 'popular', 'entertainment', 'as', 'an', 'autonomous', 'art', '_', 'art10400', 'which', 'might', 'turn', 'on', 'its', 'head', 'the', 'seriousness', 'of', 'of', ',', 'rational', 'rational', '.', '<eos>']
# ----- ID
# 39
# ----- tokens input
# Entertainment seems historically rather than essentially debased , and what emerges is a recognition of the historical possibility of popular entertainment as an autonomous art which might turn on its head the seriousness of official , rational discourse .
# ----- output predecido
# iditis seems existed rather than essentially , , and what broaches is a recognition of the historical possibility of popular entertainment as an autonomous art _ art10400 which might turn on its head the seriousness of of , rational rational . <eos>
# ----- respuesta
# ['art_art10400', 'art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'of', 'the', 'sort', 'has', 'already', 'been', 'introduced', 'into', 'some', 'of', 'ecstasy', ',', 'under', 'the', 'the', 'of', 'the', 'the', 'the', '_', 'of', 'the', 'the', 'the', 'the', 'of', 'the', 'the', 'the', 'the', 'of', 'the', 'the', '<eos>']
# ----- ID
# 40
# ----- tokens input
# Something of the sort has already been introduced into some English degrees , under the aegis of the Verbal Arts Association , who have made a welcome start with such work .
# ----- output predecido
# drillien of the sort has already been introduced into some of ecstasy , under the the of the the the _ of the the the the of the the the the of the the <eos>
# ----- respuesta
# ['art_P', 'art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'it', 'be', 'that', 'there', 'was', 'then', 'more', 'more', 'in', 'the', 'art', '_', 'p', 'world', ',', 'and', 'that', 'artists', 'artists', 'being', 'were', 'the', 'out', 'at', 'were', 'the', 'time', 'when', 'young', 'the', 'artists', 'from', 'young', 'the', 'artists', 'when', 'young', 'the', 'artists', 'from', 'young', 'the', 'fortune', '.', '<eos>']
# ----- ID
# 41
# ----- tokens input
# Could it be that there was then more racism in the art world , and that Black artists were being squeezed out at just the time when young working-class artists from the British provinces were finding unprecedented and immediate public fortune .
# ----- output predecido
# drillien it be that there was then more more in the art _ p world , and that artists artists being were the out at were the time when young the artists from young the artists when young the artists from young the fortune . <eos>
# ----- respuesta
# ['art_art10600', 'art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['nail-biting', 'pictures', 'that', 'books', 'tried', 'for', 'decades', 'to', '2', 'or', 'or', 'off', 'the', 'the', "'s", "'s", 'walls', 'will', 'also', 'travel', 'to', 'the', '_', 'the', 'in', 'in', 'and', 'then', 'to', 'the', 'in', 'of', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', 'in', '<eos>']
# ----- ID
# 42
# ----- tokens input
# The pictures that curators tried for decades to coax or pry off the Barnes 's walls will also travel to the Muse d'Orsay in Paris and then to the Museum of Western Art in Tokyo .
# ----- output predecido
# nail-biting pictures that books tried for decades to 2 or or off the the 's 's walls will also travel to the _ the in in and then to the in of in in in in in in in in in in in in in in <eos>
# ----- respuesta
# ['art_P', 'art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['9', ',', 'as', 'far', 'as', 'he', 'can', 'see', ',', 'with', 'a', 'future', 'of', 'minimum', 'of', 'and', 'maximum', ',', ',', 'he', 'has', 'decided', 'to', 'sell', 'his', 'gallery', 'at', 'on', 'he', "'s", 'as', 'an', 'art', '_', 'art10400', '_', 'light11000', 'of', 'on', 'on', "'s", 'as', 'an', 'art', '_', 'art10400', 'himself', '.', '<eos>']
# ----- ID
# 43
# ----- tokens input
# Faced , as far as he can see , with a future of minimum inflow and maximum outflow , he has decided to sell his gallery at 22 Cork Street as an art object .
# ----- output predecido
# 9 , as far as he can see , with a future of minimum of and maximum , , he has decided to sell his gallery at on he 's as an art _ art10400 _ light11000 of on on 's as an art _ art10400 himself . <eos>
# ----- respuesta
# ['art_U', 'art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['co-authors', '_', 'see23902', 'in', 'in', 'in', 'and', '1966', '1966', 'through', '1966', '.', '<eos>']
# ----- ID
# 44
# ----- tokens input
# BA Hons Combined Studies in Art and Design Application through ADAR .
# ----- output predecido
# co-authors _ see23902 in in in and 1966 1966 through 1966 . <eos>
# ----- respuesta
# ['art_P', 'art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'the', 'technical', 'art', '_', 'p', 'in', 'in', 'some', 'continental', 'schools', 'that', 'began', 'to', 'affect', 'the', 'soon', 'after', 'the', 'the', 'the', 'were', 'those', 'of', 'depends', 'and', 'results', '.', '<eos>']
# ----- ID
# 45
# ----- tokens input
# Among the technical arts cultivated in some continental schools that began to affect England soon after the Norman Conquest were those of measurement and calculation .
# ----- output predecido
# drillien the technical art _ p in in some continental schools that began to affect the soon after the the the were those of depends and results . <eos>
# ----- respuesta
# ['art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['4', '_', ',', ',', ',', ',', 'turn', '_', 'turn24213', 'into', 'a', 'handsome', 'a', 'and', 'and', 'and', 'complex', 'after', 'after', 'they', 'were', 'soon', 'defeated', 'by', 'the', '<eos>']
# ----- ID
# 46
# ----- tokens input
# Case History PITT STREET BATHS , PORTSMOUTH THESE BATHS WERE turned into a handsome Edwardian Arts and Crafts complex after they were suddenly vacated by the Navy .
# ----- output predecido
# 4 _ , , , , turn _ turn24213 into a handsome a and and and complex after after they were soon defeated by the <eos>
# ----- respuesta
# ['art_art10600', 'art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'canford', 'and', 'bought', 'sell', 'by', 'the', 'funds-service', ',', 'they', "'ve", 'done', 'cover', 'art', '_', 'art10400', 'for', ',', 'for', ',', 'and', 'and', 'and', 'and', 'and', 'yet', 'this', 'month', 'sees', 'the', 'first', 'ever', 'the', 'first', 'ever', 'of', 'their', 'work', '.', '<eos>']
# ----- ID
# 47
# ----- tokens input
# Their postcards and T-shirts sell by the crateload , they 've done cover art for Marc Almond , Erasure and Boy George and yet this month sees the first ever UK exhibition of their work .
# ----- output predecido
# drillien canford and bought sell by the funds-service , they 've done cover art _ art10400 for , for , and and and and and yet this month sees the first ever the first ever of their work . <eos>
# ----- respuesta
# ['art_art11000']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', 'art', '_', 'art10600', 'suggested', 'is', 'thus', 'which', 'to', 'consider', 'with', 'care', 'what', 'standards', 'of', 'comparison', 'should', 'be', 'used', '.', '<eos>']
# ----- ID
# 48
# ----- tokens input
# The art critic is thus bound to consider with care what standards of comparison should be used .
# ----- output predecido
# therecent art _ art10600 suggested is thus which to consider with care what standards of comparison should be used . <eos>
# ----- respuesta
# ['art_art_critic11800']
#
# --- hints:  0   --- acc: 0.0
# ['deemy', 'my', 'life', ',', 'he', 'wrote', ',', 'also', 'have', 'used', 'art', '_', 'art10400', 'to', 'fight', 'against', 'myself', '.', '<eos>']
# ----- ID
# 49
# ----- tokens input
# All my life , he wrote , I have used art to fight against myself .
# ----- output predecido
# deemy my life , he wrote , also have used art _ art10400 to fight against myself . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', 'yet', 'again', ',', 'the', 'librarian', 'intellectual', 'left', 'will', 'be', 'be', 'to', 'build', 'up', 'its', 'own', 'in', 'in', 'education', ',', 'local', 'government', ',', 'development', 'research', 'and', 'the', 'art', '_', 'p', 'and', 'the', 'the', 'world', 'and', 'the', 'the', 'world', 'outside', '.', '<eos>']
# ----- ID
# 50
# ----- tokens input
# Disappointed yet again , the British intellectual left will be tempted to build up its own Dukes in higher education , local government , scientific research and the arts and damn the world outside .
# ----- output predecido
# therecent yet again , the librarian intellectual left will be be to build up its own in in education , local government , development research and the art _ p and the the world and the the world outside . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['4', 'we', 'could', 'regard', 'an', 'organized', 'church', '_', 'p', ',', 'with', 'its', 'located', ',', ',', ',', 'laws', ',', 'music', ',', 'art', ',', 'and', 'written', 'tradition', ',', 'as', 'a', 'a', 'a', 'set', 'of', 'of', 'of', 'of', 'of', '.', '<eos>']
# ----- ID
# 51
# ----- tokens input
# Perhaps we could regard an organized church , with its architecture , rituals , laws , music , art , and written tradition , as a co-adapted stable set of mutually-assisting memes .
# ----- output predecido
# 4 we could regard an organized church _ p , with its located , , , laws , music , art , and written tradition , as a a a set of of of of of . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'diagrams', 'were', 'commissioned', 'by', 'their', 'respective', 'courts', 'and', 'were', 'chosen', 'by', 'the', 'authors', 'to', 'highlight', 'the', 'art', '_', 'art10400', 'produced', 'and', 'the', 'ideology', 'the', 'by', 'three', 'distinctive', 'types', 'of', 'regime', '.', '<eos>']
# ----- ID
# 52
# ----- tokens input
# These spaces were commissioned by their respective rulers and were chosen by the authors to illustrate the art produced and the ideology disseminated by three distinctive types of regime .
# ----- output predecido
# drillien diagrams were commissioned by their respective courts and were chosen by the authors to highlight the art _ art10400 produced and the ideology the by three distinctive types of regime . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['killpath', 'far', 'as', 'the', 'primary', 'phase', 'of', 'foreign-led', 'was', 'concerned', ',', 'the', 'plan', 'of', 'development', 'for', 'the', 'same', 'activities', 'as', 'were', 'listed', 'in', 'well', 'for', 'for', 'the', 'for', 'the', ',', 'for', ',', 'more', 'attention', 'was', 'devoted', 'to', 'history', 'and', 'and', ',', 'to', ',', 'art', '_', 'art10400', ',', 'and', 'to', 'science', ',', 'and', 'to', 'the', 'need', 'for', 'clearly', 'and', 'and', 'and', 'commitment', 'work', 'in', 'these', 'areas', 'of', 'the', 'curriculum', '.', '<eos>']
# ----- ID
# 53
# ----- tokens input
# As far as the primary phase of schooling was concerned , the plan of development favoured the same activities as were listed in A Framework for the School Curriculum , except that more attention was devoted to history and geography , to expressive arts , and to science , and to the need for clearly structured and progressively demanding work in these areas of the curriculum .
# ----- output predecido
# killpath far as the primary phase of foreign-led was concerned , the plan of development for the same activities as were listed in well for for the for the , for , more attention was devoted to history and and , to , art _ art10400 , and to science , and to the need for clearly and and and commitment work in these areas of the curriculum . <eos>
# ----- respuesta
# ['art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['lger', 'phrase', 'suggests', 'that', 'essential', 'was', 'resulted', 'in', 'an', 'activity', 'other', 'than', 'art', '_', 'art10600', '.', '<eos>']
# ----- ID
# 54
# ----- tokens input
# The phrase suggests that Brunelleschi was engaging in an activity other than art .
# ----- output predecido
# lger phrase suggests that essential was resulted in an activity other than art _ art10600 . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['piepsam', 'campaign', 'to', 'save', 'a', 'local', '_', 'p', 'centre', 'centre', ',', 'which', 'enough', ',', 'but', 'soon', 'becomes', 'the', 'target', 'for', 'x-rays', ',', 'and', 'and', 'find', 'herself', 'in', 'increasing', 'danger', 'as', 'she', 'of', 'and', 'and', 'find', 'herself', 'in', 'increasing', 'danger', 'as', 'she', 'of', 'of', '.', '<eos>']
# ----- ID
# 55
# ----- tokens input
# The campaign to save a local arts centre starts innocently enough , but soon becomes the target for intimidation , and Jane finds herself in increasing danger as she uncovers layers of corruption that spread from an Oxford college to the Houses of Parliament .
# ----- output predecido
# piepsam campaign to save a local _ p centre centre , which enough , but soon becomes the target for x-rays , and and find herself in increasing danger as she of and and find herself in increasing danger as she of of . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['the', 'art', '_', 'art10900', 'criticism', 'of', 'the', 'day', 'is', 'fully', 'described', 'in', 'the', 'in', ',', 'and', 'some', 'of', 'the', 'underlying', 'reasons', 'for', 'its', 'mainly', 'aggressive', 'character', 'are', 'responsible', ';', 'these', 'include', 'and', 'and', 'the', 'the', 'the', 'of', 'the', 'the', 'the', 'of', 'academic', 'of', '.', '<eos>']
# ----- ID
# 56
# ----- tokens input
# the art criticism of the day is fully described in the monograph , and some of the underlying reasons for its mainly aggressive character are outlined ; these include anti-Semitism and the fierce dislike of the monument by some academic sculptors .
# ----- output predecido
# the art _ art10900 criticism of the day is fully described in the in , and some of the underlying reasons for its mainly aggressive character are responsible ; these include and and the the the of the the the of academic of . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'de', 'sweetex', 'sweetex', 'to', 'avoid', 'to', "'s", "'s", 'dollar', "'s", 'year', "'s", 'debut', 'annual', "'s", 'de', "'s", 'art', '_', 'p', 'and', 'marina', 'fair', ',', 'held', 'as', 'ever', 'under', 'several', 'of', 'white', 'on', 'on', 'the', 'on', 'de', 'the', 'the', 'on', 'de', 'the', 'on', 'de', 'the', 'on', 'on', ',', 'is', 'a', 'smaller', 'on', 'than', 'last', 'year', "'s", '.', '<eos>']
# ----- ID
# 57
# ----- tokens input
# Salon de Mars Scheduled to avoid France 's pre-election jitters This year 's fifth annual Salon de Mars arts and antiques fair , held as ever under several acres of white tenting on the Champ de Mars near the Eiffel Tower from 31 March to 5 April , is a smaller edition than last year 's .
# ----- output predecido
# drillien de sweetex sweetex to avoid to 's 's dollar 's year 's debut annual 's de 's art _ p and marina fair , held as ever under several of white on on the on de the the on de the on de the on on , is a smaller on than last year 's . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['iditis', 'works', 'include', 'sculpture', 'by', 'by', 'a', ',', 'and', ',', ',', ',', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'and', 'a', 'painting', 'with', 'recent', 'of', 'of', 'contemporary', 'art', '_', 'art10600', 'by', 'by', 're-runs', 'and', 'and', ',', 'and', ',', 'and', 'and', 'centuries', 'artists', 'artists', '.', '<eos>']
# ----- ID
# 58
# ----- tokens input
# Those works include sculpture by Richard Deacon , Julian Opie , Grenville Davey and Richard Wentworth and a painting by Lisa Milroy and have been hung with recent purchases of contemporary art by Ashley Bickerton , Damien Hirst and other younger artists .
# ----- output predecido
# iditis works include sculpture by by a , and , , , and and and and and and and and and and a painting with recent of of contemporary art _ art10600 by by re-runs and and , and , and and centuries artists artists . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', 'tourists', ',', 'art', '_', 'art10400', 'centres', 'or', 'community', 'centres', ',', 'if', ',', 'designed', ',', 'are', 'probably', 'the', 'most', 'appropriate', ',', 'but', 'these', 'are', 'likely', 'to', 'depend', 'on', 'grants', 'or', 'or', ',', 'and', 'most', 'are', 'likely', 'to', 'depend', 'on', 'or', 'or', 'or', ',', 'no', 'of', 'are', 'are', 'are', 'require', 'more', 'than', 'one', 'of', 'any', 'one', 'type', '.', '<eos>']
# ----- ID
# 59
# ----- tokens input
# Concert halls , arts centres or community centres , if sympathetically designed , are probably the most appropriate , but these are likely to depend on grants or donations , and most towns will not require more than one of any one type .
# ----- output predecido
# therecent tourists , art _ art10400 centres or community centres , if , designed , are probably the most appropriate , but these are likely to depend on grants or or , and most are likely to depend on or or or , no of are are are require more than one of any one type . <eos>
# ----- respuesta
# ['art_art10400', 'art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['moreover', 'expressed', 'that', ',', 'even', 'at', 'a', 'reduced', 'rate', ',', 'from', 'on', 'revenue', 'from', 'outside', 'the', 'the', 'would', 'seriously', 'damage', 'the', 'the', 'art', '_', 'art', '_', 'market', 'market', '.', '<eos>']
# ----- ID
# 60
# ----- tokens input
# It argues that , even at a reduced rate , VAT on imports from outside the EC would seriously damage the London art market .
# ----- output predecido
# moreover expressed that , even at a reduced rate , from on revenue from outside the the would seriously damage the the art _ art _ market market . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['co-authors', 'arrests', 'mural', 'artist', '_', 'bell10600', 'artist', 'artist', "'s", ',', '220', '.', '<eos>']
# ----- ID
# 61
# ----- tokens input
# US arrests mural artist By DAVID LISTER , Arts Correspondent .
# ----- output predecido
# co-authors arrests mural artist _ bell10600 artist artist 's , 220 . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['=', '_', 'see23800', '.', '<eos>']
# ----- ID
# 62
# ----- tokens input
# Total arT wANK .
# ----- output predecido
# = _ see23800 . <eos>
# ----- respuesta
# ['art_art10600', 'art_U']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'at', 'odds', 'with', 'his', 'own', 'foundation', "'s", "'s", ',', 'age', ',', ',', 'and', 'berberis', 'artist', 'of', 'the', 'the', 'and', '1970s', ',', 'author', 'of', 'very', 'numerous', 'artists', 'coloured', 'greek', 'and', 'expanding', 'works', 'and', 'such', 'scale', 'and', 'such', 'scale', 'and', 'such', 'scale', 'and', 'such', 'scale', 'and', 'such', 'scale', 'and', 'such', 'each', 'and', ',', 'own', 'art', '_', 'p', 'the', 'at', 'at', ',', 'foundation', '.', '<eos>']
# ----- ID
# 63
# ----- tokens input
# Vasarely at odds with his own foundation Victor Vasarely , age eighty-six , leading optical artist of the 1960s and 1970s , author of very numerous brightly coloured geometrical trompe l'oeil works and large scale State commissions , has declared legal war on the president of his own arts foundation at Aix-en-Provence , Charles Debbasch .
# ----- output predecido
# drillien at odds with his own foundation 's 's , age , , and berberis artist of the the and 1970s , author of very numerous artists coloured greek and expanding works and such scale and such scale and such scale and such scale and such scale and such each and , own art _ p the at at , foundation . <eos>
# ----- respuesta
# ['art_art10400']
#
# --- hints:  0   --- acc: 0.0
# ['iditis', '1964', 'discovery', 'also', 'also', 'offers', 'a', 'combination', 'of', 'older', 'and', 'thoroughly', 'contemporary', 'fine', '_', 'art10400', '.', '<eos>']
# ----- ID
# 64
# ----- tokens input
# Iris von der Tann also offers a combination of older and thoroughly contemporary American art .
# ----- output predecido
# iditis 1964 discovery also also offers a combination of older and thoroughly contemporary fine _ art10400 . <eos>
# ----- respuesta
# ['art_art10600']
#
# --- hints:  0   --- acc: 0.0
# ['@g010l2sx', '=', '_', 'see23100', 'of', 'brokersscreens', '.', '<eos>']
# ----- ID
# 65
# ----- tokens input
# KING The Art of Love .
# ----- output predecido
# @g010l2sx = _ see23100 of brokersscreens . <eos>
# ----- respuesta
# ['art_P', 'art_art10900']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', 'new', 'begin', 'of', 'after-care', 'and', 'authority', 'should', 'be', 'created', 'to', 'be', 'this', 'new', 'empire', ',', 'separated', 'from', 'the', 'from', 'of', 'and', 'and', 'indicated', 'that', "'s", "'s", 'current', 'support', 'for', 'the', 'research', 'the', ',', 'the', ',', ',', ',', 'and', 'similar', 'and', 'and', 'and', 'and', 'and', ',', 'and', 'and', 'bodies', 'and', '.', '<eos>']
# ----- ID
# 66
# ----- tokens input
# A new Ministry of Arts and Sciences should be created to superintend this new empire , separated from the Ministry of Education and assuming that Ministry 's current responsibilities for the research councils , the Arts Council , and similar bodies .
# ----- output predecido
# therecent new begin of after-care and authority should be created to be this new empire , separated from the from of and and indicated that 's 's current support for the research the , the , , , and similar and and and and and , and and bodies and . <eos>
# ----- respuesta
# ['art_P', 'art_arts10900']
#
# --- hints:  0   --- acc: 0.0
# ['piepsam', 'next', 'move', 'was', 'to', 'persuade', 'to', 'to', 'to', 'to', 'be', 'finally', 'independent', 'and', 'join', 'her', 'in', 'partnership', 'as', 'an', 'art', '_', 'p', 'dealer', ',', 'starting', 'a', 'new', 'career', '.', '<eos>']
# ----- ID
# 67
# ----- tokens input
# My next move was to persuade Miss Hildegard Fritz-Denneville to be finally independent and join her in partnership as an art dealer , starting a new career .
# ----- output predecido
# piepsam next move was to persuade to to to to be finally independent and join her in partnership as an art _ p dealer , starting a new career . <eos>
# ----- respuesta
# ['art_art_dealer11800']
#
# --- hints:  0   --- acc: 0.0
# ...
# treated are either blind _ blind30000 or man . <eos>
# ----- respuesta
# ['blind_blind50000unperceptive00']
#
# --- hints:  0   --- acc: 0.0
# ['deemy', ',', 'ensures', ',', 'any', 'generally', 'available', 'additional', 'provision', 'for', 'deaf', 'or', 'partially', 'blind', '_', 'blind30000', 'or', 'yew12000', 'child', ',', 'and', 'others', 'such', 'as', 'as', 'child', ',', 'was', 'not', 'special', 'educational', 'provision', '.', '<eos>']
# ----- ID
# 354
# ----- tokens input
# Thus , logically , any generally available additional provision for deaf or partially blind or disturbed children , and others such as dyslexic children , was not special educational provision .
# ----- output predecido
# deemy , ensures , any generally available additional provision for deaf or partially blind _ blind30000 or yew12000 child , and others such as as child , was not special educational provision . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['therecent', 'requires', 'personal', 'understanding', 'of', 'each', 'individual', 'situation', ',', 'not', 'a', 'blind', '_', 'blind50000irrational00', 'response', 'to', 'ideals', 'and', 'respect', '.', '<eos>']
# ----- ID
# 355
# ----- tokens input
# This requires personal understanding of each individual situation , not a blind response to ideals and opinions .
# ----- output predecido
# therecent requires personal understanding of each individual situation , not a blind _ blind50000irrational00 response to ideals and respect . <eos>
# ----- respuesta
# ['blind_blind50000irrational00']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'blind', '_', 'blind30000', 'people', 'were', 'out', 'there', ',', 'alone', 'on', 'the', 'streets', ',', ',', 'along', 'with', 'their', 'nailed', 'sticks', ',', 'staring', ',', 'and', 'and', 'out', 'at', 'nothing', 'sticks', 'dark', 'glasses', '.', '<eos>']
# ----- ID
# 356
# ----- tokens input
# But blind people were out there , begging on the streets , bumbling along with their tip-tap sticks , staring sightlessly and pathetically out at nothing behind dark glasses .
# ----- output predecido
# drillien blind _ blind30000 people were out there , alone on the streets , , along with their nailed sticks , staring , and and out at nothing sticks dark glasses . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['killpath', 'my', 'new', 'label', 'of', 'blind', '_', 'blind30000', 'came', 'the', 'object', 'which', 'was', 'to', 'to', 'me', 'more', ',', 'a', ',', 'new', ',', 'long', 'white', 'sharp', '.', '<eos>']
# ----- ID
# 357
# ----- tokens input
# With my new label of blind came the object which was to stigmatize me more , a shiny new , long white cane .
# ----- output predecido
# killpath my new label of blind _ blind30000 came the object which was to to me more , a , new , long white sharp . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', '2', 'two', 'students', 'from', 'this', 'school', 'stood', 'back', 'to', 'let', 'an', 'elderly', 'for', 'woman', 'enter', 'the', 'the', 'the', 'before', 'them', 'and', 'in', 'and', 'another', 'mother', ',', 'who', 'to', 'to', 'glad', 'to', 'say', 'had', 'been', 'with', 'us', 'only', 'two', 'weeks', ',', 'was', ',', 'by', 'two', 'the', 'the', 'the', 'through', 'the', 'the', 'of', 'the', 'lengths', 'room', 'of', 'the', 'the', "'s", 'the', 'the', 'the', 'the', "'s", 'room', 'of', 'the', 'the', "'s", "'s", 'the', ',', 'as', 'a', 'blind', '_', 'blind30000', 'woman', 'across', 'the', 'road', '.', '<eos>']
# ----- ID
# 358
# ----- tokens input
# In April two students from this school stood back to let an elderly disabled woman enter the Post Office before them and in June another student , who I am glad to say had been with us only two weeks , was spotted by two seniors through the window of the tap room of the Throstle 's Nest , helping a blind woman across the road .
# ----- output predecido
# drillien 2 two students from this school stood back to let an elderly for woman enter the the the before them and in and another mother , who to to glad to say had been with us only two weeks , was , by two the the the through the the of the lengths room of the the 's the the the the 's room of the the 's 's the , as a blind _ blind30000 woman across the road . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['b-box', 'the', 'fresh', 'side', ',', 'however', ',', 'blind', '_', 'blind30000', 'singer', 'a', 'a', 'can', 'be', 'be', 'be', 'upon', 'to', 'turn', 'out', 'a', 'loathsome', 'record', ',', 'and', 'this', 'and', ',', 'strikingly', ',', 'of', ',', ',', 'lovers', ',', 'of', ',', ',', 'places', ',', 'of', ',', ',', 'places', ',', 'of', ',', ',', 'places', ',', 'of', ',', ',', 'hits', 'your', '<eos>']
# ----- ID
# 359
# ----- tokens input
# On the plus side , however , blind singer Frankie Paul can usually be relied upon to turn out a stinging record , and this crisply-mixed , soulful mlange of ragga , lovers and soul soon hits your aural G-spot .
# ----- output predecido
# b-box the fresh side , however , blind _ blind30000 singer a a can be be be upon to turn out a loathsome record , and this and , strikingly , of , , lovers , of , , places , of , , places , of , , places , of , , hits your <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['00', 'blind', 'in', 'the', 'shallow', 'dark', 'water', ',', 'it', 'is', 'swimming', 'by', 'by', ',', 'following', 'the', 'hole', 'channel', 'channel', 'channel', 'channel', '_', 'channel10600', '.', '<eos>']
# ----- ID
# 360
# ----- tokens input
# Almost blind in the shallow muddy water , it is swimming by instinct , following the deepest sand channels .
# ----- output predecido
# 00 blind in the shallow dark water , it is swimming by by , following the hole channel channel channel channel _ channel10600 . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['piepsam', 'is', 'a', 'broad', 'term', ',', 'with', 'the', 'appropriate', 'emphasis', 'on', 'the', 'child', "'s", 'potential', ',', 'but', 'has', 'been', 'used', 'too', 'often', 'been', 'to', 'to', 'with', 'blind', '_', 'blind50000irrational00', 'without', 'for', 'for', 'the', 'needs', 'of', 'or', 'for', 'the', 'needs', 'of', 'or', 'for', 'the', 'needs', 'of', 'or', 'to', 'for', 'both', 'for', 'for', 'learning', '.', '<eos>']
# ----- ID
# 361
# ----- tokens input
# It is a broad term , with the appropriate emphasis on the child 's potential , but has been used too often previously to contrast with blind without consideration for the needs of pupils who have to use both tactile and visual methods for learning .
# ----- output predecido
# piepsam is a broad term , with the appropriate emphasis on the child 's potential , but has been used too often been to to with blind _ blind50000irrational00 without for for the needs of or for the needs of or for the needs of or to for both for for learning . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['pickthorne', '=', 'were', 'blind', '_', 'blind50000irrational00', 'and', 'fungus', '.', '<eos>']
# ----- ID
# 362
# ----- tokens input
# The tentacles were blind and probing .
# ----- output predecido
# pickthorne = were blind _ blind50000irrational00 and fungus . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ["'d", "'d", 'be', 'blind', '_', 'blind', '_', 'bell10600', 'and', 'virtually', '.', '<eos>']
# ----- ID
# 363
# ----- tokens input
# We 'd be blind and virtually defenceless overnight .
# ----- output predecido
# 'd 'd be blind _ blind _ bell10600 and virtually . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', '1964', 'was', 'a', 'great', 'the', 'representing', 'the', 'the', 'features', 'of', 'the', 'blind', '_', 'blind30000', 'the', 'the', 'altering', 'portion', 'of', 'his', 'goddess', 'amidst', 'tubes', 'and', 'wires', '.', '<eos>']
# ----- ID
# 364
# ----- tokens input
# One bulkhead was a great bas-relief representing the withered features of the blind immobile Emperor embedded in the central portion of his throne amidst tubes and wires .
# ----- output predecido
# drillien 1964 was a great the representing the the features of the blind _ blind30000 the the altering portion of his goddess amidst tubes and wires . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['somescientists', 'to', 'say', 'no', 'one', 'has', 'yet', 'proved', 'by', 'blind', '_', 'blind50000unperceptive00', 'testing', 'that', 'any', 'of', 'the', 'effects', 'claimed', 'are', 'are', '.', '<eos>']
# ----- ID
# 365
# ----- tokens input
# Needless to say no one has yet proved by blind testing that any of the effects claimed are reproducible .
# ----- output predecido
# somescientists to say no one has yet proved by blind _ blind50000unperceptive00 testing that any of the effects claimed are are . <eos>
# ----- respuesta
# ['blind_U', 'blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['treated', 'parents', 'are', 'better', 'at', 'turning', 'a', 'blind', '_', 'blind', '_', 'than', 'eye', 'than', 'others', '.', '<eos>']
# ----- ID
# 366
# ----- tokens input
# Some parents are better at turning a blind eye than others .
# ----- output predecido
# treated parents are better at turning a blind _ blind _ than eye than others . <eos>
# ----- respuesta
# ['blind_U', 'blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['neither', 'knew', 'no', 'cheap', 'place', 'here', 'any', 'more', 'and', 'he', 'would', 'have', 'to', 'search', 'one', 'out', 'like', 'a', 'blind', '_', 'blind30000', 'man', 'man', 'man', 'man', '.', '<eos>']
# ----- ID
# 367
# ----- tokens input
# He knew no cheap place here any more and he would have to search one out like a blind man .
# ----- output predecido
# neither knew no cheap place here any more and he would have to search one out like a blind _ blind30000 man man man man . <eos>
# ----- respuesta
# ['blind_blind_man11800']
#
# --- hints:  0   --- acc: 0.0
# ['drillien', 'we', "'ve", 'been', 'shown', 'in', 'the', 'in', ',', 'and', 'what', 'has', ',', ',', ',', 'emerged', 'from', 'this', 'discussion', ',', 'is', 'that', 'for', 'some', 'fifteen', 'years', ',', 'we', 'engaged', 'in', 'a', 'game', 'of', 'blind', '_', 'blind', '_', 'man', 'man', 'man', 'man', 'man', 'man', 'man', '.', '<eos>']
# ----- ID
# 368
# ----- tokens input
# What we 've been shown in the Report , and what has , ah , emerged from this discussion , is that for some fifteen years , we engaged in a game of blind man 's buff .
# ----- output predecido
# drillien we 've been shown in the in , and what has , , , emerged from this discussion , is that for some fifteen years , we engaged in a game of blind _ blind _ man man man man man man man . <eos>
# ----- respuesta
# ['blind_P', 'blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['buoncamino', 'do', "n't", 'suddenly', 'go', 'blind', '_', 'blind30000', 'for', 'the', 'females', 'of', 'a', 'buyer', 'call', 'and', 'are', ',', 'therefore', ',', 'prey', 'to', 'all', 'of', 'of', 'underprivileged', 'of', 'people', 'walking', 'past', 'the', 'window', ',', 'someone', 'coming', 'in', 'to', 'see', 'you', 'and', 'so', 'on', 'on', 'then', ',', ',', 'coming', 'in', 'to', 'see', 'you', 'and', 'so', 'on', '.', '<eos>']
# ----- ID
# 369
# ----- tokens input
# You do n't suddenly go blind for the duration of a phone call and are , therefore , prey to all sorts of visual distractions people walking past the window , someone coming in to see you and so on .
# ----- output predecido
# buoncamino do n't suddenly go blind _ blind30000 for the females of a buyer call and are , therefore , prey to all of of underprivileged of people walking past the window , someone coming in to see you and so on on then , , coming in to see you and so on . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['cd2', '40-year-old', '145', ',', ',', ',', ',', '_', 'see23902', ',', '1985', ',', ',', ',', ',', '1985', ',', ',', ',', '1990', '.', '<eos>']
# ----- ID
# 370
# ----- tokens input
# MAN SPINNING WOOL , LA PAZ , BOLIVIA , 1985 PLAYING IN FRONT OF HOME/STOREY LA PAZ , BOLIVIA , 1985 MAMA LANCHI , BLIND MAID IN THE KITCHEN WITH HER DOG LUCY , COCA BAMBA , BOLIVIA , 1990 .
# ----- output predecido
# cd2 40-year-old 145 , , , , _ see23902 , 1985 , , , , 1985 , , , 1990 . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['cd2', ',', 'blind', '_', 'blind30000', 'since', 'birth', ',', 'said', '.', '<eos>']
# ----- ID
# 371
# ----- tokens input
# Edna , blind since birth , said .
# ----- output predecido
# cd2 , blind _ blind30000 since birth , said . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['9', ',', 'he', 'rose', 'a', 'from', 'from', 'his', 'belt', 'and', 'shot', 'her', 'through', 'one', 'of', 'her', 'blind', '_', 'blind30000', 'eyes', ',', 'powdery', 'her', 'brain', '.', '<eos>']
# ----- ID
# 372
# ----- tokens input
# Laughing , he plucked a laspistol from his belt and shot her through one of her blind eyes , boiling her brain .
# ----- output predecido
# 9 , he rose a from from his belt and shot her through one of her blind _ blind30000 eyes , powdery her brain . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['it', "'s", 'not', 'as', 'if', 'it', "'ll", 'hide', 'the', 'horses', ',', 'because', 'they', "'re", 'supposed', 'to', 'be', 'colour', 'blind', '_', 'blind30000', '.', '<eos>']
# ----- ID
# 373
# ----- tokens input
# It 's not as if it 'll frighten the horses , because they 're supposed to be colour blind .
# ----- output predecido
# it 's not as if it 'll hide the horses , because they 're supposed to be colour blind _ blind30000 . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ["'m", "'m", 'not', 'blind', '_', 'blind30000', ',', 'you', 'know', '.', '<eos>']
# ----- ID
# 374
# ----- tokens input
# I 'm not blind , you know .
# ----- output predecido
# 'm 'm not blind _ blind30000 , you know . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ['killpath', "'s", 'already', 'lost', 'the', 'sight', 'of', 'his', 'left', 'eye', 'because', 'cocaine', 'of', 'the', 'the', ',', 'and', 'he', "'s", 'damn', 'he', 'not', 'to', 'be', 'be', 'be', 'blind', '_', 'blind30000', ',', 'or', 'even', 'dead', ',', 'because', 'the', 'next', 'time', 'it', 'could', 'the', 'the', 'of', 'of', 'of', 'or', 'the', 'block', 'the', 'the', 'the', 'blood', 'from', 'his', 'his', 'brain', '.', '<eos>']
# ----- ID
# 375
# ----- tokens input
# He 's already lost the sight of his left eye because cocaine starved the retina of blood , and he 's damn lucky not to be totally blind , or even dead , because the next time it could constrict the arteries of his heart or block the blood from reaching his brain .
# ----- output predecido
# killpath 's already lost the sight of his left eye because cocaine of the the , and he 's damn he not to be be be blind _ blind30000 , or even dead , because the next time it could the the of of of or the block the the the blood from his his brain . <eos>
# ----- respuesta
# ['blind_blind30000']
#
# --- hints:  0   --- acc: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-a62a47ec0d81> in <module>()
#       1 evaluator = Evaluator(encoder, decoder, input_lang, output_lang, MAX_LENGTH, True)
# ----> 2 acc = evaluator.evaluate_acc(pairs_test, k_beams=1, verbose=True)
#
# ~/projects/wsd-v2/evaluator_dis.py in evaluate_acc(self, pairs, k_beams, verbose)
#     127             sentence, pos, id_senses = temp[0], int(temp[1]), temp[2:]
#     128
# --> 129             output_words = self.evaluate(sentence, k_beams)
#     130             torch.cuda.empty_cache()
#     131
#
# ~/projects/wsd-v2/evaluator_dis.py in evaluate(self, sentence, k_beams)
#      64                 topv, topi = decoder_output.data.topk(k_beams)
#      65
# ---> 66                 for ni, vi in zip(topi[0], topv[0]):
#      67                     new_beam = Beam(None, decoder_context, decoder_hidden,
#      68                                     beam.decoded_words[:], beam.decoder_attentions[:], beam.sequence_log_probs[:])
#
# KeyboardInterrupt:

# %%
pairs_train[0]
# Out:
# array(['clearly the action of a madman ; no possible sense in it .',
#        'clearly the action of a madman ; no possible sense _ sense10904 in it .'],
#       dtype='<U582')

# %%
p = ['Pop Art is an example .', '1', 'art_pop_art10600']
int(p[1])
# Out:
# 1

# %%
evaluator = Evaluator(encoder, decoder, input_lang, output_lang, 
                      MAX_LENGTH, USE_CUDA)
candidates, references = evaluator.get_candidates_and_references(pairs_test[:10000], k_beams=2)
len(candidates), len(references)
# Out:
# A Jupyter Widget

# %%
BLEU(candidates, [references])
# Out:
# (0.28063523097173265,
#  [0.6573135078342698,
#   0.37567686039915427,
#   0.22488307382629802,
#   0.13494545201862276],
#  0.953820572858132)
