# %%
from Preprocessing import construct_pairs
from Utils import save_json

# %%
pairs_train = construct_pairs('corpus/train/EnglishLS.train', '/home/krivas/projects/wsd-v2/',\
                              is_train=True, test_path=None, prune_sentence=False, verbose=True)
# Out:
# /home/krivas/anaconda3/lib/python3.6/site-packages/nltk/tag/stanford.py:183: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordNERTagger, self).__init__(*args, **kwargs)
# ---oracion
# It is quite a hefty spade , with bicycle-type handlebars and a sprung lever at the rear , which you step on to <head>activate</head> it
# ---oracione sin parentesis
# It is quite a hefty spade , with bicycle-type handlebars and a sprung lever at the rear , which you step on to <head>activate</head> it
#
#
# ---oracion
# The quality or modality of the experience depends less upon the quality of energy reaching the nervous system than upon which parts of the sensory system are <head>activated</head>
# ---oracione sin parentesis
# The quality or modality of the experience depends less upon the quality of energy reaching the nervous system than upon which parts of the sensory system are <head>activated</head>
#
#
# ---oracion
# At a neurophysiological level , the intensity of an experience is typically reflected in the number of neurones <head>activated</head> ( the phenomenon of recruitment ) and , more specifically , in the firing frequency of the relevant neurones
# ---oracione sin parentesis
# At a neurophysiological level , the intensity of an experience is typically reflected in the number of neurones <head>activated</head>  and , more specifically , in the firing frequency of the relevant neurones
#
#
# ---oracion
# I am leaving aside phenomena such as accommodation , whereby a constant stimulus when sustained may <head>activate</head> the nervous system progressively less intensively , with a corresponding reduction in the perceived intensity of the stimulus
# ---oracione sin parentesis
# I am leaving aside phenomena such as accommodation , whereby a constant stimulus when sustained may <head>activate</head> the nervous system progressively less intensively , with a corresponding reduction in the perceived intensity of the stimulus
#
#
# ---oracion
# Whilst a prospective burglar might fumbling with the clock and wondering why it won't lift , his movement will have <head>activated</head> the pressure pad which controls an audible alarm giving out 85dbs
# ---oracione sin parentesis
# Whilst a prospective burglar might fumbling with the clock and wondering why it won't lift , his movement will have <head>activated</head> the pressure pad which controls an audible alarm giving out 85dbs
#
#
# ---oracion
# This alarm may only be de - <head>activated</head> by a key holder , and the noise alone is such that the prospective thief will hopefully abandon his anti-social ideas
# ---oracione sin parentesis
# This alarm may only be de - <head>activated</head> by a key holder , and the noise alone is such that the prospective thief will hopefully abandon his anti-social ideas
#
#
# ---oracion
# Their limbs , torsos and heads can make straight , angled or rounded lines , usually at one and the same time , according to the natural structure of the dancers ' bones and how they are <head>activated</head> by the muscles
# ---oracione sin parentesis
# Their limbs , torsos and heads can make straight , angled or rounded lines , usually at one and the same time , according to the natural structure of the dancers ' bones and how they are <head>activated</head> by the muscles
#
#
# ---oracion
# They are based on a refinement of the natural movements made by the bones and joints when <head>activated</head> by the muscles , tendons and ligaments found in any human body
# ---oracione sin parentesis
# They are based on a refinement of the natural movements made by the bones and joints when <head>activated</head> by the muscles , tendons and ligaments found in any human body
#
#
# ---oracion
# The <head>activating</head> field producing resonance is the electric and magnetic field set up by an overhead power line or magnetic field producing appliance such as an electric blanket , etc
# ---oracione sin parentesis
# The <head>activating</head> field producing resonance is the electric and magnetic field set up by an overhead power line or magnetic field producing appliance such as an electric blanket , etc
#
#
# ---oracion
# There are ions <head>activated</head> by thermal motion in blood and these are always subject to the Earth 's magnetic field
# ---oracione sin parentesis
# There are ions <head>activated</head> by thermal motion in blood and these are always subject to the Earth 's magnetic field
#
#
# ---oracion
# This clause has never yet been <head>activated</head>
# ---oracione sin parentesis
# This clause has never yet been <head>activated</head>
#
#
# ---oracion
# Infected programmes <head>activate</head> the virus when started up and it looks for other programmes to infect
# ---oracione sin parentesis
# Infected programmes <head>activate</head> the virus when started up and it looks for other programmes to infect
#
#
# ---oracion
# Flames of doubt were fanned by the crew 's insistence that they had <head>activated</head> the emergency radio beacon for a week , though it was not picked up
# ---oracione sin parentesis
# Flames of doubt were fanned by the crew 's insistence that they had <head>activated</head> the emergency radio beacon for a week , though it was not picked up
#
#
# ---oracion
# Light-sensitive cells govern lens-aperture and shutter-speed settings ; infra-red beams measure distances to <head>activate</head> lens focusing ; motors wind films and operate zoom lenses
# ---oracione sin parentesis
# Light-sensitive cells govern lens-aperture and shutter-speed settings ; infra-red beams measure distances to <head>activate</head> lens focusing ; motors wind films and operate zoom lenses
#
#
# ---oracion
# Once the machine is <head>activated</head> , either by coins or cards , a hydraulic lift places a plate with the selected food into a microwave for defrosting
# ---oracione sin parentesis
# Once the machine is <head>activated</head> , either by coins or cards , a hydraulic lift places a plate with the selected food into a microwave for defrosting
#
#
# ---oracion
# Two other plans , not <head>activated</head> now , were also drawn up
# ---oracione sin parentesis
# Two other plans , not <head>activated</head> now , were also drawn up
#
#
# ---oracion
# They duly processed the information and despatched warning letters stating that offenders had five days to make a payment arrangement with a 10 per cent surcharge before a court order , a summary warrant , was <head>activated</head>
# ---oracione sin parentesis
# They duly processed the information and despatched warning letters stating that offenders had five days to make a payment arrangement with a 10 per cent surcharge before a court order , a summary warrant , was <head>activated</head>
#
#
# ---oracion
# Melanin producing cells in our bodies are <head>activated</head> by ultraviolet light from the sun and can have a protective effect
# ---oracione sin parentesis
# Melanin producing cells in our bodies are <head>activated</head> by ultraviolet light from the sun and can have a protective effect
#
#
# ---oracion
# Many trade disputes are pending , awaiting the outcome of the talks ; failure would <head>activate</head> them immediately
# ---oracione sin parentesis
# Many trade disputes are pending , awaiting the outcome of the talks ; failure would <head>activate</head> them immediately
#
#
# ---oracion
# She was <head>activated</head> by something in between
# ---oracione sin parentesis
# She was <head>activated</head> by something in between
#
#
# ---oracion
# Pulling the car off the narrow country lane , Mark pressed the button which <head>activated</head> the power-operated windows
# ---oracione sin parentesis
# Pulling the car off the narrow country lane , Mark pressed the button which <head>activated</head> the power-operated windows
#
#
# ---oracion
# To complete the uniformity of the pile , one of the wheels is fitted with an electric motor which when <head>activated</head> manually will pull back the elevator from the heap in increments down to 25mm ( 1in )
# ---oracione sin parentesis
# To complete the uniformity of the pile , one of the wheels is fitted with an electric motor which when <head>activated</head> manually will pull back the elevator from the heap in increments down to 25mm
#
#
# ---oracion
# Returning to higher mammals , you will recall that fibres entering the primary visual cortex are best <head>activated</head> by spots of light with dark surrounds on the retina
# ---oracione sin parentesis
# Returning to higher mammals , you will recall that fibres entering the primary visual cortex are best <head>activated</head> by spots of light with dark surrounds on the retina
# ---oracion
# He argued that cells become different because , at the time of cell division , different genes are transmitted to different daughter cells ( he did not use the word gene , but that is what he meant ) ; whereas in fact all body cells contain the same genes , and become different because different genes are <head>activated</head> in different cells
# ---oracione sin parentesis
# He argued that cells become different because , at the time of cell division , different genes are transmitted to different daughter cells  ; whereas in fact all body cells contain the same genes , and become different because different genes are <head>activated</head> in different cells
#
#
# ---oracion
# The procedure would have been for the pilot to pull a handle , situated between his legs , which jettisoned the canopy while <head>activating</head> a rocket that fired his seat and that of his navigator clear of the plane
# ---oracione sin parentesis
# The procedure would have been for the pilot to pull a handle , situated between his legs , which jettisoned the canopy while <head>activating</head> a rocket that fired his seat and that of his navigator clear of the plane
#
#
# ---oracion
# Jennings says the minizyme is <head>activated</head> when it combines with its target , an advantage over other anti-viral agents in that it limits the prospect for side effects
# ---oracione sin parentesis
# Jennings says the minizyme is <head>activated</head> when it combines with its target , an advantage over other anti-viral agents in that it limits the prospect for side effects
#
#
# ---oracion
# The conventional view is that the body somehow tells these altruistic cells to do the honourable thing by <head>activating</head> a suicide programme
# ---oracione sin parentesis
# The conventional view is that the body somehow tells these altruistic cells to do the honourable thing by <head>activating</head> a suicide programme
#
#
# ---oracion
# To raise its money , the Treasury will thus re - <head>activate</head> that forgotten corner of the Civil Service , the Department of National
# ---oracione sin parentesis
# To raise its money , the Treasury will thus re - <head>activate</head> that forgotten corner of the Civil Service , the Department of National
#
#
# ---oracion
# As the overnight election results came in , the Bank of England <head>activated</head> a programme to sell more than 2 billion of gilt-edged stock to help fund the Government 's high public spending
# ---oracione sin parentesis
# As the overnight election results came in , the Bank of England <head>activated</head> a programme to sell more than 2 billion of gilt-edged stock to help fund the Government 's high public spending
#
#
# ---oracion
# It destroyed morale throughout the regime , forcing commanders and party chiefs to <head>activate</head> their tribal links with the Mujahideen and save their skins before the time of reckoning
# ---oracione sin parentesis
# It destroyed morale throughout the regime , forcing commanders and party chiefs to <head>activate</head> their tribal links with the Mujahideen and save their skins before the time of reckoning
#
#
# ---oracion
# Immediate response ( allocation and visiting ) can be distinguished from ultimate response ( recommending and <head>activating</head> service-provision )
# ---oracione sin parentesis
# recommending and <head>activating</head> service-provision
#
#
# ---oracion
# If subsequently a critical incident happens which is pertinent to the individual 's particular dysfunctional assumption , then , rather like a key fitting into a lock , the dysfunctional assumptions are <head>activated</head>
# ---oracione sin parentesis
# If subsequently a critical incident happens which is pertinent to the individual 's particular dysfunctional assumption , then , rather like a key fitting into a lock , the dysfunctional assumptions are <head>activated</head>
#
#
# ---oracion
# The solvent is <head>activated</head> by water and will remain harmless unless moisture levels build up
# ---oracione sin parentesis
# The solvent is <head>activated</head> by water and will remain harmless unless moisture levels build up
#
#
# ---oracion
# Circle 136 A personal oxygen monitor which is switched on constantly and helps protect the wearer against oxygen-depleted atmospheres was launched by BOC Cryospeed 's audible alarm and flashing red light are <head>activated</head> when oxygen levels fall below 18 per cent or rise above 22 per cent
# ---oracione sin parentesis
# Circle 136 A personal oxygen monitor which is switched on constantly and helps protect the wearer against oxygen-depleted atmospheres was launched by BOC Cryospeed 's audible alarm and flashing red light are <head>activated</head> when oxygen levels fall below 18 per cent or rise above 22 per cent
#
#
# ---oracion
# By independently monitoring the temperature of a chemical reaction , it can <head>activate</head> an internal alarm should an experiment exceed a pre - programmed safety limit
# ---oracione sin parentesis
# By independently monitoring the temperature of a chemical reaction , it can <head>activate</head> an internal alarm should an experiment exceed a pre - programmed safety limit
#
#
# ---oracion
# The difference between long and short term memory depends on whether certain NMDA ( N methyl-D - aspartate ) receptors were <head>activated</head> or not
# ---oracione sin parentesis
# The difference between long and short term memory depends on whether certain NMDA  receptors were <head>activated</head> or not
#
#
# ---oracion
# When you remember something , the chemistry is the same each time every time you see Mr Jones , the same pathway is <head>activated</head>
# ---oracione sin parentesis
# When you remember something , the chemistry is the same each time every time you see Mr Jones , the same pathway is <head>activated</head>
#
#
# ---oracion
# He finds a symbol two simple drawings which are intriguing enough to <head>activate</head> each pupil into endowing them with whatever his or her own personal interpretation of horror might be
# ---oracione sin parentesis
# He finds a symbol two simple drawings which are intriguing enough to <head>activate</head> each pupil into endowing them with whatever his or her own personal interpretation of horror might be
#
#
# ---oracion
# Such wired-in behavioural programmes controlled by neuronal pacemakers are innate response repertoires <head>activated</head> endogenously or in relation to shifts in local conditions
# ---oracione sin parentesis
# Such wired-in behavioural programmes controlled by neuronal pacemakers are innate response repertoires <head>activated</head> endogenously or in relation to shifts in local conditions
#
#
# ---oracion
# The same is not the case in the Republic of Ireland with plans already <head>activated</head> to provide proper links to ports
# ---oracione sin parentesis
# The same is not the case in the Republic of Ireland with plans already <head>activated</head> to provide proper links to ports
#
#
# ---oracion
# This is the last bond to be actively redeemed until 1957 when a minor flurry of interest in <head>activating</head> redemption might have been responsible for some bond buying-in activity , although the Club waited until 1983 for the total buying-in to take place
# ---oracione sin parentesis
# This is the last bond to be actively redeemed until 1957 when a minor flurry of interest in <head>activating</head> redemption might have been responsible for some bond buying-in activity , although the Club waited until 1983 for the total buying-in to take place
#
#
# ---oracion
# Thinking there was too much water in the system , rather than too little , they turned off even the emergency cooling system which had by then been <head>activated</head>
# ---oracione sin parentesis
# Thinking there was too much water in the system , rather than too little , they turned off even the emergency cooling system which had by then been <head>activated</head>
#
#
# ---oracion
# coli contain enigmatic lengths of DNA ( insertion sequences ) which code for no known product but can move about the chromosome during bacterial multiplication , <head>activating</head> or silencing genes
# ---oracione sin parentesis
# coli contain enigmatic lengths of DNA  which code for no known product but can move about the chromosome during bacterial multiplication , <head>activating</head> or silencing genes
# ---oracion
# The fulling mill had a large wheel , turned by the water power , which <head>activated</head> wooden hammers , rising and falling on the cloth in soapy water
# ---oracione sin parentesis
# The fulling mill had a large wheel , turned by the water power , which <head>activated</head> wooden hammers , rising and falling on the cloth in soapy water
#
#
# ---oracion
# A node that is in the A2 ( secondary activation ) state ( either because its stimulus has only recently been presented or because it has been <head>activated</head> internally by means of an excitatory associative link ) will not be able to move into Al
# ---oracione sin parentesis
# either because its stimulus has only recently been presented or because it has been <head>activated</head> internally by means of an excitatory associative link
#
#
# ---oracion
# More specifically , the model makes the usual associative assumption that excitatory links will be established between representations ( of elements ) that are <head>activated</head> concurrently
# ---oracione sin parentesis
# More specifically , the model makes the usual associative assumption that excitatory links will be established between representations  that are <head>activated</head> concurrently
#
#
# ---oracion
# ( 1988 b ) support this interpretation by demonstrating that the VS pre - exposure treatment will produce perfectly good latent inhibition when the CS used in the conditioning phase is itself vinegar followed by sucrose , an arrangement that should ensure that the same representation of vinegar is <head>activated</head> on both occasions
# ---oracione sin parentesis
#  support this interpretation by demonstrating that the VS pre - exposure treatment will produce perfectly good latent inhibition when the CS used in the conditioning phase is itself vinegar followed by sucrose , an arrangement that should ensure that the same representation of vinegar is <head>activated</head> on both occasions
#
#
# ---oracion
# Konorski 's ( 1967 ) well-developed and influential theory of conditioning deals with inhibitory learning by assuming that an inhibitory CS is one that <head>activates</head> a no-US representation
# ---oracione sin parentesis
# Konorski 's  well-developed and influential theory of conditioning deals with inhibitory learning by assuming that an inhibitory CS is one that <head>activates</head> a no-US representation
#
#
# ---oracion
# Their proposal ( see Chapter 3 ) was that the associability of an element <head>activated</head> by external stimulation will be enhanced when this element lacks associative connections
# ---oracione sin parentesis
# Their proposal  was that the associability of an element <head>activated</head> by external stimulation will be enhanced when this element lacks associative connections
#
#
# ---oracion
# As we have seen , modern theories of Pavlovian conditioning assume that stimuli can <head>activate</head> the representations of other events
# ---oracione sin parentesis
# As we have seen , modern theories of Pavlovian conditioning assume that stimuli can <head>activate</head> the representations of other events
#
#
# ---oracion
# It should be acknowledged that not all theories of Pavlovian learning are entirely happy with the suggestion that an associatively <head>activated</head> representation can form an excitatory link with the ( directly <head>activated</head> ) representation of some other event
# ---oracione sin parentesis
# directly <head>activated</head>
#
#
# ---oracion
# But when it comes to the issue of how a given physical stimulus is actually perceived , we have chosen to represent this in terms of the central representational elements that it <head>activates</head>
# ---oracione sin parentesis
# But when it comes to the issue of how a given physical stimulus is actually perceived , we have chosen to represent this in terms of the central representational elements that it <head>activates</head>
#
#
# ---oracion
# This must mean , in terms of the figure , an increase in the number of a and b elements <head>activated</head> by the stimuli , something that can be represented diagrammatically in more than one way
# ---oracione sin parentesis
# This must mean , in terms of the figure , an increase in the number of a and b elements <head>activated</head> by the stimuli , something that can be represented diagrammatically in more than one way
#
#
# ---oracion
# There is no net increase in the number of elements <head>activated</head> by a given stimulus but the circles have been moved apart , indicating not only an increase in the number of unique elements <head>activated</head> by a stimulus but a corresponding decrease in the number of common elements <head>activated</head>
# ---oracione sin parentesis
# There is no net increase in the number of elements <head>activated</head> by a given stimulus but the circles have been moved apart , indicating not only an increase in the number of unique elements <head>activated</head> by a stimulus but a corresponding decrease in the number of common elements <head>activated</head>
#
#
# ---oracion
# There would again be an increase in the ability of a elements to overshadow c elements , but in addition the reduction of the number of c elements <head>activated</head> by A would mean that relatively few of them would be capable of acquiring associative strength in the first place
# ---oracione sin parentesis
# There would again be an increase in the ability of a elements to overshadow c elements , but in addition the reduction of the number of c elements <head>activated</head> by A would mean that relatively few of them would be capable of acquiring associative strength in the first place
#
#
# ---oracion
# To attempt , in some intuition of evil , to understand them , to enact them , and so to <head>activate</head> and reveal the evil in one 's own soul
# ---oracione sin parentesis
# To attempt , in some intuition of evil , to understand them , to enact them , and so to <head>activate</head> and reveal the evil in one 's own soul
#
#
# ---oracion
# For all his doubts and self-irony , Palomar still wants to penetrate the secrets of the world and , to this end , what is seen acts only as a means of <head>activating</head> the thoughtfulness of language
# ---oracione sin parentesis
# For all his doubts and self-irony , Palomar still wants to penetrate the secrets of the world and , to this end , what is seen acts only as a means of <head>activating</head> the thoughtfulness of language
#
#
# ---oracion
# The sensor measures alkalinity and when the level falls below a pre - set value it <head>activates</head> a pump that delivers product from a bulk container to the tank in sufficient quantity to make up solution to the desired strength
# ---oracione sin parentesis
# The sensor measures alkalinity and when the level falls below a pre - set value it <head>activates</head> a pump that delivers product from a bulk container to the tank in sufficient quantity to make up solution to the desired strength
#
#
# ---oracion
# He had smelt burning and realized that the time pencil in one of their bombs had <head>activated</head>
# ---oracione sin parentesis
# He had smelt burning and realized that the time pencil in one of their bombs had <head>activated</head>
#
#
# ---oracion
# Turn on or <head>activate</head> any security devices you have fitted
# ---oracione sin parentesis
# Turn on or <head>activate</head> any security devices you have fitted
#
#
# ---oracion
# The unit will automatically activate if submerged , but should be <head>activated</head> prior to diving , either by immersing it in water or placing moistened fingertips on the two on contacts
# ---oracione sin parentesis
# The unit will automatically activate if submerged , but should be <head>activated</head> prior to diving , either by immersing it in water or placing moistened fingertips on the two on contacts
#
#
# ---oracion
# it has to provide a kind of internal sensation or perception in order to <head>activate</head> the correct response
# ---oracione sin parentesis
# it has to provide a kind of internal sensation or perception in order to <head>activate</head> the correct response
#
#
# ---oracion
# Set up in 1972 , the NRC is not a permanent body and is only <head>activated</head> in times of crisis as during the miners ' strike , from which two developments of particular importance emerged
# ---oracione sin parentesis
# Set up in 1972 , the NRC is not a permanent body and is only <head>activated</head> in times of crisis as during the miners ' strike , from which two developments of particular importance emerged
# ---oracion
# Mature striated muscle cells make muscle-specific proteins and when such a cell is fused with a variety of other cell types which include liver and cartilage cells , then muscle-specific genes are <head>activated</head> in these cells leading to the production of muscle-specific proteins
# ---oracione sin parentesis
# Mature striated muscle cells make muscle-specific proteins and when such a cell is fused with a variety of other cell types which include liver and cartilage cells , then muscle-specific genes are <head>activated</head> in these cells leading to the production of muscle-specific proteins
#
#
# ---oracion
# When this DNA construct is incorporated into the DNA of the developing embryo the protein will be made in those cells where the promoter is <head>activated</head> , even if the protein is quite inappropriate to the cell
# ---oracione sin parentesis
# When this DNA construct is incorporated into the DNA of the developing embryo the protein will be made in those cells where the promoter is <head>activated</head> , even if the protein is quite inappropriate to the cell
#
#
# ---oracion
# Shortly after birth , the mouse was fed water containing traces of metal , so <head>activating</head> the injected construct ; the result was a mouse almost twice the size of a normal mouse , and was affectionately labelled Supermouse
# ---oracione sin parentesis
# Shortly after birth , the mouse was fed water containing traces of metal , so <head>activating</head> the injected construct ; the result was a mouse almost twice the size of a normal mouse , and was affectionately labelled Supermouse
#
#
# ---oracion
# Activation of one gene can lead to the synthesis of a protein which <head>activates</head> some genes and inhibits others , which in turn may control yet other genes
# ---oracione sin parentesis
# Activation of one gene can lead to the synthesis of a protein which <head>activates</head> some genes and inhibits others , which in turn may control yet other genes
#
#
# ---oracion
# Its special property is that it can <head>activate</head> most of the genes that are required in the mature muscle
# ---oracione sin parentesis
# Its special property is that it can <head>activate</head> most of the genes that are required in the mature muscle
#
#
# ---oracion
# One can imagine how an external signal could <head>activate</head> a gene like myogenin and so guide the cell down the muscle pathway
# ---oracione sin parentesis
# One can imagine how an external signal could <head>activate</head> a gene like myogenin and so guide the cell down the muscle pathway
#
#
# ---oracion
# More recently , the degranulating action of platelet - <head>activating</head> factor has been demonstrated ( Chignard et al , 1979 ; McManus et al , 1979 )
# ---oracione sin parentesis
# More recently , the degranulating action of platelet - <head>activating</head> factor has been demonstrated
#
#
# ---oracion
# However , from experiments using thromboxane synthetase inhibitors it appears that when platelets are <head>activated</head> and the prostaglandin cascade is triggered by release of endogenous arachidonic acid then the endoperoxides generated exert their proaggregatory effects by their conversion to the more potent compound thromboxane A 2
# ---oracione sin parentesis
# However , from experiments using thromboxane synthetase inhibitors it appears that when platelets are <head>activated</head> and the prostaglandin cascade is triggered by release of endogenous arachidonic acid then the endoperoxides generated exert their proaggregatory effects by their conversion to the more potent compound thromboxane A 2
#
#
# ---oracion
# It has been proposed that endoperoxides and thromboxane A 2 <head>activate</head> platelets by acting as calcium ionophores , hence mobilising intracellular free calcium ( Gerrard et al , 1978 )
# ---oracione sin parentesis
# It has been proposed that endoperoxides and thromboxane A 2 <head>activate</head> platelets by acting as calcium ionophores , hence mobilising intracellular free calcium
#
#
# ---oracion
# Tsuboi et al , 1981 ) and to <head>activate</head> platelet adenylate cyclase leading to increased levels of cyclic AMP ( Lagarde et al , 1975 )
# ---oracione sin parentesis
# Tsuboi et al , 1981 ) and to <head>activate</head> platelet adenylate cyclase leading to increased levels of cyclic AMP ( Lagarde et al , 1975 )
#
#
# ---oracion
# I 'm sure Ness District deleted Devil 's Dance from the SCO posters but all that had been asleep was now <head>activated</head>
# ---oracione sin parentesis
# I 'm sure Ness District deleted Devil 's Dance from the SCO posters but all that had been asleep was now <head>activated</head>
#
#
# ---oracion
# This tangible negative force then <head>activates</head> the left side of your brain and projects onto the inner screen of your mind the failures mentioned earlier
# ---oracione sin parentesis
# This tangible negative force then <head>activates</head> the left side of your brain and projects onto the inner screen of your mind the failures mentioned earlier
#
#
# ---oracion
# STAGNATION Don't choose aggressive , adrenaline-inducing activities but use exercise to <head>activate</head> the body fully as our nervous system and chemistry have primed our bodies for this purpose
# ---oracione sin parentesis
# STAGNATION Don't choose aggressive , adrenaline-inducing activities but use exercise to <head>activate</head> the body fully as our nervous system and chemistry have primed our bodies for this purpose
#
#
# ---oracion
# When done briskly it will warm you up , <head>activating</head> your metabolism , eliminating stress-induced chemicals from the body , and exercising muscles and joints
# ---oracione sin parentesis
# When done briskly it will warm you up , <head>activating</head> your metabolism , eliminating stress-induced chemicals from the body , and exercising muscles and joints
#
#
# ---oracion
# The stress is usually an actual or perceived rejection , which <head>activates</head> the individual 's underlying sense of worthlessness
# ---oracione sin parentesis
# The stress is usually an actual or perceived rejection , which <head>activates</head> the individual 's underlying sense of worthlessness
#
#
# ---oracion
# These molecules go on to <head>activate</head> a nuclease enzyme that breaks down messenger RNA molecules used to make viral proteins
# ---oracione sin parentesis
# These molecules go on to <head>activate</head> a nuclease enzyme that breaks down messenger RNA molecules used to make viral proteins
#
#
# ---oracion
# Both enzymes appear to be <head>activated</head> by viral double-stranded RNA
# ---oracione sin parentesis
# Both enzymes appear to be <head>activated</head> by viral double-stranded RNA
#
#
# ---oracion
# Another idea thrown up by interferon research has been to make synthetic analogues of the 2 ' 5 ' oligoadenylate molecules formed in response to interferon and which <head>activate</head> the nuclease enzyme to break down viral messenger RNA
# ---oracione sin parentesis
# Another idea thrown up by interferon research has been to make synthetic analogues of the 2 ' 5 ' oligoadenylate molecules formed in response to interferon and which <head>activate</head> the nuclease enzyme to break down viral messenger RNA
#
#
# ---oracion
# All of which lends circumstantial weight to the idea that oncogenes may be <head>activated</head> by stripping them of their methyl groups and also explains the common observation that tumour cells may sometimes express inappropriately characteristics of other tissue cells
# ---oracione sin parentesis
# All of which lends circumstantial weight to the idea that oncogenes may be <head>activated</head> by stripping them of their methyl groups and also explains the common observation that tumour cells may sometimes express inappropriately characteristics of other tissue cells
#
#
# ---oracion
# At the same time they <head>activate</head> the rearranged DNA so that large quantities of antibody protein are produced from it
# ---oracione sin parentesis
# At the same time they <head>activate</head> the rearranged DNA so that large quantities of antibody protein are produced from it
#
#
# ---oracion
# This led George Klein , of the Karolinska Institute in Sweden , to suggest ( Nature , vol 294 , p 213 ) that these translocations might not just <head>activate</head> the antibody genes on the normal rearranged DNA they might also <head>activate</head> a proto - oncogene on chromosome 8
# ---oracione sin parentesis
# This led George Klein , of the Karolinska Institute in Sweden , to suggest  that these translocations might not just <head>activate</head> the antibody genes on the normal rearranged DNA they might also <head>activate</head> a proto - oncogene on chromosome 8
# ---oracion
# They suspected that it might work by inserting its own genes and in particular the promotor DNA that <head>activates</head> them next to an innocent cellular proto - oncogene , thus stirring it to an unnatural and cancer-causing level of activity
# ---oracione sin parentesis
# They suspected that it might work by inserting its own genes and in particular the promotor DNA that <head>activates</head> them next to an innocent cellular proto - oncogene , thus stirring it to an unnatural and cancer-causing level of activity
#
#
# ---oracion
# The beam needs to <head>activate</head> only two of the five cells on the staff
# ---oracione sin parentesis
# The beam needs to <head>activate</head> only two of the five cells on the staff
#
#
# ---oracion
# On the other hand , occupied localised states , confined to limited regions of the semiconductor , do exist adjacent to vacant localised states , at energies just below EF , and their electrons can move by thermally - <head>activated</head> hopping between sites
# ---oracione sin parentesis
# On the other hand , occupied localised states , confined to limited regions of the semiconductor , do exist adjacent to vacant localised states , at energies just below EF , and their electrons can move by thermally - <head>activated</head> hopping between sites
#
#
# ---oracion
# Such latent viruses can be re - <head>activated</head> by a variety of poorly understood influences ( including ultra violet radiation , carcinogens and other chemicals ) to produce a sudden outbreak of the viral disease
# ---oracione sin parentesis
# Such latent viruses can be re - <head>activated</head> by a variety of poorly understood influences  to produce a sudden outbreak of the viral disease
#
#
# ---oracion
# So far no-one has succeded in <head>activating</head> methane , but if the current rate of progress is maintained that feat must be just around the corner
# ---oracione sin parentesis
# So far no-one has succeded in <head>activating</head> methane , but if the current rate of progress is maintained that feat must be just around the corner
#
#
# ---oracion
# Now only one pixel in each column must be <head>activated</head> ; all the others must contrast with it
# ---oracione sin parentesis
# Now only one pixel in each column must be <head>activated</head> ; all the others must contrast with it
#
#
# ---oracion
# Some prototypes have been made with the LC molecules <head>activated</head> by laser light
# ---oracione sin parentesis
# Some prototypes have been made with the LC molecules <head>activated</head> by laser light
#
#
# ---oracion
# The liquid crystal molecules may adopt a random orientation when they are <head>activated</head> ( 2 ) and thus scatter light incident on the LC cell
# ---oracione sin parentesis
# The liquid crystal molecules may adopt a random orientation when they are <head>activated</head>  and thus scatter light incident on the LC cell
#
#
# ---oracion
# Malcom Green and Robin Perutz at Oxford University have harnessed matrix isolation work in the quest to find a simple way of <head>activating</head> methane , a process of enormous commercial interest because of the vast stores under the North Sea
# ---oracione sin parentesis
# Malcom Green and Robin Perutz at Oxford University have harnessed matrix isolation work in the quest to find a simple way of <head>activating</head> methane , a process of enormous commercial interest because of the vast stores under the North Sea
#
#
# ---oracion
# Unfortunately , the tungsten compound will not react with methane , so the problem of <head>activating</head> it is not yet solved
# ---oracione sin parentesis
# Unfortunately , the tungsten compound will not react with methane , so the problem of <head>activating</head> it is not yet solved
#
#
# ---oracion
# To <head>activate</head> the system , the shopkeeper passes the card through a magnetic-strip reader in the terminal , enters the cost of the purchase , and the customer punches out a personal code on a detachable keypad
# ---oracione sin parentesis
# To <head>activate</head> the system , the shopkeeper passes the card through a magnetic-strip reader in the terminal , enters the cost of the purchase , and the customer punches out a personal code on a detachable keypad
#
#
# ---oracion
# Many plant cells rapidly expand when their cell walls are acidified ; acid <head>activates</head> enzymes that increase the flexibility of cell walls
# ---oracione sin parentesis
# Many plant cells rapidly expand when their cell walls are acidified ; acid <head>activates</head> enzymes that increase the flexibility of cell walls
#
#
# ---oracion
# When the chimpanzees came close to the leopard , he <head>activated</head> its mechanism , so that it started to move its head
# ---oracione sin parentesis
# When the chimpanzees came close to the leopard , he <head>activated</head> its mechanism , so that it started to move its head
#
#
# ---oracion
# The soles of the feet should be in contact with the ground because receptors in the feet directly <head>activate</head> the postural muscles throughout the torso
# ---oracione sin parentesis
# The soles of the feet should be in contact with the ground because receptors in the feet directly <head>activate</head> the postural muscles throughout the torso
#
#
# ---oracion
# If these are not <head>activated</head> , by having the legs stretched out in front , for example , then you will end up sitting in a slumped manner
# ---oracione sin parentesis
# If these are not <head>activated</head> , by having the legs stretched out in front , for example , then you will end up sitting in a slumped manner
#
#
# ---oracion
# To advocate the starting of the process on a very young child might appear to be heartless , but the overriding need to generate within the child mind the beginning of a conscience and the instinctive urge to <head>activate</head> it , must be the guiding factor
# ---oracione sin parentesis
# To advocate the starting of the process on a very young child might appear to be heartless , but the overriding need to generate within the child mind the beginning of a conscience and the instinctive urge to <head>activate</head> it , must be the guiding factor
#
#
# ---oracion
# The other type of cat one that is given a more excitingly varied diet has its food variety mechanism fully <head>activated</head> throughout its life and therefore becomes more demanding and fussy with food
# ---oracione sin parentesis
# The other type of cat one that is given a more excitingly varied diet has its food variety mechanism fully <head>activated</head> throughout its life and therefore becomes more demanding and fussy with food
#
#
# ---oracion
# The system can <head>activate</head> central alarms or shut down distribution systems in affected areas
# ---oracione sin parentesis
# The system can <head>activate</head> central alarms or shut down distribution systems in affected areas
#
#
# ---oracion
# On the other hand , as the presence of a splinter of wood in the finger readily proves , tissues have very effective sensors for foreign objects , and defence mechanisms are readily <head>activated</head>
# ---oracione sin parentesis
# On the other hand , as the presence of a splinter of wood in the finger readily proves , tissues have very effective sensors for foreign objects , and defence mechanisms are readily <head>activated</head>
#
#
# ---oracion
# One of them <head>activates</head> a secret latch , book shelves swing aside to reveal a flight of descending stone steps
# ---oracione sin parentesis
# One of them <head>activates</head> a secret latch , book shelves swing aside to reveal a flight of descending stone steps
#
#
# ---oracion
# Their purpose is to <head>activate</head> local debate but on terms laid down by the dominant ideology
# ---oracione sin parentesis
# Their purpose is to <head>activate</head> local debate but on terms laid down by the dominant ideology
#
#
# ---oracion
# The ease of application , fluidity and prompt absorption are of prime importance for such products and the massaging action on the affected area helps to <head>activate</head> the ingredients of the cream and improve circulation
# ---oracione sin parentesis
# The ease of application , fluidity and prompt absorption are of prime importance for such products and the massaging action on the affected area helps to <head>activate</head> the ingredients of the cream and improve circulation
# ---oracion
# However , the statement also lacks any structure to be <head>activated</head>
# ---oracione sin parentesis
# However , the statement also lacks any structure to be <head>activated</head>
#
#
# ---oracion
# If this cleaving or oneness is actually to occur , it must be <head>activated</head> by a commitment to intimacy , not just physical intimacy but spiritual and psychological intimacy as well
# ---oracione sin parentesis
# If this cleaving or oneness is actually to occur , it must be <head>activated</head> by a commitment to intimacy , not just physical intimacy but spiritual and psychological intimacy as well
#
#
# ---oracion
# Alarms can either be rigged up in every room in your house , or you can wear an alarm unit on your person , to <head>activate</head> in times of need
# ---oracione sin parentesis
# Alarms can either be rigged up in every room in your house , or you can wear an alarm unit on your person , to <head>activate</head> in times of need
#
#
# ---oracion
# He ran up the ramp , the sergeant liftmaster <head>activating</head> the hydraulics even before he had set loot on it
# ---oracione sin parentesis
# He ran up the ramp , the sergeant liftmaster <head>activating</head> the hydraulics even before he had set loot on it
#
#
# ---oracion
# They both knew that no timer could be relied upon to be that sensitive , that when he <head>activated</head> it , the chances were reasonable that it would detonate instantly before he could throw it
# ---oracione sin parentesis
# They both knew that no timer could be relied upon to be that sensitive , that when he <head>activated</head> it , the chances were reasonable that it would detonate instantly before he could throw it
#
#
# ---oracion
# You take the pen out and it automatically <head>activates</head> the recording mechanism
# ---oracione sin parentesis
# You take the pen out and it automatically <head>activates</head> the recording mechanism
#
#
# ---oracion
# It 's irritatingly easy to crash at first , as the pushscroll is only <head>activated</head> when you 're more than halfway across the screen , giving you little time to see and avoid hazards
# ---oracione sin parentesis
# It 's irritatingly easy to crash at first , as the pushscroll is only <head>activated</head> when you 're more than halfway across the screen , giving you little time to see and avoid hazards
#
#
# ---oracion
# UV - <head>activated</head>
# ---oracione sin parentesis
# UV - <head>activated</head>
#
#
# ---oracion
# Each output <head>activates</head> the clock for the next one in line
# ---oracione sin parentesis
# Each output <head>activates</head> the clock for the next one in line
#
#
# ---oracion
# This closure is only momentary because of the differentiating action of the coupling components capacitor C6 and resistor R21 , and the rest of the circuit is then <head>activated</head> in the way already explained
# ---oracione sin parentesis
# This closure is only momentary because of the differentiating action of the coupling components capacitor C6 and resistor R21 , and the rest of the circuit is then <head>activated</head> in the way already explained
#
#
# ---oracion
# Because the BT Azure is Britain 's first totally voice - <head>activated</head> cellphone
# ---oracione sin parentesis
# Because the BT Azure is Britain 's first totally voice - <head>activated</head> cellphone
#
#
# ---oracion
# Resist may also be too thick or artwork film too opaque , and has not been thoroughly <head>activated</head> by the UV light see above
# ---oracione sin parentesis
# Resist may also be too thick or artwork film too opaque , and has not been thoroughly <head>activated</head> by the UV light see above
#
#
# ---oracion
# Sound <head>activated</head> , it will soon send out good vibrations to the rest of the groovers
# ---oracione sin parentesis
# Sound <head>activated</head> , it will soon send out good vibrations to the rest of the groovers
#
#
# ---oracion
# The answer was found during detailed studies of the trigger mechanism which <head>activates</head> the anemone 's nematocysts or stinging cells
# ---oracione sin parentesis
# The answer was found during detailed studies of the trigger mechanism which <head>activates</head> the anemone 's nematocysts or stinging cells
#
#
# ---oracion
# Alongside the power socket are a pair of sockets from which to remotely switch the effect bypass and to take the ME-6 from program into manual mode , where each of the 6 pedals <head>activates</head> individual effects , making the ME-6 work just like a series of ordinary pedals
# ---oracione sin parentesis
# Alongside the power socket are a pair of sockets from which to remotely switch the effect bypass and to take the ME-6 from program into manual mode , where each of the 6 pedals <head>activates</head> individual effects , making the ME-6 work just like a series of ordinary pedals
#
#
# ---oracion
# it can be left to recall programmed patches or , by using the manual programming button , be set to operate like a series of pedals with each footswitch <head>activating</head> an effect in real time
# ---oracione sin parentesis
# it can be left to recall programmed patches or , by using the manual programming button , be set to operate like a series of pedals with each footswitch <head>activating</head> an effect in real time
#
#
# ---oracion
# You then press the relevant patch pedal to set the bank number and repress the relevant patch pedal to <head>activate</head> the chosen sound
# ---oracione sin parentesis
# You then press the relevant patch pedal to set the bank number and repress the relevant patch pedal to <head>activate</head> the chosen sound
#
#
# ---oracion
# In play mode , rotating this control selects effect chains , and when pushed it <head>activates</head> the bypass function
# ---oracione sin parentesis
# ...
# ---oracione sin parentesis
# recall the Fodor 's <head>argument</head> against learning
#
#
# ---oracion
# It will rely upon an <head>argument</head> from Kant
# ---oracione sin parentesis
# It will rely upon an <head>argument</head> from Kant
#
#
# ---oracion
# Coda We have covered a lot of ground , and maybe the path through the undergrowth of <head>arguments</head> and data is not a very straight or a very clear one
# ---oracione sin parentesis
# Coda We have covered a lot of ground , and maybe the path through the undergrowth of <head>arguments</head> and data is not a very straight or a very clear one
#
#
# ---oracion
# There are <head>arguments</head> for all possible positions , but none of them convinces us for long ( see chapters 1 and 5 )
# ---oracione sin parentesis
# There are <head>arguments</head> for all possible positions , but none of them convinces us for long
#
#
# ---oracion
# First , there is the dualist 's <head>argument</head> that mental processes cannot be physical processes because physical entities such as neurons-lack certain qualities such as intentionality or consciousness that characterize the mental
# ---oracione sin parentesis
# First , there is the dualist 's <head>argument</head> that mental processes cannot be physical processes because physical entities such as neurons-lack certain qualities such as intentionality or consciousness that characterize the mental
#
#
# ---oracion
# If it is really necessary to think of mental states as having qualitative content ( and see Dennett , 1988 , for some powerful <head>arguments</head> that it is not ) , then it follows from functionalism that such qualia do not have causal interactions with other mental states or behaviour and are mere epiphenomena
# ---oracione sin parentesis
# and see Dennett , 1988 , for some powerful <head>arguments</head> that it is not
#
#
# ---oracion
# I have not provided any convincing <head>arguments</head> as to why one should believe it
# ---oracione sin parentesis
# I have not provided any convincing <head>arguments</head> as to why one should believe it
#
#
# ---oracion
# And although the majority of materialist philosophers base their belief in the neurophysiological theory of perception on <head>arguments</head> rather than observations , they are , nevertheless , greatly influenced by the apparent successes of neurophysiology
# ---oracione sin parentesis
# And although the majority of materialist philosophers base their belief in the neurophysiological theory of perception on <head>arguments</head> rather than observations , they are , nevertheless , greatly influenced by the apparent successes of neurophysiology
#
#
# ---oracion
# A further telling <head>argument</head> against the dual aspect theory-and one that has been rarely noticed is that aspects are relative to viewpoints ; in other words , they emerge posterior to perceptions
# ---oracione sin parentesis
# A further telling <head>argument</head> against the dual aspect theory-and one that has been rarely noticed is that aspects are relative to viewpoints ; in other words , they emerge posterior to perceptions
#
#
# ---oracion
# However , it is necessary to say a word or two here to refute this seemingly compelling <head>argument</head>
# ---oracione sin parentesis
# However , it is necessary to say a word or two here to refute this seemingly compelling <head>argument</head>
#
#
# ---oracion
# Afterwards somehow an <head>argument</head> started
# ---oracione sin parentesis
# Afterwards somehow an <head>argument</head> started
#
#
# ---oracion
# Their <head>argument</head> is that it is good for the tournament , a s well as the players concerned , if as many as possible of the higher ranked competitors survive the early rounds
# ---oracione sin parentesis
# Their <head>argument</head> is that it is good for the tournament , a s well as the players concerned , if as many as possible of the higher ranked competitors survive the early rounds
#
#
# ---oracion
# The conflicts within British tennis As Wimbledon again approaches , the <head>arguments</head> about why British tennis is so poor still rage on , and are getting even more heated
# ---oracione sin parentesis
# The conflicts within British tennis As Wimbledon again approaches , the <head>arguments</head> about why British tennis is so poor still rage on , and are getting even more heated
#
#
# ---oracion
# The government accepted the <head>argument</head> , and approved the investment
# ---oracione sin parentesis
# The government accepted the <head>argument</head> , and approved the investment
#
#
# ---oracion
# And David Gardner 's defence of processed hops does remind the listener powerfully of the <head>arguments</head> advanced by the brewers in the 1960s when they were replacing cask ale with keg beer
# ---oracione sin parentesis
# And David Gardner 's defence of processed hops does remind the listener powerfully of the <head>arguments</head> advanced by the brewers in the 1960s when they were replacing cask ale with keg beer
#
#
# ---oracion
# I 've outlined above , and which is our common heritage , should cast around for some solid <head>arguments</head> to counter its spread
# ---oracione sin parentesis
# I 've outlined above , and which is our common heritage , should cast around for some solid <head>arguments</head> to counter its spread
#
#
# ---oracion
# Controversy and <head>argument</head> attract notoriety
# ---oracione sin parentesis
# Controversy and <head>argument</head> attract notoriety
#
#
# ---oracion
# The Observer , the photograph that appeared alongside it gives the lie to this self-generated <head>argument</head>
# ---oracione sin parentesis
# The Observer , the photograph that appeared alongside it gives the lie to this self-generated <head>argument</head>
#
#
# ---oracion
# Let the <head>argument</head> rage about the ethics of bolting
# ---oracione sin parentesis
# Let the <head>argument</head> rage about the ethics of bolting
#
#
# ---oracion
# While acknowledging his <head>argument</head> for the bolt placement ,
# ---oracione sin parentesis
# While acknowledging his <head>argument</head> for the bolt placement ,
# ---oracion
# This statement can defend both sides of the <head>argument</head>
# ---oracione sin parentesis
# This statement can defend both sides of the <head>argument</head>
#
#
# ---oracion
# As for the other matter , it sounds like your dog could have earned his scabs by either defending himself , or having an <head>argument</head> with a cat
# ---oracione sin parentesis
# As for the other matter , it sounds like your dog could have earned his scabs by either defending himself , or having an <head>argument</head> with a cat
#
#
# ---oracion
# This distinction should be preserved ( even though the Russian verb is not quite square with the English ) , since it belongs to the novel 's overall against-logic <head>argument</head>
# ---oracione sin parentesis
# This distinction should be preserved  , since it belongs to the novel 's overall against-logic <head>argument</head>
#
#
# ---oracion
# As with the censored Christian <head>argument</head> in Notes from Underground ,
# ---oracione sin parentesis
# As with the censored Christian <head>argument</head> in Notes from Underground ,
#
#
# ---oracion
# This <head>argument</head> just does not hold water
# ---oracione sin parentesis
# This <head>argument</head> just does not hold water
#
#
# ---oracion
# Look at the <head>arguments</head>
# ---oracione sin parentesis
# Look at the <head>arguments</head>
#
#
# ---oracion
# It uses post fix notation , where <head>arguments</head> come first and operators follow
# ---oracione sin parentesis
# It uses post fix notation , where <head>arguments</head> come first and operators follow
#
#
# ---oracion
# It acknowledges that the following texts and their <head>arguments</head> are difficult , but the difficulty is not to be hidden we ourselves have no right to hide it
# ---oracione sin parentesis
# It acknowledges that the following texts and their <head>arguments</head> are difficult , but the difficulty is not to be hidden we ourselves have no right to hide it
#
#
# ---oracion
# His <head>arguments</head> are fast-moving but inexact , and he engages in some wild flourishes of
# ---oracione sin parentesis
# His <head>arguments</head> are fast-moving but inexact , and he engages in some wild flourishes of
#
#
# ---oracion
# He takes poststructuralist assumptions about the death of the author and the disappearance of the self-subsistent ego , and applies them to the history of English poetry , in a work which combines ingenious close reading , impressive knowledge of metre , and an overall <head>argument</head> of stratospheric thinness and remoteness
# ---oracione sin parentesis
# He takes poststructuralist assumptions about the death of the author and the disappearance of the self-subsistent ego , and applies them to the history of English poetry , in a work which combines ingenious close reading , impressive knowledge of metre , and an overall <head>argument</head> of stratospheric thinness and remoteness
#
#
# ---oracion
# The use of names rather than <head>arguments</head> as ammunition has become noticeable in such exercises , on both sides of the Atlantic , as Chris Baldick remarks in a review of Frederick Crews 's
# ---oracione sin parentesis
# The use of names rather than <head>arguments</head> as ammunition has become noticeable in such exercises , on both sides of the Atlantic , as Chris Baldick remarks in a review of Frederick Crews 's
#
#
# ---oracion
# One lamentable practice which Crews rightly scorns is the increasingly revived trick or medieval rhetoric in which one attempts to substantiate one 's theoretical <head>argument</head> not by anything so vulgarly empirical as a fact or a text but merely by invoking a name from the sacred pantheon
# ---oracione sin parentesis
# One lamentable practice which Crews rightly scorns is the increasingly revived trick or medieval rhetoric in which one attempts to substantiate one 's theoretical <head>argument</head> not by anything so vulgarly empirical as a fact or a text but merely by invoking a name from the sacred pantheon
#
#
# ---oracion
# Tallis 's case is convincing , though he has certainly not said the last word on the matter , and there may well be further <head>arguments</head> from those who are professionally engaged in linguistics
# ---oracione sin parentesis
# Tallis 's case is convincing , though he has certainly not said the last word on the matter , and there may well be further <head>arguments</head> from those who are professionally engaged in linguistics
#
#
# ---oracion
# Scholes , however , believes that Saussure is himself inconsistent , and responsible for later confusion , but the thrust of his <head>argument</head> is very close to Tallis 's , and both of them are concerned as were Thurley and Nuttall to reinstate the validity of reference and to deny that language is a system of pure differences , without relation to reality
# ---oracione sin parentesis
# Scholes , however , believes that Saussure is himself inconsistent , and responsible for later confusion , but the thrust of his <head>argument</head> is very close to Tallis 's , and both of them are concerned as were Thurley and Nuttall to reinstate the validity of reference and to deny that language is a system of pure differences , without relation to reality
#
#
# ---oracion
# it argues against reason by the processes of reason , and a political cause , however radical , cannot be advanced without the traditional processes of <head>argument</head> and attending to evidence
# ---oracione sin parentesis
# it argues against reason by the processes of reason , and a political cause , however radical , cannot be advanced without the traditional processes of <head>argument</head> and attending to evidence
#
#
# ---oracion
# This is an interestingly eclectic <head>argument</head> which recalls Gadamer on the fusion of horizons ( the reader 's and the text 's ) , Marcuse on the utopian possibilities of high culture , and Sartre on the necessarily progressive implications of major literature
# ---oracione sin parentesis
# This is an interestingly eclectic <head>argument</head> which recalls Gadamer on the fusion of horizons  , Marcuse on the utopian possibilities of high culture , and Sartre on the necessarily progressive implications of major literature
#
#
# ---oracion
# Skeptical Engagements , he provides detailed and substantially supported <head>arguments</head> for abandoning it
# ---oracione sin parentesis
# Skeptical Engagements , he provides detailed and substantially supported <head>arguments</head> for abandoning it
#
#
# ---oracion
# Yet his system , like others on the contemporary scene , is constructed so as to repel <head>argument</head> or contrary evidence
# ---oracione sin parentesis
# Yet his system , like others on the contemporary scene , is constructed so as to repel <head>argument</head> or contrary evidence
#
#
# ---oracion
# This question provoked <head>arguments</head> in America about the Norton Anthology of Literature by Women , some of the contents of which were said to have had little value as literature
# ---oracione sin parentesis
# This question provoked <head>arguments</head> in America about the Norton Anthology of Literature by Women , some of the contents of which were said to have had little value as literature
#
#
# ---oracion
# In this light , <head>arguments</head> about Derrida 's meaning have the fascination and intractability of <head>arguments</head> about the interpretation of , say , Eliot 's poetry
# ---oracione sin parentesis
# In this light , <head>arguments</head> about Derrida 's meaning have the fascination and intractability of <head>arguments</head> about the interpretation of , say , Eliot 's poetry
#
#
# ---oracion
# This was the position argued some years ago by practitioners of la nouvelle critique , who believed that clarity in <head>argument</head> was a form of ideological mystification , reinforcing the status quo
# ---oracione sin parentesis
# This was the position argued some years ago by practitioners of la nouvelle critique , who believed that clarity in <head>argument</head> was a form of ideological mystification , reinforcing the status quo
#
#
# ---oracion
# I complained in my review that it was studded with references to fashionable French gurus that were purely cosmetic , adding nothing to the author 's <head>argument</head>
# ---oracione sin parentesis
# I complained in my review that it was studded with references to fashionable French gurus that were purely cosmetic , adding nothing to the author 's <head>argument</head>
# ---oracion
# Something similar is true of politics , another transcendent signified and <head>argument</head> - stopper
# ---oracione sin parentesis
# Something similar is true of politics , another transcendent signified and <head>argument</head> - stopper
#
#
# ---oracion
# In a published <head>argument</head> between Scholes and Hirsch , the former made the following statement , on the assumption that the conservative Hirsch would disagree with it
# ---oracione sin parentesis
# In a published <head>argument</head> between Scholes and Hirsch , the former made the following statement , on the assumption that the conservative Hirsch would disagree with it
#
#
# ---oracion
# Lewis 's <head>argument</head> that any piece of writing has a claim to being literary if someone can read it in a literary i
# ---oracione sin parentesis
# Lewis 's <head>argument</head> that any piece of writing has a claim to being literary if someone can read it in a literary i
#
#
# ---oracion
# The latter presentation is not so common , because of the generally unfavourable associations of aesthetic in our culture , though it is implied whenever students are asked to approach a poem as a work of art , rather than as an historical document or a philosophical <head>argument</head>
# ---oracione sin parentesis
# The latter presentation is not so common , because of the generally unfavourable associations of aesthetic in our culture , though it is implied whenever students are asked to approach a poem as a work of art , rather than as an historical document or a philosophical <head>argument</head>

# %%
pairs_train.shape
# Out:
# (8642, 4)

# %%
file_path_train = 'data_train_con_poda.json'
save_json(file_path_train, pairs_train)

# %%
pairs_test = construct_pairs('corpus/test/EnglishLS.test', '/home/krivas/projects/wsd-v2/',\
                             is_train=False, test_path='corpus/test/EnglishLS.test.key', prune_sentence=False, verbose=True)
# Out:
# /home/krivas/anaconda3/lib/python3.6/site-packages/nltk/tag/stanford.py:183: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordNERTagger, self).__init__(*args, **kwargs)
# ---oracion
# Sodalities , such as the Legion of Mary , Opus Dei , and Christian Life communities , have partially extended this form of commitment to some , particularly more middle-class laity , and continue to have an important role in <head>activating</head> laity for what are judged to be religious goals both personally and socially
# ---oracione sin parentesis
# an important role in activating laity for what .
#
#
# ---oracion
# Avoid fitting one in the kitchen , as fumes from cooking are often enough to <head>activate</head> the alarm
# ---oracione sin parentesis
# Avoid fitting one in the kitchen , as fumes from cooking are often enough to activate the alarm .
#
#
# ---oracion
# SHOTECTOR works by monitoring the current flowing in the live and neutral wires and is <head>activated</head> by any leakage of current to earth perhaps through you
# ---oracione sin parentesis
# SHOTECTOR works by and is activated by any leakage of current to earth perhaps through you .
#
#
# ---oracion
# Some work on electronic beams , while others are <head>activated</head> by air movement just opening the door can be enough to set off this type
# ---oracione sin parentesis
# others are activated by air movement just opening the door .
#
#
# ---oracion
# Variable confidence and prediction internals can be <head>activated</head> , special function parameters displayed , a data summary for a selected equation viewed , and data residuals displayed either directly as data , in percentaged form , or graphically
# ---oracione sin parentesis
# Variable confidence and prediction internals can be activated .
#
#
# ---oracion
# On June 22 1897 , the Queen , in the telegraph room at Buckingham Palace , pressed the button <head>activating</head> the Central Telegraph Office 's equipment in St
# ---oracione sin parentesis
# June 22 1897 , the Queen , in the telegraph room at Buckingham Palace , pressed the button activating the Central Telegraph Office 's equipment in St .
#
#
# ---oracion
# Mr Glennie <head>activated</head> an emergency locator beacon , and they were confident of being rescued within a week
# ---oracione sin parentesis
# Mr Glennie activated an emergency locator beacon .
#
#
# ---oracion
# They are difficult to locate and <head>activate</head>
# ---oracione sin parentesis
# They are difficult and activate .
#
#
# ---oracion
# The virus is <head>activated</head> when the computer program is executed by running it on a computer
# ---oracione sin parentesis
# The virus is activated .
#
#
# ---oracion
# Hong Kong Receiving a copy of the AGM Minutes from the Branch prompts Air Mail to give a little space to describe the activities and efforts being made by the Branch Committee , a committee which has been virtually unchanged since the Branch was re - <head>activated</head> six years ago
# ---oracione sin parentesis
# the Branch was re - activated six years ago .
#
#
# ---oracion
# A violent , enduring mythology is <head>activated</head> to make sense of immediate socio-political crisis and fear
# ---oracione sin parentesis
# A violent , enduring mythology is activated .
#
#
# ---oracion
# Twin adds a second lens of 70mm focal length , <head>activated</head> at the touch of a button
# ---oracione sin parentesis
# Twin adds a second lens of 70mm focal length , activated at the touch of a button .
#
#
# ---oracion
# Two other plans , not <head>activated</head> in the present dispute , were also drawn up
# ---oracione sin parentesis
# Two other plans , not activated in the present dispute , were also drawn up .
#
#
# ---oracion
# The old hydraulically - <head>activated</head> system had 10 small clutch plates , whereas the new one has a bigger 23cm ( 9in ) flywheel and four big plates
# ---oracione sin parentesis
# activated system had 10 small clutch plates .
#
#
# ---oracion
# I know how to program the software that <head>activates</head> the Goddess
# ---oracione sin parentesis
# the software that activates the Goddess .
#
#
# ---oracion
# <head>activated</head> to demand compensation , they then relapsed into the noumenon , leaving households to go about their business ; revenues from taxes were not kept in a fisc , but allocated to household budgets and so on
# ---oracione sin parentesis
# activated to demand compensation , they then relapsed into the noumenon , ; .
#
#
# ---oracion
# a separate jet of steam , which is <head>activated</head> by a button on top of the handle , is useful for sniper attacks on to-defeat cuff wrinkles
# ---oracione sin parentesis
# a separate jet of steam , which is activated by a button on top of the handle .
#
#
# ---oracion
# Karpov decided to enter an end game in the hope of relieving the pressure , but Short skilfully took control of the only open file on the board with both his rooks and <head>activated</head> the king and advanced his pawn majority on the queenside
# ---oracione sin parentesis
# Karpov decided , but Short skilfully took control of the only open file on the board with both his rooks and activated the king and advanced his pawn majority on the queenside .
#
#
# ---oracion
# But it does not <head>activate</head> taste buds and has no intrinsic flavour
# ---oracione sin parentesis
# But it does not activate taste buds and has no intrinsic flavour .
#
#
# ---oracion
# Concealed inside are three motors which control the movement of its limbs and <head>activate</head> a recording of its manic laugh
# ---oracione sin parentesis
# three motors which control the movement of its limbs and activate a recording of its manic laugh .
#
#
# ---oracion
# It was some species of voice - <head>activated</head> flytrap she had never heard of
# ---oracione sin parentesis
# activated flytrap .
#
#
# ---oracion
# Once <head>activated</head> , dysfunctional assumptions produce negative automatic thoughts negative in that they are associated with unpleasant emotions and automatic in that they pop into people 's heads rather than being the product of any deliberate reasoning process
# ---oracione sin parentesis
# activated , dysfunctional assumptions produce .
#
#
# ---oracion
# A stronger ( long ) serotonin stimulus causes the release of amino acids which <head>activate</head> the NMDA receptors , leading to long term memory
# ---oracione sin parentesis
# the release of amino acids which activate the NMDA receptors .
#
#
# ---oracion
# As he approaches the garage door it swings open as if by magic in fact by electricity , <head>activated</head> by a remote-control device in Vic 's pocket a feat that never fails to give him a deep , childlike pleasure
# ---oracione sin parentesis
# it swings open as if by magic in fact by electricity , activated by a remote-control device in Vic 's pocket a feat .
#
#
# ---oracion
# To the extent that this identification is more likely to be made when the stimulus in question is already capable of <head>activating</head> a detailed representation , the likelihood of a vigorous CR may be increased
# ---oracione sin parentesis
# the extent that this identification is more likely to be made when the stimulus in question is already capable of activating a detailed representation , the likelihood of a vigorous CR may be increased .
#
#
# ---oracion
# For our present purposes , however , the important feature of the model is that it develops the implications of the widely accepted notion that even the simplest stimulus will consist of a set ( probably a large number ) of elements and that only some of these will be sampled ( will <head>activate</head> their central representations ) on a given exposure ( cf
# ---oracione sin parentesis
# our present purposes , however , the important feature of the model is that and that only some of these will be sampled  on a given exposure -LRB- cf .
#
#
# ---oracion
# According to this alternative view , the target association may be formed perfectly normally but since , on a subsequent test trial , both this and any previously learned association will become <head>activated</head> when the CS is presented , the subjects may fail to retrieve the correct one and the likelihood of the CR will be reduced
# ---oracione sin parentesis
# both this and any previously learned association will become activated .
#
#
# ---oracion
# In a different context , however , the CS will be able to evoke Al and since the Al state is better than A2 at <head>activating</head> an associative link , the CS will be better able to elicit its CR when the context is changed
# ---oracione sin parentesis
# better than A2 at activating an associative link .
#
#
# ---oracion
# Thus B would become capable of activating the US representation ( and of evoking a CR ) by way of its ability to <head>activate</head> the X representation
# ---oracione sin parentesis
# its ability to activate the X representation .
#
#
# ---oracion
# 11 ( b ) shows an increase in the areas a and b with a consequent reduction in the proportion ( although not the absolute number ) of c elements <head>activated</head> by a stimulus
# ---oracione sin parentesis
# 11  shows an increase in the areas a and b with a consequent reduction in the proportion  of c elements activated by a stimulus .
#
#
# ---oracion
# Sure enough , the twenty-minute time pencils <head>activated</head> the detonators and up went the aircraft
# ---oracione sin parentesis
# Sure enough , the twenty-minute time pencils activated the detonators and up went the aircraft .
#
#
# ---oracion
# First impressions are of a compact unit , encased in a heavy-duty rubber wrist pod , with clearly readable figures on its LCD display and one actuating button underneath the screen at last a move away from water <head>activated</head> touch-type buttons
# ---oracione sin parentesis
# First impressions are of a compact unit , encased in a heavy-duty rubber wrist pod , with clearly readable figures on its LCD display and one actuating button underneath the screen at last a move away from water activated touch-type buttons .
#
#
# ---oracion
# Try <head>activating</head> again , or wait a little while before re-activation
# ---oracione sin parentesis
# Try activating again , or wait a little while before re-activation .
#
#
# ---oracion
# Dale and his colleagues in the 1930s showed that acetylcholine , in addition to its other properties , was a local hormone relaying messages at autonomic ganglia , that is at critical points in the nerve pathways which control the heart and blood vessels , and at the sites where nerves <head>activate</head> voluntary muscles
# ---oracione sin parentesis
# nerves activate voluntary muscles .
#
#
# ---oracion
# Specific promoters are <head>activated</head> in specific cells
# ---oracione sin parentesis
# Specific promoters are activated in specific cells .
#
#
# ---oracion
# One such gene is myogenin which <head>activates</head> a set of genes in muscle development
# ---oracione sin parentesis
# myogenin which activates a set of genes in muscle development .
#
#
# ---oracion
# In relation to stress , regular exercise increases the circulation which in turn increases oxygen levels in the blood and <head>activates</head> the hormonal system ( the endocrine glands )
# ---oracione sin parentesis
# the circulation which in turn increases oxygen levels in the blood and activates the hormonal system  .
#
#
# ---oracion
# Platelets <head>activated</head> by thrombin were found to produce haemagglutinin activity with fixed bovine erythrocytes ( Gartner et al , 1980 ) , and subsequently the same group have shown that this agglutinin is bound to platelet membranes and appears in the incubation fluid following platelet activation by thrombin ( Gartner et al , 1980 )
# ---oracione sin parentesis
# Platelets activated by thrombin were found .
#
#
# ---oracion
# I can <head>activate</head> within my unconscious the healing power
# ---oracione sin parentesis
# I can activate within my unconscious the healing power .
#
#
# ---oracion
# The Ijmuiden Ridge forms the southern edge of the inverted Broad Fourteens Basin and has the characteristics of a line of complex re - <head>activated</head> fault movement
# ---oracione sin parentesis
# The Ijmuiden Ridge forms the southern edge of the inverted Broad Fourteens Basin and has the characteristics of a line of complex re - activated fault movement .
#
#
# ---oracion
# Researchers have now discovered that even by themselves , promoters can stimulate cells to produce <head>activated</head> forms of oxygen , known as free radicals
# ---oracione sin parentesis
# cells to produce activated forms of oxygen , known as free radicals .
#
#
# ---oracion
# And recent research has dramatically shown that one way for them to make the break is through the activation of cellular oncogenes genes that are more or less inactive in normal cells hut seem to be altered or <head>activated</head> in tumour cells ( New
# ---oracione sin parentesis
# normal cells hut seem to be altered or activated in tumour cells -LRB- New .
#
#
# ---oracion
# Plainly in any less desperate case the risk of <head>activating</head> oncogenes would absolutely forbid the use of such a drug
# ---oracione sin parentesis
# the risk of activating oncogenes would absolutely forbid the use of such a drug .
#
#
# ---oracion
# But while these reports neatly confirm Kein 's and Hayward 's ideas about the activation of proto - oncogenes in leukaemias and lymphomas , they have also helped to unleash a surprisingly violent controversy about how the proto - oncogene is <head>activated</head>
# ---oracione sin parentesis
# the proto - oncogene is activated .
#
#
# ---oracion
# Once attached to a metal , an alkane is <head>activated</head>
# ---oracione sin parentesis
# an alkane is activated .
#
#
# ---oracion
# Although these transition metal compounds will <head>activate</head> carbon-hydrogen bonds , they do not behave catalytically , and so are of limited practical value
# ---oracione sin parentesis
# these transition metal compounds will activate carbon-hydrogen bonds .
#
#
# ---oracion
# If the body is used in an uncoordinated fashion some of the reflexes are not triggered and , therefore , do not <head>activate</head> the postural muscles
# ---oracione sin parentesis
# some of the reflexes are not triggered and , therefore , do not activate the postural muscles .
#
#
# ---oracion
# Voltage and current signals can be used to pre - set speed or to call up the actual values for speed and torque , and the start/stop functions can be <head>activated</head> using the same method
# ---oracione sin parentesis
# the start/stop functions can be activated .
#
#
# ---oracion
# Following swelling of the polymer beads , free-radical addition polymerisation is <head>activated</head> by using heat , with benzoyl peroxide as the initiator
# ---oracione sin parentesis
# Following swelling of the polymer beads , free-radical addition polymerisation is activated .
#
#
# ---oracion
# ( a ) Experimental set-up for measuring of cuspal deformation in teeth during light - <head>activated</head> polymerisation of a polymer-composite restorative material
# ---oracione sin parentesis
#  Experimental set-up for measuring of cuspal deformation in teeth during light - activated polymerisation of a polymer-composite restorative material .
#
#
# ---oracion
# Recently , hybrid glass ionomers have been made that cure partly by light - <head>activated</head> polymerisation , besides the normal acid-base setting reaction
# ---oracione sin parentesis
# that cure partly by light - activated polymerisation , besides the normal acid-base setting reaction .
#
#
# ---oracion
# If so , how are they <head>activated</head>
# ---oracione sin parentesis
# so , how are they activated .
#
#
# ---oracion
# I put the binoculars up again , found him , <head>activated</head> the automatic focus , pressed the button , heard the quiet click of the shutter
# ---oracione sin parentesis
# I put the binoculars up again , found him , activated the automatic focus , pressed the button , heard the quiet click of the shutter .
#
#
# ---oracion
# Unlike still red wines , sparkling Champagne does not benefit from a detectable tannin content , although a little tannin will be added prior to the last racking to <head>activate</head> the fining agent
# ---oracione sin parentesis
# still red wines , sparkling Champagne does not benefit from a detectable tannin content , although a little tannin will be added prior to the last racking to activate the fining agent .
#
#
# ---oracion
# I think she was probably <head>activated</head> by a divine obstinacy
# ---oracione sin parentesis
# she was probably activated by a divine obstinacy .
#
#
# ---oracion
# When the onboard tuner is <head>activated</head> in this way the guitar signal is instantly muted , avoiding the need for the player to bend down to the tuner switch on the unit , or re-patch the guitar lead
# ---oracione sin parentesis
# the onboard tuner is activated in this way .
# ---oracion
# position one is straightforward humbuckers ; position two coil taps both pickups , leaving just the outer coils operational ; position three <head>activates</head> only the inner coils ; position four gives you the humbuckers in parallel and five puts them out of phase
# ---oracione sin parentesis
# position three activates only the inner coils .
#
#
# ---oracion
# Inside the denser ch'i of the living body flow more rarefied currents which circulate and <head>activate</head> it , moving freely as breath , less freely as blood
# ---oracione sin parentesis
# currents which circulate and activate it .
#
#
# ---oracion
# The natives know that it is not the actual paintings in the caves that <head>activate</head> the Kurunba but the rocks on which they are drawn ; the rocks being imbued with the spirit of the entities depicted
# ---oracione sin parentesis
# the caves that activate the Kurunba but the rocks .
#
#
# ---oracion
# Three eclipses will <head>activate</head> parts of the Virgo horoscope , open your eyes to possibilities and ensure that you get out of any ruts
# ---oracione sin parentesis
# Three eclipses will activate parts of the Virgo horoscope , open your eyes to possibilities and ensure .
#
#
# ---oracion
# threshold level specifications are drawn up with an eye to meeting the needs of learners as eventual participants in contexts of communicative interaction , rather than with a concern to <head>activate</head> the actual learning process itself
# ---oracione sin parentesis
# a concern to activate the actual learning process itself .
#
#
# ---oracion
# In other words it does not use theory to <head>activate</head> the crucial process of mediation
# ---oracione sin parentesis
# other words it does not use theory to activate the crucial process of mediation .
#
#
# ---oracion
# Many of the specific meanings which can be deciphered out of the symbol are not <head>activated</head> because they are not indexically required
# ---oracione sin parentesis
# Many of the specific meanings which are not activated .
#
#
# ---oracion
# Shoctector works by monitoring the current flowing in the live and neutral wires , and is <head>activated</head> by any leakage of current to earth perhaps through you
# ---oracione sin parentesis
# Shoctector works by , and is activated by any leakage of current to earth perhaps through you .
#
#
# ---oracion
# Antifreeze , the name of this trace heating tape , is controlled by pre - set thermostats , and is only <head>activated</head> when the temperature drops to near freezing , or below , making it economical and cost-effective
# ---oracione sin parentesis
# set thermostats , and is only activated .
#
#
# ---oracion
# Finally , of course , there must be a substance such as glucose , which can <head>activate</head> the sodium cotransport systems in the gut epithelium the systems upon which the principle of ORT relies
# ---oracione sin parentesis
# glucose , which can activate the sodium .
#
#
# ---oracion
# The ZETA team detected these neutrons using scintillation counters and boron counters , and by <head>activating</head> silver ( neutrons have a large cross-section propensity to interact with boron and silver , hence the use of these elements to detect them ) and showed that fusion was taking place in ZETA on a substantial scale
# ---oracione sin parentesis
# The ZETA team detected these neutrons using scintillation counters and boron counters , and by activating silver  and showed .
#
#
# ---oracion
# They are available with voice - <head>activated</head> recording facility so they only tape when you talk
# ---oracione sin parentesis
# They are available with voice - activated recording facility .
#
#
# ---oracion
# Irish Moss , Clover Blossom and Bay Laurel to give a brilliant shine that is re - <head>activated</head> with brushing
# ---oracione sin parentesis
# a brilliant shine that is re - activated .
#
#
# ---oracion
# They stood impassive as the optic burner angled across them , glinting red but not yet <head>activated</head>
# ---oracione sin parentesis
# They stood impassive as the optic burner angled across them , but not yet activated .
#
#
# ---oracion
# Judge Alistair Bell re - <head>activated</head> the suspended sentence and imposed another six-month term to run concurrently
# ---oracione sin parentesis
# Judge Alistair Bell re - activated the suspended sentence and imposed another six-month term .
#
#
# ---oracion
# As the system detects mismatches between initial bottom-up sensory information and the top-down information about the expected sound representation of words generated by context , inappropriate candidates within the initial cohort are de - <head>activated</head>
# ---oracione sin parentesis
# inappropriate candidates within the initial cohort are de - activated .
#
#
# ---oracion
# By this method the detail of the object will be seen in a wider visual angle and the retinal image will be magnified , a greater part of the retina thus being <head>activated</head>
# ---oracione sin parentesis
# the retinal image will be magnified , a greater part of the retina thus being activated .
#
#
# ---oracion
# Maybe it 's not <head>activated</head> by which
# ---oracione sin parentesis
# it 's not activated .
#
#
# ---oracion
# In that case , the ship would want to be a large number of miles away before the mine was <head>activated</head>
# ---oracione sin parentesis
# the mine was activated .
#
#
# ---oracion
# Do you think it could be de - <head>activated</head> , sir
# ---oracione sin parentesis
# it could be de - activated , sir .
#
#
# ---oracion
# I suspect that it can't be de - <head>activated</head>
# ---oracione sin parentesis
# it ca n't be de - activated .
#
#
# ---oracion
# When <head>activated</head> by being pumped full of air these modules will be able to prevent water from entering the Lagoon and also from leaving
# ---oracione sin parentesis
# activated .
#
#
# ---oracion
# After we reduced the parts to three , it became clear that we had to remove the work from the centre and reduce it to two elements , which would hold the volumes of the north and the south galleries and make a linkage across the Octagon <head>activating</head> the entire space
# ---oracione sin parentesis
# it became clear that we had activating the entire space .
#
#
# ---oracion
# Its system is derived from an architecture that integrates disparate products and applications around an event-driven core providing an automated alarm system <head>activated</head> in anticipation of a user-defined problem and takes immediate action
# ---oracione sin parentesis
# an architecture that integrates disparate products and applications around an event-driven core providing an automated alarm system activated in anticipation of a user-defined problem and takes immediate action .
#
#
# ---oracion
# When <head>activated</head> , a bright fluorescent light illuminates for up to 60 seconds , or for as long as there is movement
# ---oracione sin parentesis
# activated , a bright fluorescent light illuminates for up to 60 seconds , or for as long .
#
#
# ---oracion
# If the adventurers are successful in picking the lock , this trap won't be <head>activated</head> , but they will have to be very careful taking out the money without breaking the glass sphere ( no test needed , but you should roll dice as if you were making some secret test just to scare the players )
# ---oracione sin parentesis
# this trap wo n't be activated .
#
#
# ---oracion
# High Masters of the Ordo Hydra would <head>activate</head> those psychic spores
# ---oracione sin parentesis
# High Masters of the Ordo Hydra would activate those psychic spores .
#
#
# ---oracion
# Some were constructed so that they would only move when a passing person <head>activated</head> a treadle of some sort so that the toy would suddenly spring into life
# ---oracione sin parentesis
# a passing person activated so .
#
#
# ---oracion
# Emotional experience , on the other hand , he thought was the result of <head>activating</head> specific areas of the cerebral cortex in much the same way as activating other areas produced visual or auditory experience
# ---oracione sin parentesis
# the result of activating specific areas of the cerebral cortex in much the same way as activating other areas produced visual or auditory experience .
#
#
# ---oracion
# This led Morgan ( 1943 ) to argue that drive must be due to <head>activating</head> a central nervous system mechanism that represents the drive state , much in the same way as Papez was claiming that activation of the cingulate cortex represented emotion
# ---oracione sin parentesis
# This led Morgan  to argue that drive must be due to activating a central nervous system mechanism .
#
#
# ---oracion
# Output neurons can be <head>activated</head> in one of two ways , either by the output pattern generator line , or by the input cells
# ---oracione sin parentesis
# Output neurons can be activated in one of two ways , either by the output pattern generator line , or by the input cells .
#
#
# ---oracion
# After a number of such pairings a particular pattern of input will come to evoke a selected output pattern , without the output pattern generator being <head>activated</head>
# ---oracione sin parentesis
# a particular pattern of input will come , without the output pattern generator being activated .
#
#
# ---oracion
# Each Y-neuron contacts only one output cell and is capable of <head>activating</head> that cell
# ---oracione sin parentesis
# Each Y-neuron contacts only one output cell and is capable of activating that cell .
#
#
# ---oracion
# The physical events that <head>activate</head> our sense organs are already imperfect versions of the properties of objects that we wish to know about
# ---oracione sin parentesis
# The physical events that activate our sense organs .
#
#
# ---oracion
# You find that cells in adjacent parts of the visual cortex are <head>activated</head> by stimulation in adjacent parts of the visual field
# ---oracione sin parentesis
# cells in adjacent parts of the visual cortex are activated by stimulation in adjacent parts of the visual field .
#
#
# ---oracion
# But they had already spoken that morning , their plans drawn up ready to be <head>activated</head>
# ---oracione sin parentesis
# their plans drawn up ready to be activated .
#
#
# ---oracion
# The following example of a joint problem-solving session , discussed in greater detail elsewhere in a different context ( Hanko 1985/7 ) , illustrates both the range of issues that can arise for exploration , and the processes which can be <head>activated</head> in group consultation to contribute to insight and solution
# ---oracione sin parentesis
# the processes which can be activated in group consultation .
#
#
# ---oracion
# Sparc users create hot-key <head>activated</head> macro commands that correspond to any sequence of keyboard or mouse inputs
# ---oracione sin parentesis
# Sparc users create hot-key activated macro commands .
#
#
# ---oracion
# SayIt which builds voice - <head>activated</head> macros
# ---oracione sin parentesis
# SayIt which builds voice - activated macros .
#
#
# ---oracion
# Disk-resident MIBs will be able to be loaded and <head>activated</head> dynamically as well as unloaded and de - activated in order to free memory
# ---oracione sin parentesis
# Disk-resident MIBs will be able to be loaded and activated dynamically as well as unloaded and de - activated in order to free memory .
#
#
# ---oracion
# Its solution is derived from an architecture that integrates disparate products and applications around an event-drive core providing an automated alarm system <head>activated</head> in anticipation of a user-defined problem and takes immediate action
# ---oracione sin parentesis
# an architecture that integrates disparate products and applications around an event-drive core providing an automated alarm system activated in anticipation of a user-defined problem and takes immediate action .
#
#
# ---oracion
# II might <head>activate</head> a p185 receptor tyrosine kinase ( perhaps erbB2 ) on
# ---oracione sin parentesis
# II might activate a p185 receptor tyrosine kinase  .
#
#
# ---oracion
# II <head>activates</head> the phosphorylation of a
# ---oracione sin parentesis
# II activates the phosphorylation of a .
#
#
# ---oracion
# Thus , Max can bind DNA in the absence of Myc but does not significantly <head>activate</head> transcription in our system unless tagged with a heterologous transactivation domain
# ---oracione sin parentesis
# Thus , Max can bind DNA in the absence of Myc but does not significantly activate transcription in our system .
#
#
# ---oracion
# what initiates the formation of the actin cable , and what <head>activates</head> its contraction and the associated cell rearrangements
# ---oracione sin parentesis
# what , and what activates its contraction and the associated cell rearrangements .
#
#
# ---oracion
# Clearly , PLC - 1 is <head>activated</head> by all four members of the q family ( q , 11 , 14 , and 16 )
# ---oracione sin parentesis
# Clearly , PLC - 1 is activated by all four members of the q family  .
#
#
# ---oracion
# This will <head>activate</head> presynaptic L - AP4 receptors and reduce glutamate release
# ---oracione sin parentesis
# This will activate presynaptic L - AP4 receptors and reduce glutamate release .
#
#
# ---oracion
# It will also <head>activate</head> some postsynaptic NMDA receptors , allowing some postsynaptic Ca 2+ influx at synapses that are not releasing glutamate ( when other active synapses depolarize the cell and remove Mg 2+ - block of the NMDA channels )
# ---oracione sin parentesis
# It will also activate some postsynaptic NMDA receptors .
#
#
# ---oracion
# Growth stimulation by all FGFs tested is not unexpected because different FGF ligands can interact with and <head>activate</head> the same receptor , and FGF receptors are expressed in limb mesenchyme 1 8 , 19
# ---oracione sin parentesis
# Growth stimulation by all FGFs tested and activate the same receptor .
#
#
# ---oracion
# Cooperativity describes the existence of an intensity threshold for induction ; weak tetani , <head>activating</head> relatively few afferent fibres , do not trigger LTP
# ---oracione sin parentesis
# weak tetani , activating relatively few afferent fibres , do not trigger LTP .
#
#
# ---oracion
# Weak stimuli , activating only a few fibres , fail to induce LTP not because insufficient L-glutamate is released to <head>activate</head> NMDA receptors , but because the level of depolarization provided by the weak input does not produce an adequate reduction of the Mg 2+ block
# ---oracione sin parentesis
# insufficient L-glutamate is released to activate NMDA receptors .
#
#
# ---oracion
# When many fibres are <head>activated</head> in synchrony by a strong stimulus , depolarization spreads between neighbouring synapses to enhance the unblocking of NMDA channels
# ---oracione sin parentesis
# many fibres are activated in synchrony by a strong stimulus .
#
#
# ---oracion
# A recent view is that a postsynaptic kinase is <head>activated</head> transiently ( for less than a few minutes following the tetanus ) and a presynaptic kinase is activated for longer periods ( but for less than 1 hour )
# ---oracione sin parentesis
# a postsynaptic kinase is activated transiently  .
#
#
# ---oracion
# Another phospholipase A 2-derived lipid , platelet - <head>activating</head> factor , also has some of the properties expected of a retrograde messenger
# ---oracione sin parentesis
# A 2-derived lipid , platelet - activating factor , also has some of the properties expected of a retrograde messenger .
#
#
# ---oracion
# When the Schaffer collateral - commissural pathway is stimulated it also <head>activates</head> GABAergic interneurons ( through glutamatergic synapses similar to those on pyramidal neurons ) and this leads to the biphasic i
# ---oracione sin parentesis
# it also activates GABAergic interneurons  .
#
#
# ---oracion
# Other enzymes , such as nitric oxide synthase ( NOS ) , if present , may also be <head>activated</head> by the Ca 2+ transient
# ---oracione sin parentesis
# Other enzymes , such as nitric oxide synthase  , if present , may also be activated by the Ca 2 + transient .
#
#
# ---oracion
# T-cell proliferation by blocking the calcium - <head>activated</head> pathway leading to interleukin-2 transcription
# ---oracione sin parentesis
# T-cell proliferation by blocking the calcium - activated pathway leading to interleukin-2 transcription .
#
#
# ---oracion
# The gene is not initially <head>activated</head> in r3 at 8
# ---oracione sin parentesis
# The gene is not initially activated in r3 at 8 .
#
#
# ---oracion
# This sentence may be <head>added</head> to the new one-year term
# ---oracione sin parentesis
# This sentence may be added to the new one-year term .
#
#
# ---oracion
# Mao <head>added</head>
# ---oracione sin parentesis
# Mao added .
#
#
# ---oracion
# His memories of his Paris studio <head>add</head> spice to his account , for the facilities there were used not only by his students but in addition by such major artists as Mir and Picasso
# ---oracione sin parentesis
# His memories of his Paris studio add spice to his account , for the facilities .
#
#
# ---oracion
# And for wanting , Fraser <head>adds</head> , to destroy her
# ---oracione sin parentesis
# And for , Fraser adds .
#
#
# ---oracion
# Everything will be subjugated to that goal Kapuscinski 's way with words entails <head>adding</head> , repeating piling up , for the space of a slim volume
# ---oracione sin parentesis
# Everything will be subjugated to that goal Kapuscinski 's way with words entails adding , repeating , for the space of a slim volume .
#
#
# ---oracion
# As long as you know what you 're doing , she ventures , <head>adding</head>
# ---oracione sin parentesis
# As long as you know what you 're doing , , adding .
#
#
# ---oracion
# The range is obviously very wide , and you may find yourself in a Greek tragedy , or even a modern exercise play such as Games by James Saunders , where the student may <head>add</head> to the text by research material which can be incorporated in the project
# ---oracione sin parentesis
# the student may add to the text by research material .
#
#
# ---oracion
# One can also <head>add</head> that there is something in the present policies of the SDLP which suggest a need to maintain a somewhat fragile unity in respect of the national question
# ---oracione sin parentesis
# One can also add .
#
#
# ---oracion
# One can recognize here , with Lvi - Strauss ( 1968 ) , the importance of ambiguous mediators in relating the opposites within one 's cultural universe and one can <head>add</head> the Apprentice Boys to Lvi - Strauss 's shortlist of tricksters and twins in this role
# ---oracione sin parentesis
# one can add the Apprentice Boys to Lvi .
#
#
# ---oracion
# It should be <head>added</head> here that the high clergy hardly recognized that they had actually been exercising a political religious power of a specifically sectarian or monopolistic type
# ---oracione sin parentesis
# It should be added here .
#
#
# ---oracion
# The curate <head>added</head> to this that those promoting the integrated project were in fact promoting secularism
# ---oracione sin parentesis
# The curate added to this .
#
#
# ---oracion
# Not <head>add</head> to the pollution
# ---oracione sin parentesis
# Not add to the pollution .
#
#
# ---oracion
# My unease at having to cut into the glass , at having to <head>add</head> to the glass , he wrote
# ---oracione sin parentesis
# My unease at , at having to add to the glass , he wrote .
#
#
# ---oracion
# He <head>added</head> quickly
# ---oracione sin parentesis
# He added quickly .
#
#
# ---oracion
# Some brewers <head>add</head> extra sugar at this stage to encourage the continuing fermentation
# ---oracione sin parentesis
# Some brewers add extra sugar at this stage .
#
#
# ---oracion
# Finings , a glutinous substance made from the bladder of the sturgeon , is <head>added</head> either at the conditioning stage or when the beer is in cask to fine or clear the beer
# ---oracione sin parentesis
# Finings , a glutinous substance made from the bladder of the sturgeon , is added either at the conditioning stage or .
#
#
# ---oracion
# She <head>added</head> that all rooms contained details about the charges in an information directory
# ---oracione sin parentesis
# She added .
#
#
# ---oracion
# The chromium and nickel are <head>added</head> to give shine and prevent rusting
# ---oracione sin parentesis
# The chromium and nickel are added .
#
#
# ---oracion
# She <head>adds</head> eggs , cream , or a little crme fraiche , and wild mushrooms cooked with shallots
# ---oracione sin parentesis
# She adds eggs , cream , or a little crme fraiche .
#
#
# ---oracion
# Or even <head>added</head> to others already there
# ---oracione sin parentesis
# Or even added to others already there .
#
#
# ---oracion
# I <head>added</head> ( with uncharacteristic generosity ) , and thank you for the present
# ---oracione sin parentesis
# I added  , and thank you for the present .
#
#
# ---oracion
# I still can't quite work out how this all <head>adds</head> up
# ---oracione sin parentesis
# this all adds up .
#
#
# ---oracion
# I paused for a moment , then <head>added</head>
# ---oracione sin parentesis
# I paused for a moment , then added .
#
#
# ---oracion
# Dig over , remove weeds and <head>add</head> manure to prepare new borders for planting
# ---oracione sin parentesis
# Dig over , remove weeds and add manure .
#
#
# ---oracion
# Place them on a sandy layer over seed compost in trays , <head>adding</head> more sand to cover all but the tips
# ---oracione sin parentesis
# Place them on a sandy layer over seed compost in trays , adding more sand .
#
#
# ---oracion
# If your container has no drainage holes , it is essential to plant in bulb fibre , which is a compost of peat or a peat substitute with crushed oyster shell and charcoal <head>added</head> to keep the compost sweet
# ---oracione sin parentesis
# bulb fibre , which is a compost of peat or a peat substitute with crushed oyster shell and charcoal added .
#
#
# ---oracion
# When the manures rot down they <head>add</head> organic matter to the soil , which turns into humus
# ---oracione sin parentesis
# they add organic matter to the soil .
#
#
# ---oracion
# Worm casts make excellent additives to composts , not only improving the structure of the medium but <head>adding</head> nutrients and growth-promoting hormones too
# ---oracione sin parentesis
# Worm casts , not only improving the structure of the medium but adding nutrients and growth-promoting hormones too .
#
#
# ---oracion
# All you do is put in the starter compost and the newspaper , <head>add</head> the worms and put some kitchen waste on top
# ---oracione sin parentesis
# All is put in the starter compost and the newspaper , add the worms and put some kitchen waste on top .
#
#
# ---oracion
# At they munch their way through , you progressively <head>add</head> waste until the bin 's full
# ---oracione sin parentesis
# you progressively add waste .
#
#
# ---oracion
# Growers in Holland have <head>added</head> two more popular plants to the list of species which can cause allergies in gardeners
# ---oracione sin parentesis
# Growers in Holland have added two more popular plants to the list of species .
#
#
# ---oracion
# Castlewellan Gold , a Leyland cypress type Dwarf box makes traditional edging Flowering quince will <head>add</head> colour Griswlinia will tolerate salt-laden winds Yew foliage and fruits are attractive , but poisonous
# ---oracione sin parentesis
# traditional edging Flowering quince will add colour Griswlinia .
#
#
# ---oracion
# I believe , should <head>add</head> a crucial semantic dimension to compliment the many non-qualitative enquiries into policing now in progress
# ---oracione sin parentesis
# I believe , should add a crucial semantic dimension .
#
#
# ---oracion
# The second thing to note is that each offence carries its own scale of penalties , and penalties for one offence are not <head>added</head> on to penalties imposed for a different offence
# ---oracione sin parentesis
# penalties for one offence are not added on to penalties imposed for a different offence .
#
#
# ---oracion
# Note that the knee drops as the foot drives out , <head>adding</head> to the thrusting action
# ---oracione sin parentesis
# Note that the knee drops as the foot drives out , adding to the thrusting action .
#
#
# ---oracion
# The recoil gives you <head>added</head> stability , but you must take care that it doesn't thrust you backwards and off balance
# ---oracione sin parentesis
# you added stability .
#
#
# ---oracion
# Now , Robertson , <head>add</head> this
# ---oracione sin parentesis
# Now , Robertson , add this .
#
#
# ---oracion
# Within an hour Allan , Donald the smith , and the Logan brothers had set off down the strath to Weem with the petitions in a leather wallet , to <head>add</head> to the already thick bunch in James 's strong-box , and Cameron and James had got horses from a sympathizer in the village and rode off towards the narrow glen of Keltney
# ---oracione sin parentesis
# and the Logan brothers had set off down the strath to Weem with the petitions in a leather wallet , to add to the already thick bunch in James 's strong-box , and .
#
#
# ---oracion
# Hebrew teachers never failed to emphasise this aspect of his heritage ; never failed to <head>add</head> to his sense of duty and destiny
# ---oracione sin parentesis
# ; never failed to add to his sense of duty and destiny .
# ---oracion
# There is a fascinating folk-tale about a child 's pre - birth experience which <head>adds</head> weight to this , though it is not reserved to the Kohanim
# ---oracione sin parentesis
# birth experience which adds weight to this .
#
#
# ---oracion
# Later the legends and stories with which she had grown up would be <head>added</head> to them stories of astonishing miracles and heroic adventures , by which she and her father , Solomon Klinitsky - Klein whose influence on Leonard should not be overlooked fired his imagination and stimulated his ideas
# ---oracione sin parentesis
# Later the legends and stories with which would be added to them stories of astonishing miracles and heroic adventures , by which and stimulated his ideas .
#
#
# ---oracion
# He declined to <head>add</head> anything in the column for Other personal information
# ---oracione sin parentesis
# He declined to add anything in the column for Other personal information .
#
#
# ---oracion
# Accordingly , he read arts in his first year ; commerce ( which included accounting , commercial law , political science and a couple of doses of mathematics ) in his second ; arts ( though strangely retaining political science ) for his third and fourth years , to which was <head>added</head> zoology
# ---oracione sin parentesis
# Accordingly , he read arts in his first year ; commerce  in his second ; arts  for his third and fourth years , to which was added zoology .
#
#
# ---oracion
# Leonard could be fastidious to the nth degree in completing his own work he has always said that he works one word at a time , and can spend months , even years , in <head>adding</head> finesse to it ; he is nevertheless dismissive of anything approaching scholarly exactitude , still more so pedantry
# ---oracione sin parentesis
# Leonard could be fastidious to the nth degree in , in adding finesse to it ; .
#
#
# ---oracion
# Easily the most promising , judged Pacey , in 1961 ; and George Woodcock <head>added</head> that Leonard was one who could write lines which are no longer good imitation Yeats ; they are lines which only Yeats could have imitated
# ---oracione sin parentesis
# George Woodcock added .
#
#
# ---oracion
# Hasidic myth , and comments that the poet as priest is forced beyond Genesis ( sic ) ; elsewhere she <head>adds</head> a description of Leonard as the exiled poet priest of
# ---oracione sin parentesis
# elsewhere she adds a description of Leonard as the exiled poet priest .
#
#
# ---oracion
# And not only rabbis , one might <head>add</head> , but priests and nuns , monks , ministers and bishops
# ---oracione sin parentesis
# one might add , but priests and nuns .
#
#
# ---oracion
# Purdy <head>added</head> ,
# ---oracione sin parentesis
# Purdy added .
#
#
# ---oracion
# And , he <head>added</head> , you 're part of the shopping expedition tomorrow morning
# ---oracione sin parentesis
# And , he added , you 're part of the shopping expedition tomorrow morning .
#
#
# ---oracion
# Then she <head>added</head> , Sheila can put me up until
# ---oracione sin parentesis
# she added .
#
#
# ---oracion
# So , you can experiment , <head>adding</head> an extra lane at each end
# ---oracione sin parentesis
# So , you can experiment , adding an extra lane at each end .
#
#
# ---oracion
# He not only <head>added</head> a greater dimension through his excellent , exciting tennis , but also through his personality
# ---oracione sin parentesis
# He not only added a greater dimension through his excellent , exciting tennis , but also through his personality .
#
#
# ---oracion
# This storage of glycogen in the muscles <head>adds</head> to the overall size of the muscles
# ---oracione sin parentesis
# This storage of glycogen in the muscles adds to the overall size of the muscles .
#
#
# ---oracion
# It is also possible to modify the original by <head>adding</head> or omitting parts , or even combining different patterns into one carving
# ---oracione sin parentesis
# It is also possible to modify the original by adding or omitting parts , or even combining different patterns into one carving .
#
#
# ---oracion
# Just to <head>add</head> to the confusion there are also different types of handles
# ---oracione sin parentesis
# Just to add to the confusion .
#
#
# ---oracion
# A couple will each receive a community charge bill , but their income and savings will be <head>added</head> together when their benefit is worked out
# ---oracione sin parentesis
# their income and savings will be added together .
#
#
# ---oracion
# To compensate for these temporary speed restrictions additional recovery time is <head>added</head> to daytime schedules
# ---oracione sin parentesis
# additional recovery time is added to daytime schedules .
#
#
# ---oracion
# The Royal Ballet ) A fifth choreographer must be <head>added</head> to this list
# ---oracione sin parentesis
# The Royal Ballet -RRB- A fifth choreographer must be added to this list .
#
#
# ---oracion
# Grande and Petite batterie Petipa 's suggestion that beats can <head>add</head> brilliance to the dance is nowhere better exemplified than in the briss vois and temps depoisson of the Bluebird 's solo in
# ---oracione sin parentesis
# beats can add brilliance to the dance .
#
#
# ---oracion
# The brilliant bravura variation when Kitri springs lightly forwards sur les pointes whilst fanning herself and Basil attempts to make his zapateado ( heel-tapping ) appear authentic by the slightly crouching pose of his body , <head>add</head> even greater panache to their efforts
# ---oracione sin parentesis
# The brilliant bravura variation when , add even greater panache to their efforts .
#
#
# ---oracion
# When talking about Le Carnaval , he <head>added</head>
# ---oracione sin parentesis
# he added .
#
#
# ---oracion
# Choreographers must then decide how many and which details they need to <head>add</head> to disclose the particular features of the story , theme and/or music that they wish to communicate
# ---oracione sin parentesis
# Choreographers must then decide how many and which details they need to add .
#
#
# ---oracion
# Instead of a secondary fermentation in the cask to <head>add</head> a full , mature palate , keg beers are killed off in the brewery by filtration , chilling and pasteurisation
# ---oracione sin parentesis
# the cask to add a full , mature palate .
#
#
# ---oracion
# As the wort is boiled in the copper with the hops many brewers also <head>add</head> sugars , such as glucose or cereal syrup , to encourage a strong fermentation
# ---oracione sin parentesis
# the wort is boiled in the copper with the hops many brewers also add .
#
#
# ...
#
#
# ---oracion
# We sat there drinking hot chocolate and <head>watching</head> the clouds scrape raggedly past
# ---oracione sin parentesis
# there drinking hot chocolate and watching .
#
#
# ---oracion
# Mehew 's contribution probably surprised the scouts , who were almost certainly in Bath to <head>watch</head> Penrice and Nigel Martyn , but it is a fair reflection of his part in pushing Rovers into second place
# ---oracione sin parentesis
# the scouts , who were almost certainly in Bath to watch Penrice and Nigel Martyn .
#
#
# ---oracion
# Navratilova had <head>watched</head> in awe as Evert opened up the rain-delayed Federation Cup semi-final between the United States and Czechoslovakia to set her team on the way to a 2-0 victory
# ---oracione sin parentesis
# Navratilova had watched in awe .
#
#
# ---oracion
# Second Division at Halifax , Hull KR and Ryedale York , where 5,000 <head>watched</head> the inaugural game at the club 's swish new stadium in the suburbs
# ---oracione sin parentesis
# 5,000 watched the inaugural game at the club 's swish new stadium in the suburbs .
#
#
# ---oracion
# Human rights can be <head>won</head> even against overwhelming odds
# ---oracione sin parentesis
# Human rights can be won even against overwhelming odds .
#
#
# ---oracion
# At least an hour before the cooks submitted their offerings to be judged , it was clear who was going to <head>win</head>
# ---oracione sin parentesis
# least an hour before , it was clear who was going to win .
#
#
# ---oracion
# Yorks Pools <head>win</head>
# ---oracione sin parentesis
# Yorks Pools win .
#
#
# ---oracion
# Although the opposing team has no chance of <head>winning</head> , any attempt to withdraw your remaining team-member ( s ) may well be rewarded by disqualification of the entire team for bad sportsmanship
# ---oracione sin parentesis
# the opposing team has no chance of winning .
#
#
# ---oracion
# To do so is to help the opponent to <head>win</head> without his having to hit you with a single scoring technique
# ---oracione sin parentesis
# the opponent to win .
#
#
# ---oracion
# Now if we are going to roast the lairds , and get some rights at last , do you think we can <head>win</head> our lease back from old Menzies do you think so , Angus
# ---oracione sin parentesis
# we can win our lease back from old Menzies .
#
#
# ---oracion
# Undertakings to be <head>won</head> from the lairds binding themselves to undertake nothing punitive against tenants seen at meetings
# ---oracione sin parentesis
# Undertakings to be won from the lairds .
#
#
# ---oracion
# So we need all help , all resources , everybody , if we are to <head>win</head> , and save ourselves
# ---oracione sin parentesis
# So we need all help , all resources , everybody , if we are to win , and save ourselves .
# ---oracion
# Knowing that if they break our will , they <head>win</head>
# ---oracione sin parentesis
# they win .
#
#
# ---oracion
# The Buddekes , however , were to <head>win</head>
# ---oracione sin parentesis
# The Buddekes , however , were to win .
#
#
# ---oracion
# But when you have a situation where youngsters of 12 or 13 and in some cases even younger who may only have <head>won</head> a couple of matches , are being offered 500,000 guarantees to sign up with one of the management companies before they are snapped up by one of the rival agents , the potential for long term damage is enormous
# ---oracione sin parentesis
# even younger who may only have won a couple of matches .
#
#
# ---oracion
# Steffi could <head>win</head> the gold medal playing left-handed
# ---oracione sin parentesis
# Steffi could win the gold medal playing left-handed .
#
#
# ---oracion
# In fact , by <head>winning</head> the Pilkington Glass Ladies ' title in June for the 10th time , she came to within one of Chris Evert 's record of 157 career titles
# ---oracione sin parentesis
# fact , by winning the Pilkington Glass Ladies ' title in June for the 10th time , she came to within one of Chris Evert 's record of 157 career titles .
#
#
# ---oracion
# To have a chance of <head>winning</head> this superb prize , just answer the three questions below and send your answers in to arrive not later than 28th August
# ---oracione sin parentesis
# a chance of winning this superb prize .
#
#
# ---oracion
# The prize of five Wilson Hammer rackets to be <head>won</head> in the April issue of
# ---oracione sin parentesis
# The prize of five Wilson Hammer rackets to be won in the April issue .
#
#
# ---oracion
# whilst younger brother Craig , fought back from one set down against James Lake ( Lincs ) to <head>win</head> the 12 and under title 46 62 61
# ---oracione sin parentesis
# one set down against James Lake  to win the 12 .
#
#
# ---oracion
# Two young athletes <head>winning</head> on the big stage and managing to enjoy every minute of the experience
# ---oracione sin parentesis
# Two young athletes winning on the big stage and managing .
#
#
# ---oracion
# Higgs Light Music ( left ) <head>won</head> third prize in the class
# ---oracione sin parentesis
# Higgs Light Music  won third prize in the class .
#
#
# ---oracion
# Teddy Bears may not be the most active models , but their nuances of age make reproduction in wood a challenge , as George Brownlee discovered when he carved this award - <head>winning</head> piece
# ---oracione sin parentesis
# he carved this award - winning piece .
#
#
# ---oracion
# Richard Meighan 's gouge and Alan Toplin 's Bosch drill which <head>won</head> third prize , and 100 of Kirchen carving tools
# ---oracione sin parentesis
# Richard Meighan 's gouge and Alan Toplin 's Bosch drill which won third prize , and .
#
#
# ---oracion
# Dateline Ultar Aficionados of the prose of Victor Saunders , who <head>won</head> the Boardman - Tasker award for his book Elusive
# ---oracione sin parentesis
# Victor Saunders , who won the Boardman - Tasker award for his book Elusive .
#
#
# ---oracion
# Efforts over a prolonged period by the BMC and the Sandstone Climbing Club have failed to <head>win</head> reductions in the excessive charges here , but these efforts will continue
# ---oracione sin parentesis
# Efforts over a prolonged period by the BMC and the Sandstone Climbing Club have failed to win reductions in the excessive charges here , but .
#
#
# ---oracion
# And to keep the children amused , a Lego competition will be held in the creche , so that junior selfbuilders can also build their own houses , and perhaps <head>win</head> some Lego , too
# ---oracione sin parentesis
# junior selfbuilders can also build their own houses , and perhaps win some Lego , too .
#
#
# ---oracion
# SKILLS WITH GUINNESS ORIGINAL and <head>win</head> a holiday for two to the Caribbean
# ---oracione sin parentesis
# SKILLS WITH GUINNESS ORIGINAL and win a holiday for two to the Caribbean .
#
#
# ---oracion
# The entry will go back into the bag for the Grand Draw , so you 'll have the chance of <head>winning</head> more than one prize if you fill in this section but it is entirely optional
# ---oracione sin parentesis
# the chance of winning more than one prize .
#
#
# ---oracion
# September 2nd will <head>win</head> a prize
# ---oracione sin parentesis
# September 2nd will win a prize .
#
#
# ---oracion
# I could 've <head>won</head> prizes
# ---oracione sin parentesis
# I could 've won prizes .
#
#
# ---oracion
# We can't <head>win</head> but we must keep trying
# ---oracione sin parentesis
# We ca n't win but .
#
#
# ---oracion
# Commercial battles are not always won on technical merit , and at present X Windows is probably <head>winning</head>
# ---oracione sin parentesis
# present X Windows is probably winning .
#
#
# ---oracion
# For the next 12 years , Field relentlessly pursued his project , <head>winning</head> support of distinguished scientists and electrical engineers such as John Brett , Charles Bright and William Thomson ( later the first Lord Kelvin of Largs )
# ---oracione sin parentesis
# the next 12 years , Field relentlessly pursued his project , winning support of distinguished scientists and electrical engineers such as John Brett , Charles Bright and William Thomson  .
#
#
# ---oracion
# But Mr Lawson has to show he knows how to do the trick , before he can <head>win</head> his argument , in theory or in the markets
# ---oracione sin parentesis
# he can win his argument .
#
#
# ---oracion
# But , if Hammersmith <head>wins</head> and the deals are declared legal , the council will have to pay the losses on the transactions
# ---oracione sin parentesis
# Hammersmith wins .
#
#
# ---oracion
# Prost 's result does little to further his cause in the championship if he has to drop his lower scores but Senna now knows that he must <head>win</head> the final two races in Japan and Australia
# ---oracione sin parentesis
# he must win the final two races in Japan and Australia .
#
#
# ---oracion
# Some of them , by no means all , paid 7 to witness Mark Calcavecchia , Curtis Strange and Tom Kite <head>win</head> 100,000 ( 62,000 ) apiece
# ---oracione sin parentesis
# Some of them , by no means all , paid 7 to witness Mark Calcavecchia , Curtis Strange and Tom Kite win 100,000  apiece .
#
#
# ---oracion
# The following week he <head>won</head> in Phoenix by seven strokes
# ---oracione sin parentesis
# he won in Phoenix by seven strokes .
#
#
# ---oracion
# Kelly , who has <head>won</head> this race three times , said
# ---oracione sin parentesis
# Kelly , who has won this race three times .
#
#
# ---oracion
# Still , the best man <head>won</head>
# ---oracione sin parentesis
# Still , the best man won .
#
#
# ---oracion
# Having <head>won</head> two of this series in the fastest times already , he would have had to finish four seconds behind the steeplechaser Mark Rowland to lose the first prize of 5,000
# ---oracione sin parentesis
# Having won two of this series in the fastest times already , he would have had .
#
#
# ---oracion
# 8 GOING for the gap took on a painful new meaning for Steve Bowling when he helped Llanelli claw their way back to <head>win</head> this entertaining game
# ---oracione sin parentesis
# 8 GOING for the gap took on a painful new meaning for Steve Bowling when he helped Llanelli claw their way back to win this entertaining game .
#
#
# ---oracion
# Please <head>write</head> to
# ---oracione sin parentesis
# Please write to .
#
#
# ---oracion
# As there is no Embassy of Taiwan in the UK , please do not copy any appeals to another embassy , as proposed on the letter <head>writing</head> page
# ---oracione sin parentesis
# please do not copy any appeals to another embassy , as proposed on the letter writing page .
#
#
# ---oracion
# 39 of the prisoners featured in the letter <head>writing</head> campaign have been released ; about 50 remain in prison
# ---oracione sin parentesis
# 39 of the prisoners featured in the letter writing campaign have been released .
#
#
# ---oracion
# South Korean authorities <head>wrote</head> to AI in response to its appeals for imprisoned artist Hong Song-dam and publisher Chang Ui - gyun
# ---oracione sin parentesis
# South Korean authorities wrote to AI in response to its appeals for imprisoned artist Hong Song-dam and publisher Chang Ui - gyun .
#
#
# ---oracion
# He no longer wishes to emigrate and is planning to <head>write</head> his memoirs
# ---oracione sin parentesis
# He no longer wishes to emigrate and is planning to write his memoirs .
#
#
# ---oracion
# Wang Xizhe , a factory worker from Guangzhou , was an activist in the pro-democracy movement in China who helped to <head>write</head> and put up a 100 - metre newspaper wall in his city in 1974 which attracted worldwide interest
# ---oracione sin parentesis
# an activist in the pro-democracy movement in China who helped to write and put up a 100 - metre newspaper wall in his city in 1974 .
#
#
# ---oracion
# I am <head>writing</head> as
# ---oracione sin parentesis
# I am writing .
#
#
# ---oracion
# Is the text or part of the text <head>written</head> so that a reader will benefit in a future encounter with a work of art
# ---oracione sin parentesis
# Is the text or part of the text written so .
#
#
# ---oracion
# Things are not so simple , as some art historians <head>write</head> well about the present , with a generosity of feeling and approach enriching to contemporary culture
# ---oracione sin parentesis
# some art historians write well about the present .
#
#
# ---oracion
# Typically , a laudatory essay he <head>wrote</head> was called
# ---oracione sin parentesis
# he wrote .
#
#
# ---oracion
# Along this fiery path and valley , the tossing waves by which the swell of the sea is restlessly divided , lift themselves in dark , indefinite , fantastic forms , each casting a faint and ghastly shadow behind it along the illumined foam Purple and blue , the lurid shadows of the hollow breakers are cast upon the mist of night , which gathers cold and low , advancing like the shadow of death upon the guilty ship as it labours amid the lightening of the sea , its thin mast <head>written</head> upon the sky , in lines of blood
# ---oracione sin parentesis
# it labours amid the lightening of the sea , its thin mast written upon the sky , in lines of blood .
#
#
# ---oracion
# Fnon , like other excellent critics , was a valued friend of artists , and so he remained all his life even though he gave up <head>writing</head> criticism after a decade of working on the Revue blanche from 1893 to 1903
# ---oracione sin parentesis
# and so he remained all his life even though he gave up writing criticism after a decade .
#
#
# ---oracion
# Surrealist writer Georges Hugnet to <head>write</head> a historical essay , but it was Barr 's intelligent advocacy and choice of works that made the show such a significant affair
# ---oracione sin parentesis
# Georges Hugnet to write a historical essay .
#
#
# ---oracion
# Barr , in what used to be a general policy for museum curators , was not <head>writing</head> a passionate defence of the work his museum exhibited
# ---oracione sin parentesis
# Barr , in what , was not writing a passionate defence of the work .
#
#
# ---oracion
# In 1964 Peter Murray <head>wrote</head> an introduction to a new edition , in which he made an observation about the passage on Bernini 's St Teresa , the sculptural group in Rome which is a key work of the Baroque
# ---oracione sin parentesis
# 1964 Peter Murray wrote an introduction to a new edition , in which , the sculptural group in Rome .
#
#
# ---oracion
# More , probably , has been <head>written</head> about this great hall-like chapel than any other building in the world ; but in fact no description , picture or photograph conveys the impact which it makes
# ---oracione sin parentesis
# More , probably , has been written about this great hall-like chapel than any other building in the world .
#
#
# ---oracion
# Here is an American artist <head>writing</head> about his dismay at the work he saw at Paris in 1831
# ---oracione sin parentesis
# Here is an American artist writing about his dismay at the work .
#
#
# ---oracion
# From a letter to Francesco Gonzaga , <head>written</head> in 1622 and published by A
# ---oracione sin parentesis
# a letter to Francesco Gonzaga , written in 1622 and published by A .
#
#
# ---oracion
# I <head>write</head> Deceased across their letters Siegfried ,
# ---oracione sin parentesis
# I write Deceased across their letters Siegfried .
#
#
# ---oracion
# Some schools have been able to co-ordinate work with the National Film School , where a script has been <head>written</head> for the personalities in a group and then filmed on location , and this worked effectively
# ---oracione sin parentesis
# a script has been written for the personalities in a group and then filmed on location .
#
#
# ---oracion
# The drama school will give you some advice on when and where to <head>write</head> to , and how you organise your letters , but outside advice is very important in helping you to see yourself in perspective
# ---oracione sin parentesis
# some advice on when and where to write to , and .
#
#
# ---oracion
# It will be up to you to <head>write</head> constantly and make contacts everywhere and you will largely be responsible for yourself
# ---oracione sin parentesis
# It will be up to you to write constantly and make contacts everywhere and .
#
#
# ---oracion
# There 's lots of new plays being <head>written</head> that
# ---oracione sin parentesis
# There 's lots of new plays being written that .

# %%
pairs_test.shape
# Out:
# (4252, 4)

# %%
file_path_test = 'data_test_con_poda.json'
save_json(file_path_test, pairs_test)
